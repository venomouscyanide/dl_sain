# %% [markdown]
# ### Get all imports

# %%
import math
import os
import string
from collections import Counter, defaultdict
from math import ceil
from typing import List, Set, Tuple, Type, Dict
from abc import abstractmethod

import torch
from torch import nn
from torch.nn import CrossEntropyLoss
import gdown
import unidecode

# %% [markdown]
# ### Init the class which will give the password datasets. Currently supports Mate1, 000webhost and ClixSense.

# %%
class PasswordDataset:
    @abstractmethod
    def get_download_url(self) -> str:
        pass

    @abstractmethod
    def get_dataset_local_path(self) -> str:
        pass


class ClixSense(PasswordDataset):
    def get_download_url(self) -> str:
        return 'https://drive.google.com/uc?id=1S0-1gdzoP-HecS3L5_zStZhvTt9A4q97'

    def get_dataset_local_path(self) -> str:
        return 'pwd_dataset_manager/datasets/ClixSense.txt'


class WebHost(PasswordDataset):
    def get_download_url(self) -> str:
        return 'https://drive.google.com/uc?id=11tsLveuHo3xaVL2DRh3FfuUPG8LEtzYd'

    def get_dataset_local_path(self) -> str:
        return 'pwd_dataset_manager/datasets/000webhost.txt'


class Mate1(PasswordDataset):
    def get_download_url(self) -> str:
        return 'https://drive.google.com/uc?id=10LtJiV9J-Vuy1I8iSxacH4fsPqZamIeB'

    def get_dataset_local_path(self) -> str:
        return 'pwd_dataset_manager/datasets/Mate1.txt'


class DatasetFactory:
    def get(self, dataset_name: str) -> Type[PasswordDataset]:
        if dataset_name == "ClixSense":
            return ClixSense
        elif dataset_name == "000webhost":
            return WebHost
        elif dataset_name == "Mate1":
            return Mate1
        else:
            raise NotImplementedError(f"Dataset: {dataset_name} not supported")


def get_dataset(dataset_klass: Type[PasswordDataset]) -> List[str]:
    local_dataset = dataset_klass().get_dataset_local_path()
    if not os.path.exists(local_dataset):
        gdown.download(dataset_klass().get_download_url(), quiet=True, output=local_dataset)

    with open(local_dataset, "r") as dataset:
        contents = unidecode.unidecode(dataset.read())
        contents = contents.split('\n')
        contents = [content[:-1].strip() for content in contents]
    return contents

# %% [markdown]
# ### Declare all utilities
# This includes method to convert string to tensor + method for training on ClixSense dataset

# %%
# min size of ClixSense is 6
# max size of ClixSense is 25
# most common with their no_of_occurrences
# [('123456', 17871), ('123456789', 3294), ('12345678', 2091), ('password', 1967), ('111111', 1892),
# ('1234567', 1299), ('iloveyou', 1266), ('qwerty', 1187), ('clixsense', 1172), ('000000', 977)]

def get_input_expected_clixsense(dataset: List[str]) -> Tuple[List[Tuple[str, int]], Dict[str, Set[Tuple[str, str]]]]:    
    password_slices_dict = defaultdict(set)
    # this was made to be in this way because I wanted to support more slices within a password.
    # However, this is not being done. As a result this looks really stupid.
    [password_slices_dict[pwd].add((pwd[0: -1], pwd[1:])) for pwd in dataset[:]]

    n_most_common = 100000
    all_passwords = [pwd for pwd in dataset]
    counter = Counter(all_passwords)
    most_common = counter.most_common(n_most_common)

    return most_common, password_slices_dict


def convert_str_to_tensor(string_to_convert: str):
    size = len(string_to_convert)
    converted_tensor = torch.zeros(size, 1).long()
    for index, char in enumerate(string_to_convert):
        converted_tensor[index][0] = string.printable.index(char)
    return converted_tensor.to(device)

# %% [markdown]
# ### The GRU RNN network
# This is trained on 100,000 most common passwords in ClixSense for a set number of epochs
# The training itself was done locally due to compute constraints on Colab.

# %%
class GRU_RNN(nn.Module):
    def __init__(self, embedding_dim: int, hidden_size: int, no_of_hidden_layers: int, output_size: int):
        super().__init__()
        self.embedding_dim = embedding_dim
        # (L, N, H_in)
        self.gru = nn.GRU(self.embedding_dim, hidden_size, num_layers=no_of_hidden_layers)
        self.embedding = nn.Embedding(len(string.printable), embedding_dim=self.embedding_dim)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, input: torch.Tensor, hidden_state: torch.Tensor):
        input = self.embedding(input)
        reshaped_input = input.view(1, 1, self.embedding_dim)
        input, hidden_state = self.gru(reshaped_input, hidden_state)
        output = self.linear(input)
        return output, hidden_state

# %% [markdown]
# ### Init the class which will train the RNN on ClixSense

# %%
class PasswordGuesserUsingRNN:
    def __init__(self):
        self.hidden_size = 100
        self.no_of_hidden_layers = 20
        self.output_size = len(string.printable)
        self.embedding_dim = 5
        self.epochs = 10
        self.eta = 1e-4

    def train_and_evaluate(self):
        dataset_klass = DatasetFactory().get("ClixSense")
        dataset = get_dataset(dataset_klass)

        gru_model = GRU_RNN(self.embedding_dim, self.hidden_size, self.no_of_hidden_layers, self.output_size).to(device)
        optimizer = torch.optim.Adam(gru_model.parameters(), lr=self.eta)
        loss_fn = CrossEntropyLoss()

        n_most_common, pwd_inp_exp = get_input_expected_clixsense(dataset)
        # total_len of dict = 1338980
        # total length of passwords = 2221027
        for epoch in range(self.epochs):
            for pwd_index, (most_common_pwd, num_occ) in enumerate(n_most_common[:]):
                inp_target_set = pwd_inp_exp[most_common_pwd]
                for _ in range(ceil((num_occ / 100000) * 100)):
                    for input_pwd, target_pwd in inp_target_set:
                        loss = 0
                        optimizer.zero_grad()

                        hidden_state = self._init_hidden()
                        input_tensor = convert_str_to_tensor(input_pwd)
                        target_tensor = convert_str_to_tensor(target_pwd)

                        for input, expected in zip(input_tensor, target_tensor):
                            output, hidden_state = gru_model(input, hidden_state)
                            loss += loss_fn(output[-1], expected)

                        loss.backward()
                        optimizer.step()

                        loss = loss.item() / len(input_pwd)

                if pwd_index % 1000 == 0:
                    print(f"At pwd_index: {pwd_index} of {len(n_most_common)}")
                    print(f"training password: {most_common_pwd}")

                    print(f'At epoch: {epoch} with loss: {loss}')
                    start = "123"
                    prediction = self.evaluate_password(gru_model, start, 15)
                    print(f"Prediction is {prediction} for start with '{start}'")

        return gru_model

    def evaluate_password(self, gru_model: nn.Module, password_start: str, max_length: int):
        prediction = password_start
        start_tensor = convert_str_to_tensor(password_start)
        with torch.no_grad():
            hidden_state = self._init_hidden()
            for char in start_tensor:
                _, hidden_state = gru_model(char, hidden_state)

            input = start_tensor[-1]
            for char_gen in range(max_length - len(password_start)):
                output, hidden_state = gru_model(input, hidden_state)

                # understand below; taken from the ref colab
                output_dist = output.data.view(-1).exp()
                top_i = torch.multinomial(output_dist, 1)[0]

                char_predicted = string.printable[top_i]
                prediction += char_predicted
                input = convert_str_to_tensor(char_predicted)

        return prediction

    def _init_hidden(self):
        # (D∗num_layers, N, Hout)
        return torch.zeros(self.no_of_hidden_layers, 1, self.hidden_size).to(device)

# %% [markdown]
# ### Train the GRU model on ClixSense

# %%
device = "cuda"
gru_model = PasswordGuesserUsingRNN().train_and_evaluate()
torch.save(gru_model, 'saved_gru_pwd.model')
# Out:
# At pwd_index: 0 of 100000
# training password: 12345
# At epoch: 0 with loss: 4.540670871734619
# Prediction is 123l-T
# M.0#L)=0 for start with '123'
# At pwd_index: 1000 of 100000
# training password: coffe
# At epoch: 0 with loss: 3.8765103816986084
# Prediction is 123nu2lh1ealamc for start with '123'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-fcd30006f96e> in <module>
#       1 device = "cuda"
# ----> 2 gru_model = PasswordGuesserUsingRNN().train_and_evaluate()
#       3 torch.save(gru_model, 'saved_gru_pwd.model')
#
# <ipython-input-14-a247e3114545> in train_and_evaluate(self)
#      36
#      37                         loss.backward()
# ---> 38                         optimizer.step()
#      39
#      40                         loss = loss.item() / len(input_pwd)
#
# ~/.local/lib/python3.6/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.local/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps'])
#     120         return loss
#
# ~/.local/lib/python3.6/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      90             denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      91         else:
# ---> 92             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93
#      94         step_size = lr / bias_correction1
#
# KeyboardInterrupt:

# %% [markdown]
# The actual training was done locally and the logs for which can be found here: https://gist.github.com/venomouscyanide/8c4e18d042f4db891a614f838fa1b03a
#
# The training took approximately 11 hours to complete.
# After training, I save the model for easily running experiments on the other 2 datasets.
#
# The saved model is hosted here: https://drive.google.com/file/d/1P5_RetiDuEh-dLMpPt_sdjrSc9fX9Pej/view?usp=sharing

# %% [markdown]
# ## Init the class that will help make password guesses

# %%
class MakePasswordGuesses:
    MIN_LENGTH: int = 5
    MAX_LENGTH: int = 15
    MAX_TRIES_PER_CONFIG: int = 5
    MAX_GUESSES: int = int(math.pow(10, 6))

    def __init__(self, model: nn.Module, verbose: bool = True):
        self.model = model
        self.verbose = verbose

    def evaluate_dataset(self, dataset_name: str) -> Tuple[Set[str], Set[str]]:
        dataset_klass = DatasetFactory().get(dataset_name)
        dataset = get_dataset(dataset_klass)

        dataset_counter = Counter(dataset)

        print(f'Total passwords in {dataset_name} is {len(dataset)}')
        most_common = dataset_counter.most_common()

        total_correct_guesses, guessed_passwords, all_starters_used = self._make_guesses(most_common, dataset_counter)
        missed_passwords = set(dataset_counter.keys()).difference(guessed_passwords)

        print(
            f"Unique guesses correct: {len(guessed_passwords)} and Total guesses: {total_correct_guesses} and total misses: {len(missed_passwords)}"
        )
        print(f"Coverage on {dataset_name}: {round(total_correct_guesses) / len(dataset)}")

        self._write_debug(dataset_name, "all_starters.txt", all_starters_used)
        self._write_debug(dataset_name, "unique_correct_guesses.txt", guessed_passwords)
        self._write_debug(dataset_name, "missed_passwords.txt", missed_passwords)

        return guessed_passwords, missed_passwords

    def _form_candidates(self, common_pwd: str) -> List[str]:
        min_len = 3
        return [common_pwd[0:end] for end in range(min_len, len(common_pwd))]

    def _make_guesses(self, most_common: List[Tuple[str, int]], dataset_counter: Counter):
        total_correct_guesses = 0
        uniq_guessed_passwords = set()
        all_starters_used = set()
        total_guess_tracker = 0

        for common_pwd, _ in most_common:
            starter_candidates = self._form_candidates(common_pwd)
            all_starters_used |= set(starter_candidates)

            for candidate in starter_candidates:

                for max_len in range(self.MIN_LENGTH, self.MAX_LENGTH):

                    for _ in range(self.MAX_TRIES_PER_CONFIG):
                        if total_guess_tracker > self.MAX_GUESSES:
                            return total_correct_guesses, uniq_guessed_passwords, all_starters_used

                        total_guess_tracker += 1
                        if total_guess_tracker % 1000 == 0 and self.verbose:
                            print(f"At guess {total_guess_tracker} of {self.MAX_GUESSES}")

                        guess = PasswordGuesserUsingRNN().evaluate_password(self.model, candidate, max_length=max_len)

                        if guess not in uniq_guessed_passwords:
                            occurrences = dataset_counter.get(guess)
                            if occurrences:
                                if self.verbose:
                                    print(
                                        f"Correct guess: {guess}, for candidate: {candidate}, given max_len: {max_len}")
                                total_correct_guesses += occurrences
                                uniq_guessed_passwords.add(guess)

        return total_correct_guesses, uniq_guessed_passwords, all_starters_used

    def _write_debug(self, dataset_name: str, file_name: str, data_as_set: Set[str]):
        debug_folder = f'debug_{dataset_name}'
        if not os.path.exists(debug_folder):
            os.mkdir(debug_folder)

        data_as_str = '\n'.join(data_as_set)
        with open(os.path.join(debug_folder, file_name), "w") as debug_file:
            debug_file.write(data_as_str)

# %%
gru_model = torch.load('saved_gru_pwd.model')
MakePasswordGuesses(gru_model).evaluate_dataset('Mate1')
# Out:
# Total passwords in Mate1 is 27398563
# Correct guess: 12359, for candidate: 123, given max_len: 5
# Correct guess: 12329, for candidate: 123, given max_len: 5
# Correct guess: 12374, for candidate: 123, given max_len: 5
# Correct guess: 12340, for candidate: 123, given max_len: 5
# Correct guess: 12322, for candidate: 123, given max_len: 5
# Correct guess: 123939, for candidate: 123, given max_len: 6
# Correct guess: 123129, for candidate: 123, given max_len: 6
# Correct guess: 12347, for candidate: 1234, given max_len: 5
# Correct guess: 12348, for candidate: 1234, given max_len: 5
# Correct guess: 12346, for candidate: 1234, given max_len: 5
# Correct guess: 12342, for candidate: 1234, given max_len: 5
# Correct guess: 12344, for candidate: 1234, given max_len: 5
# Correct guess: 123472, for candidate: 1234, given max_len: 6
# Correct guess: 123401, for candidate: 1234, given max_len: 6
# Correct guess: 123430, for candidate: 1234, given max_len: 6
# Correct guess: 123453, for candidate: 1234, given max_len: 6
# Correct guess: 123419, for candidate: 1234, given max_len: 6
# Correct guess: 1234545, for candidate: 1234, given max_len: 7
# Correct guess: 1234232, for candidate: 1234, given max_len: 7
# Correct guess: 12312, for candidate: 123, given max_len: 5
# Correct guess: 12332, for candidate: 123, given max_len: 5
# Correct guess: 12380, for candidate: 123, given max_len: 5
# Correct guess: 12336, for candidate: 123, given max_len: 5
# Correct guess: 12394, for candidate: 123, given max_len: 5
# Correct guess: 123790, for candidate: 123, given max_len: 6
# Correct guess: 123602, for candidate: 123, given max_len: 6
# Correct guess: 123737, for candidate: 123, given max_len: 6
# Correct guess: 123696, for candidate: 123, given max_len: 6
# Correct guess: 123747, for candidate: 123, given max_len: 6
# Correct guess: 1239612, for candidate: 123, given max_len: 7
# Correct guess: 1234716, for candidate: 123, given max_len: 7
# Correct guess: 12349, for candidate: 1234, given max_len: 5
# Correct guess: 123411, for candidate: 1234, given max_len: 6
# Correct guess: 123439, for candidate: 1234, given max_len: 6
# Correct guess: 1234276, for candidate: 1234, given max_len: 7
# Correct guess: 1234575, for candidate: 1234, given max_len: 7
# Correct guess: 12345, for candidate: 12345, given max_len: 5
# Correct guess: 123451, for candidate: 12345, given max_len: 6
# Correct guess: 123454, for candidate: 12345, given max_len: 6
# Correct guess: 123457, for candidate: 12345, given max_len: 6
# Correct guess: 1234570, for candidate: 12345, given max_len: 7
# Correct guess: 1234522, for candidate: 12345, given max_len: 7
# Correct guess: 1234518, for candidate: 12345, given max_len: 7
# Correct guess: 1234571, for candidate: 12345, given max_len: 7
# Correct guess: 123456, for candidate: 123456, given max_len: 5
# Correct guess: 1234561, for candidate: 123456, given max_len: 7
# Correct guess: 1234564, for candidate: 123456, given max_len: 7
# Correct guess: 1234567, for candidate: 123456, given max_len: 7
# Correct guess: 1234568, for candidate: 123456, given max_len: 7
# Correct guess: 12345696, for candidate: 123456, given max_len: 8
# Correct guess: 12345688, for candidate: 123456, given max_len: 8
# Correct guess: 12345668, for candidate: 123456, given max_len: 8
# Correct guess: 12345679, for candidate: 1234567, given max_len: 8
# Correct guess: 12345678, for candidate: 1234567, given max_len: 8
# Correct guess: 12345671, for candidate: 1234567, given max_len: 8
# Correct guess: 12345672, for candidate: 1234567, given max_len: 8
# Correct guess: 12345670, for candidate: 1234567, given max_len: 8
# Correct guess: 123456781, for candidate: 1234567, given max_len: 9
# Correct guess: 12367, for candidate: 123, given max_len: 5
# Correct guess: 12358, for candidate: 123, given max_len: 5
# Correct guess: 12320, for candidate: 123, given max_len: 5
# Correct guess: 12326, for candidate: 123, given max_len: 5
# Correct guess: 12372, for candidate: 123, given max_len: 5
# Correct guess: 123252, for candidate: 123, given max_len: 6
# Correct guess: 123523, for candidate: 123, given max_len: 6
# Correct guess: 12378, for candidate: 123, given max_len: 5
# Correct guess: 12319, for candidate: 123, given max_len: 5
# Correct guess: 12330, for candidate: 123, given max_len: 5
# Correct guess: 12337, for candidate: 123, given max_len: 5
# Correct guess: 123921, for candidate: 123, given max_len: 6
# Correct guess: 123144, for candidate: 123, given max_len: 6
# Correct guess: 123779, for candidate: 123, given max_len: 6
# Correct guess: 123660, for candidate: 123, given max_len: 6
# Correct guess: 123458, for candidate: 1234, given max_len: 6
# Correct guess: 123404, for candidate: 1234, given max_len: 6
# Correct guess: 123414, for candidate: 1234, given max_len: 6
# Correct guess: 123489, for candidate: 1234, given max_len: 6
# Correct guess: 123459, for candidate: 12345, given max_len: 6
# Correct guess: 12345g, for candidate: 12345, given max_len: 6
# Correct guess: 1234527, for candidate: 12345, given max_len: 7
# Correct guess: 1234587, for candidate: 12345, given max_len: 7
# Correct guess: 1234524, for candidate: 12345, given max_len: 7
# Correct guess: pasar, for candidate: pas, given max_len: 5
# Correct guess: pasre, for candidate: pas, given max_len: 5
# Correct guess: passo, for candidate: pass, given max_len: 5
# Correct guess: passc, for candidate: pass, given max_len: 5
# Correct guess: passu, for candidate: pass, given max_len: 5
# Correct guess: passa, for candidate: pass, given max_len: 5
# Correct guess: passes, for candidate: pass, given max_len: 6
# Correct guess: passon, for candidate: pass, given max_len: 6
# Correct guess: passw, for candidate: passw, given max_len: 5
# Correct guess: passwd, for candidate: passw, given max_len: 6
# Correct guess: passwr, for candidate: passw, given max_len: 6
# Correct guess: passwa, for candidate: passw, given max_len: 6
# Correct guess: passw1r, for candidate: passw, given max_len: 7
# Correct guess: passwo, for candidate: passwo, given max_len: 5
# Correct guess: passwor, for candidate: passwo, given max_len: 7
# Correct guess: passwoo, for candidate: passwo, given max_len: 7
# Correct guess: passwo1, for candidate: passwo, given max_len: 7
# Correct guess: passwor7, for candidate: passwo, given max_len: 8
# Correct guess: 12397, for candidate: 123, given max_len: 5
# Correct guess: 12371, for candidate: 123, given max_len: 5
# Correct guess: 12310, for candidate: 123, given max_len: 5
# Correct guess: 12398, for candidate: 123, given max_len: 5
# Correct guess: 123611, for candidate: 123, given max_len: 6
# Correct guess: 123542, for candidate: 123, given max_len: 6
# Correct guess: 123190, for candidate: 123, given max_len: 6
# Correct guess: 123547, for candidate: 123, given max_len: 6
# Correct guess: 123431, for candidate: 123, given max_len: 6
# Correct guess: 1231052, for candidate: 123, given max_len: 7
# Correct guess: 12341, for candidate: 1234, given max_len: 5
# Correct guess: 123498, for candidate: 1234, given max_len: 6
# Correct guess: 123477, for candidate: 1234, given max_len: 6
# Correct guess: 1234500, for candidate: 12345, given max_len: 7
# Correct guess: 123456h, for candidate: 12345, given max_len: 7
# Correct guess: 1234515, for candidate: 12345, given max_len: 7
# Correct guess: 1234566, for candidate: 123456, given max_len: 7
# Correct guess: 1234563, for candidate: 123456, given max_len: 7
# Correct guess: 1234562, for candidate: 123456, given max_len: 7
# Correct guess: 12345623, for candidate: 123456, given max_len: 8
# Correct guess: 12345631, for candidate: 123456, given max_len: 8
# Correct guess: 12345611, for candidate: 123456, given max_len: 8
# Correct guess: 12369, for candidate: 123, given max_len: 5
# Correct guess: 12352, for candidate: 123, given max_len: 5
# Correct guess: 12300, for candidate: 123, given max_len: 5
# Correct guess: 12333, for candidate: 123, given max_len: 5
# Correct guess: 12390, for candidate: 123, given max_len: 5
# Correct guess: 123200, for candidate: 123, given max_len: 6
# Correct guess: 123109, for candidate: 123, given max_len: 6
# Correct guess: 123340, for candidate: 123, given max_len: 6
# Correct guess: 123176, for candidate: 123, given max_len: 6
# Correct guess: 1236226, for candidate: 123, given max_len: 7
# At guess 1000 of 1000000
# Correct guess: 123484, for candidate: 1234, given max_len: 6
# Correct guess: 123441, for candidate: 1234, given max_len: 6
# Correct guess: 123455, for candidate: 1234, given max_len: 6
# Correct guess: 123464, for candidate: 1234, given max_len: 6
# Correct guess: 1234208, for candidate: 1234, given max_len: 7
# Correct guess: 123452, for candidate: 12345, given max_len: 6
# Correct guess: 123450, for candidate: 12345, given max_len: 6
# Correct guess: 1234532, for candidate: 12345, given max_len: 7
# Correct guess: 1234553, for candidate: 12345, given max_len: 7
# Correct guess: 12345136, for candidate: 12345, given max_len: 8
# Correct guess: 1234560, for candidate: 123456, given max_len: 7
# Correct guess: 12345661, for candidate: 123456, given max_len: 8
# Correct guess: 12345632, for candidate: 123456, given max_len: 8
# Correct guess: 12345690, for candidate: 123456, given max_len: 8
# Correct guess: 12345676, for candidate: 1234567, given max_len: 8
# Correct guess: 12345673, for candidate: 1234567, given max_len: 8
# Correct guess: 12345677654, for candidate: 1234567, given max_len: 11
# Correct guess: 123456780, for candidate: 12345678, given max_len: 9
# Correct guess: 123456789, for candidate: 12345678, given max_len: 9
# Correct guess: 123456782, for candidate: 12345678, given max_len: 9
# Correct guess: 1234567899, for candidate: 12345678, given max_len: 10
# Correct guess: 1234567800, for candidate: 12345678, given max_len: 10
# Correct guess: ilove, for candidate: ilov, given max_len: 5
# Correct guess: ilovma, for candidate: ilov, given max_len: 6
# Correct guess: ilovef, for candidate: ilove, given max_len: 6
# Correct guess: iloves, for candidate: ilove, given max_len: 6
# Correct guess: ilovet, for candidate: ilove, given max_len: 6
# Correct guess: ilovee, for candidate: ilove, given max_len: 6
# Correct guess: ilovea, for candidate: ilove, given max_len: 6
# Correct guess: ilovetl, for candidate: ilove, given max_len: 7
# Correct guess: iloveat, for candidate: ilove, given max_len: 7
# Correct guess: iloveear, for candidate: ilove, given max_len: 8
# Correct guess: iloveani, for candidate: ilove, given max_len: 8
# Correct guess: ilovey, for candidate: ilovey, given max_len: 5
# Correct guess: iloveye, for candidate: ilovey, given max_len: 7
# Correct guess: iloveya, for candidate: ilovey, given max_len: 7
# Correct guess: 11122, for candidate: 111, given max_len: 5
# Correct guess: 11189, for candidate: 111, given max_len: 5
# Correct guess: 11159, for candidate: 111, given max_len: 5
# Correct guess: 11155, for candidate: 111, given max_len: 5
# Correct guess: 11115, for candidate: 111, given max_len: 5
# Correct guess: 111022, for candidate: 111, given max_len: 6
# Correct guess: 111969, for candidate: 111, given max_len: 6
# Correct guess: 11110, for candidate: 1111, given max_len: 5
# Correct guess: 11111, for candidate: 1111, given max_len: 5
# Correct guess: 11112, for candidate: 1111, given max_len: 5
# Correct guess: 111101, for candidate: 1111, given max_len: 6
# Correct guess: 111126, for candidate: 1111, given max_len: 6
# Correct guess: 111197, for candidate: 1111, given max_len: 6
# Correct guess: 111182, for candidate: 1111, given max_len: 6
# Correct guess: 111141, for candidate: 1111, given max_len: 6
# Correct guess: qwers, for candidate: qwe, given max_len: 5
# Correct guess: qwern, for candidate: qwer, given max_len: 5
# Correct guess: qwere, for candidate: qwer, given max_len: 5
# Correct guess: qwera, for candidate: qwer, given max_len: 5
# Correct guess: qwerst, for candidate: qwer, given max_len: 6
# Correct guess: mylea, for candidate: myl, given max_len: 5
# Correct guess: mylal, for candidate: myl, given max_len: 5
# Correct guess: mylor, for candidate: mylo, given max_len: 5
# Correct guess: myloe, for candidate: mylo, given max_len: 5
# Correct guess: myloo, for candidate: mylo, given max_len: 5
# Correct guess: 00039, for candidate: 000, given max_len: 5
# Correct guess: 00035, for candidate: 000, given max_len: 5
# Correct guess: 00008, for candidate: 000, given max_len: 5
# Correct guess: 00028, for candidate: 000, given max_len: 5
# Correct guess: 00002, for candidate: 0000, given max_len: 5
# Correct guess: 00009, for candidate: 0000, given max_len: 5
# Correct guess: 00003, for candidate: 0000, given max_len: 5
# Correct guess: 00004, for candidate: 0000, given max_len: 5
# Correct guess: 00001, for candidate: 0000, given max_len: 5
# Correct guess: 000085, for candidate: 0000, given max_len: 6
# Correct guess: 000022, for candidate: 0000, given max_len: 6
# Correct guess: 000000, for candidate: 0000, given max_len: 6
# Correct guess: 0000224, for candidate: 0000, given max_len: 7
# Correct guess: 0000022, for candidate: 0000, given max_len: 7
# Correct guess: 00000ra, for candidate: 0000, given max_len: 7
# Correct guess: 0000221, for candidate: 0000, given max_len: 7
# Correct guess: 000000006, for candidate: 0000, given max_len: 9
# Correct guess: 12327, for candidate: 123, given max_len: 5
# Correct guess: 12318, for candidate: 123, given max_len: 5
# Correct guess: 12361, for candidate: 123, given max_len: 5
# Correct guess: 123156, for candidate: 123, given max_len: 6
# Correct guess: 123506, for candidate: 123, given max_len: 6
# Correct guess: 1235762, for candidate: 123, given max_len: 7
# Correct guess: 12311, for candidate: 1231, given max_len: 5
# Correct guess: 12313, for candidate: 1231, given max_len: 5
# Correct guess: 123125, for candidate: 1231, given max_len: 6
# Correct guess: 123161, for candidate: 1231, given max_len: 6
# Correct guess: 1231555, for candidate: 1231, given max_len: 7
# Correct guess: lovng, for candidate: lov, given max_len: 5
# At guess 2000 of 1000000
# Correct guess: lovei, for candidate: love, given max_len: 5
# Correct guess: lovep, for candidate: love, given max_len: 5
# Correct guess: lovee, for candidate: love, given max_len: 5
# Correct guess: lovers, for candidate: love, given max_len: 6
# Correct guess: loveg1, for candidate: love, given max_len: 6
# Correct guess: loverat, for candidate: love, given max_len: 7
# Correct guess: matae, for candidate: mat, given max_len: 5
# Correct guess: matab, for candidate: mat, given max_len: 5
# Correct guess: notel, for candidate: not, given max_len: 5
# Correct guess: nothi, for candidate: noth, given max_len: 5
# Correct guess: nothin, for candidate: nothi, given max_len: 6
# Correct guess: pusko, for candidate: pus, given max_len: 5
# Correct guess: pusin, for candidate: pus, given max_len: 5
# Correct guess: foona, for candidate: foo, given max_len: 5
# Correct guess: footn, for candidate: foot, given max_len: 5
# Correct guess: foota, for candidate: foot, given max_len: 5
# Correct guess: foot2, for candidate: foot, given max_len: 5
# Correct guess: footb, for candidate: footb, given max_len: 5
# Correct guess: footbo, for candidate: footb, given max_len: 6
# Correct guess: footba, for candidate: footb, given max_len: 6
# Correct guess: footba6, for candidate: footba, given max_len: 7
# Correct guess: footbase, for candidate: footba, given max_len: 8
# Correct guess: 65457, for candidate: 654, given max_len: 5
# Correct guess: 65494, for candidate: 654, given max_len: 5
# Correct guess: 65410, for candidate: 654, given max_len: 5
# Correct guess: 65493, for candidate: 654, given max_len: 5
# Correct guess: 65459, for candidate: 654, given max_len: 5
# Correct guess: 654125, for candidate: 654, given max_len: 6
# Correct guess: 654909, for candidate: 654, given max_len: 6
# Correct guess: 65435, for candidate: 6543, given max_len: 5
# Correct guess: 65432, for candidate: 6543, given max_len: 5
# Correct guess: 65439, for candidate: 6543, given max_len: 5
# Correct guess: 65436, for candidate: 6543, given max_len: 5
# Correct guess: 654367, for candidate: 6543, given max_len: 6
# Correct guess: hellh, for candidate: hel, given max_len: 5
# Correct guess: helli, for candidate: hel, given max_len: 5
# Correct guess: helea, for candidate: hel, given max_len: 5
# Correct guess: motee, for candidate: mot, given max_len: 5
# Correct guess: moto1, for candidate: mot, given max_len: 5
# Correct guess: mota0, for candidate: mot, given max_len: 5
# Correct guess: moths, for candidate: moth, given max_len: 5
# Correct guess: mothd, for candidate: moth, given max_len: 5
# Correct guess: motho0, for candidate: moth, given max_len: 6
# Correct guess: abc12, for candidate: abc1, given max_len: 5
# Correct guess: lovss, for candidate: lov, given max_len: 5
# Correct guess: lovmo, for candidate: lov, given max_len: 5
# Correct guess: lovit, for candidate: lov, given max_len: 5
# Correct guess: lovie2, for candidate: lov, given max_len: 6
# Correct guess: lovek, for candidate: love, given max_len: 5
# Correct guess: lovea, for candidate: love, given max_len: 5
# Correct guess: loveo, for candidate: love, given max_len: 5
# Correct guess: loveth, for candidate: love, given max_len: 6
# Correct guess: loveit, for candidate: love, given max_len: 6
# Correct guess: lovelo, for candidate: love, given max_len: 6
# Correct guess: loveame, for candidate: love, given max_len: 7
# Correct guess: comep, for candidate: com, given max_len: 5
# Correct guess: comik, for candidate: com, given max_len: 5
# Correct guess: comso, for candidate: com, given max_len: 5
# At guess 3000 of 1000000
# Correct guess: compl, for candidate: comp, given max_len: 5
# Correct guess: compn, for candidate: comp, given max_len: 5
# Correct guess: compe, for candidate: comp, given max_len: 5
# Correct guess: comp1, for candidate: comp, given max_len: 5
# Correct guess: compo, for candidate: comp, given max_len: 5
# Correct guess: compu, for candidate: compu, given max_len: 5
# Correct guess: comput, for candidate: comput, given max_len: 5
# Correct guess: computn, for candidate: comput, given max_len: 7
# Correct guess: lonil, for candidate: lon, given max_len: 5
# Correct guess: lonle, for candidate: lon, given max_len: 5
# Correct guess: londi, for candidate: lond, given max_len: 5
# Correct guess: londa, for candidate: lond, given max_len: 5
# Correct guess: londo, for candidate: lond, given max_len: 5
# Correct guess: 12335, for candidate: 123, given max_len: 5
# Correct guess: 12317, for candidate: 123, given max_len: 5
# Correct guess: 12314, for candidate: 123, given max_len: 5
# Correct guess: 12389, for candidate: 123, given max_len: 5
# Correct guess: 123695, for candidate: 123, given max_len: 6
# Correct guess: 123099, for candidate: 123, given max_len: 6
# Correct guess: 1237525, for candidate: 123, given max_len: 7
# Correct guess: 1234521, for candidate: 123, given max_len: 7
# Correct guess: 12339, for candidate: 1233, given max_len: 5
# Correct guess: 123346, for candidate: 1233, given max_len: 6
# Correct guess: 123359, for candidate: 1233, given max_len: 6
# Correct guess: schae, for candidate: sch, given max_len: 5
# Correct guess: schaum, for candidate: sch, given max_len: 6
# Correct guess: schanel, for candidate: sch, given max_len: 7
# Correct guess: schoo, for candidate: scho, given max_len: 5
# Correct guess: schon, for candidate: scho, given max_len: 5
# Correct guess: schoor, for candidate: scho, given max_len: 6
# Correct guess: oneai, for candidate: one, given max_len: 5
# Correct guess: oneik, for candidate: one, given max_len: 5
# Correct guess: oneid, for candidate: one, given max_len: 5
# Correct guess: one32, for candidate: one, given max_len: 5
# Correct guess: onel3, for candidate: onel, given max_len: 5
# Correct guess: onelo, for candidate: onelo, given max_len: 5
# Correct guess: onelos, for candidate: onelo, given max_len: 6
# Correct guess: 66694, for candidate: 666, given max_len: 5
# Correct guess: 66665, for candidate: 666, given max_len: 5
# Correct guess: 66699, for candidate: 666, given max_len: 5
# Correct guess: 66612, for candidate: 666, given max_len: 5
# Correct guess: 66669, for candidate: 666, given max_len: 5
# Correct guess: 666602, for candidate: 666, given max_len: 6
# Correct guess: 66666, for candidate: 6666, given max_len: 5
# Correct guess: 66662, for candidate: 6666, given max_len: 5
# Correct guess: livei, for candidate: live, given max_len: 5
# Correct guess: live4, for candidate: live, given max_len: 5
# Correct guess: live2, for candidate: live, given max_len: 5
# Correct guess: liveo, for candidate: live, given max_len: 5
# Correct guess: liveka, for candidate: live, given max_len: 6
# Correct guess: live00, for candidate: live, given max_len: 6
# Correct guess: liver, for candidate: liver, given max_len: 5
# Correct guess: livern, for candidate: liver, given max_len: 6
# Correct guess: livere, for candidate: liver, given max_len: 6
# Correct guess: livero, for candidate: liver, given max_len: 6
# Correct guess: liverna, for candidate: liver, given max_len: 7
# Correct guess: liverp, for candidate: liverp, given max_len: 5
# Correct guess: liverp9, for candidate: liverp, given max_len: 7
# Correct guess: liverp2, for candidate: liverp, given max_len: 7
# Correct guess: liverpo, for candidate: liverpo, given max_len: 5
# Correct guess: liverpou, for candidate: liverpo, given max_len: 8
# Correct guess: liverpoi, for candidate: liverpo, given max_len: 8
# Correct guess: fucti, for candidate: fuc, given max_len: 5
# At guess 4000 of 1000000
# Correct guess: fucki, for candidate: fuck, given max_len: 5
# Correct guess: fucke, for candidate: fuck, given max_len: 5
# Correct guess: fucka, for candidate: fuck, given max_len: 5
# Correct guess: fucku, for candidate: fuck, given max_len: 5
# Correct guess: fuckna, for candidate: fuck, given max_len: 6
# Correct guess: fucknh, for candidate: fuck, given max_len: 6
# Correct guess: fucky, for candidate: fucky, given max_len: 5
# Correct guess: fuckyi, for candidate: fucky, given max_len: 6
# Correct guess: fuckyk, for candidate: fucky, given max_len: 6
# Correct guess: fuckya, for candidate: fucky, given max_len: 6
# Correct guess: fucky6, for candidate: fucky, given max_len: 6
# Correct guess: prom1, for candidate: pro, given max_len: 5
# Correct guess: promb, for candidate: prom, given max_len: 5
# Correct guess: prome, for candidate: prom, given max_len: 5
# Correct guess: promc, for candidate: prom, given max_len: 5
# Correct guess: proms, for candidate: prom, given max_len: 5
# Correct guess: promi, for candidate: prom, given max_len: 5
# Correct guess: promin, for candidate: promi, given max_len: 6
# Correct guess: promil, for candidate: promi, given max_len: 6
# Correct guess: lovan, for candidate: lov, given max_len: 5
# Correct guess: lovya, for candidate: lov, given max_len: 5
# Correct guess: lovel, for candidate: love, given max_len: 5
# Correct guess: lover, for candidate: love, given max_len: 5
# Correct guess: loveaa, for candidate: love, given max_len: 6
# Correct guess: lovesu, for candidate: love, given max_len: 6
# Correct guess: lovetay, for candidate: love, given max_len: 7
# Correct guess: fatha, for candidate: fat, given max_len: 5
# Correct guess: fatii, for candidate: fat, given max_len: 5
# Correct guess: fatno, for candidate: fat, given max_len: 5
# Correct guess: fatip, for candidate: fat, given max_len: 5
# Correct guess: fathr, for candidate: fath, given max_len: 5
# Correct guess: mica6, for candidate: mic, given max_len: 5
# Correct guess: micea, for candidate: mic, given max_len: 5
# Correct guess: mich5, for candidate: mich, given max_len: 5
# Correct guess: mich2, for candidate: mich, given max_len: 5
# Correct guess: micha, for candidate: mich, given max_len: 5
# Correct guess: mich4, for candidate: mich, given max_len: 5
# Correct guess: micham, for candidate: mich, given max_len: 6
# Correct guess: michna, for candidate: mich, given max_len: 6
# Correct guess: michee, for candidate: mich, given max_len: 6
# Correct guess: michau, for candidate: micha, given max_len: 6
# Correct guess: michae, for candidate: micha, given max_len: 6
# Correct guess: michat, for candidate: micha, given max_len: 6
# Correct guess: michaa, for candidate: micha, given max_len: 6
# Correct guess: monya, for candidate: mon, given max_len: 5
# Correct guess: monol, for candidate: mon, given max_len: 5
# Correct guess: monia1, for candidate: mon, given max_len: 6
# Correct guess: monaa3, for candidate: mon, given max_len: 6
# Correct guess: monaal, for candidate: mon, given max_len: 6
# Correct guess: mones, for candidate: mone, given max_len: 5
# Correct guess: monei, for candidate: mone, given max_len: 5
# Correct guess: moner, for candidate: mone, given max_len: 5
# Correct guess: basss, for candidate: bas, given max_len: 5
# Correct guess: basee, for candidate: base, given max_len: 5
# Correct guess: basel, for candidate: base, given max_len: 5
# Correct guess: base7, for candidate: base, given max_len: 5
# Correct guess: basetre, for candidate: base, given max_len: 7
# Correct guess: baseb, for candidate: baseb, given max_len: 5
# Correct guess: basebal, for candidate: baseb, given max_len: 7
# Correct guess: baseba, for candidate: baseba, given max_len: 5
# Correct guess: angl1, for candidate: ang, given max_len: 5
# Correct guess: angn3, for candidate: ang, given max_len: 5
# Correct guess: angho, for candidate: ang, given max_len: 5
# Correct guess: angean, for candidate: ang, given max_len: 6
# Correct guess: angee, for candidate: ange, given max_len: 5
# Correct guess: angec, for candidate: ange, given max_len: 5
# Correct guess: angeal, for candidate: ange, given max_len: 6
# At guess 5000 of 1000000
# Correct guess: haria, for candidate: har, given max_len: 5
# Correct guess: harma, for candidate: har, given max_len: 5
# Correct guess: harek, for candidate: har, given max_len: 5
# Correct guess: haroa, for candidate: har, given max_len: 5
# Correct guess: harls, for candidate: harl, given max_len: 5
# Correct guess: harlt, for candidate: harl, given max_len: 5
# Correct guess: harlea, for candidate: harl, given max_len: 6
# Correct guess: harlegr, for candidate: harl, given max_len: 7
# Correct guess: monab, for candidate: mon, given max_len: 5
# Correct guess: monde, for candidate: mon, given max_len: 5
# Correct guess: monono, for candidate: mon, given max_len: 6
# Correct guess: monoso, for candidate: mon, given max_len: 6
# Correct guess: monyk0, for candidate: mon, given max_len: 6
# Correct guess: monkr, for candidate: monk, given max_len: 5
# Correct guess: monkl, for candidate: monk, given max_len: 5
# Correct guess: monko, for candidate: monk, given max_len: 5
# Correct guess: monka, for candidate: monk, given max_len: 5
# Correct guess: monk7, for candidate: monk, given max_len: 5
# Correct guess: 98742, for candidate: 987, given max_len: 5
# Correct guess: 98715, for candidate: 987, given max_len: 5
# Correct guess: 98760, for candidate: 987, given max_len: 5
# Correct guess: 987536, for candidate: 987, given max_len: 6
# Correct guess: 9879871, for candidate: 987, given max_len: 7
# Correct guess: 98765, for candidate: 9876, given max_len: 5
# Correct guess: 98767, for candidate: 9876, given max_len: 5
# Correct guess: 987660, for candidate: 9876, given max_len: 6
# Correct guess: 987692, for candidate: 9876, given max_len: 6
# Correct guess: 987696, for candidate: 9876, given max_len: 6
# Correct guess: 987651, for candidate: 98765, given max_len: 6
# Correct guess: 987653, for candidate: 98765, given max_len: 6
# Correct guess: 987654, for candidate: 98765, given max_len: 6
# Correct guess: 987657, for candidate: 98765, given max_len: 6
# Correct guess: 9876512, for candidate: 98765, given max_len: 7
# Correct guess: 9876543, for candidate: 987654, given max_len: 7
# Correct guess: 98765478, for candidate: 987654, given max_len: 8
# Correct guess: 98765430, for candidate: 9876543, given max_len: 8
# Correct guess: 98765431, for candidate: 9876543, given max_len: 8
# Correct guess: 98765432, for candidate: 9876543, given max_len: 8
# Correct guess: 69626, for candidate: 696, given max_len: 5
# Correct guess: 69610, for candidate: 696, given max_len: 5
# Correct guess: 69664, for candidate: 696, given max_len: 5
# Correct guess: 69635, for candidate: 696, given max_len: 5
# Correct guess: 696972, for candidate: 696, given max_len: 6
# Correct guess: 69691, for candidate: 6969, given max_len: 5
# Correct guess: 69694, for candidate: 6969, given max_len: 5
# Correct guess: 69699, for candidate: 6969, given max_len: 5
# Correct guess: 696992, for candidate: 6969, given max_len: 6
# Correct guess: 696900, for candidate: 6969, given max_len: 6
# Correct guess: 6969012, for candidate: 6969, given max_len: 7
# Correct guess: fucli, for candidate: fuc, given max_len: 5
# Correct guess: fucda, for candidate: fuc, given max_len: 5
# Correct guess: fuckn, for candidate: fuck, given max_len: 5
# Correct guess: fuckh, for candidate: fuck, given max_len: 5
# Correct guess: fucks, for candidate: fuck, given max_len: 5
# Correct guess: fuck0, for candidate: fuck, given max_len: 5
# Correct guess: fuckwi, for candidate: fuck, given max_len: 6
# Correct guess: fuckjo, for candidate: fuck, given max_len: 6
# Correct guess: fuckana, for candidate: fuck, given max_len: 7
# Correct guess: andle, for candidate: and, given max_len: 5
# Correct guess: andpa, for candidate: and, given max_len: 5
# Correct guess: andea, for candidate: and, given max_len: 5
# Correct guess: andom, for candidate: and, given max_len: 5
# Correct guess: andrt, for candidate: andr, given max_len: 5
# Correct guess: andri, for candidate: andr, given max_len: 5
# Correct guess: andra, for candidate: andr, given max_len: 5
# Correct guess: andre, for candidate: andr, given max_len: 5
# Correct guess: andrea6, for candidate: andr, given max_len: 7
# Correct guess: zxcvf, for candidate: zxcv, given max_len: 5
# Correct guess: zxcv6, for candidate: zxcv, given max_len: 5
# Correct guess: zxcvb, for candidate: zxcvb, given max_len: 5
# Correct guess: zxcvb1, for candidate: zxcvb, given max_len: 6
# Correct guess: zxcvbn1, for candidate: zxcvb, given max_len: 7
# Correct guess: monta, for candidate: mon, given max_len: 5
# Correct guess: monlo, for candidate: mon, given max_len: 5
# Correct guess: monku, for candidate: mon, given max_len: 5
# Correct guess: mona14, for candidate: mon, given max_len: 6
# Correct guess: monako, for candidate: mon, given max_len: 6
# Correct guess: lovat, for candidate: lov, given max_len: 5
# Correct guess: lovya3, for candidate: lov, given max_len: 6
# At guess 6000 of 1000000
# Correct guess: qwert, for candidate: qwer, given max_len: 5
# Correct guess: qwert1, for candidate: qwert, given max_len: 6
# Correct guess: qwert0, for candidate: qwert, given max_len: 6
# Correct guess: qwert5, for candidate: qwert, given max_len: 6
# Correct guess: qwerti, for candidate: qwert, given max_len: 6
# Correct guess: qwertr, for candidate: qwert, given max_len: 6
# Correct guess: qwerty, for candidate: qwerty, given max_len: 5
# Correct guess: qwertyo, for candidate: qwerty, given max_len: 7
# Correct guess: qwertyy, for candidate: qwerty, given max_len: 7
# Correct guess: qwertyv, for candidate: qwerty, given max_len: 7
# Correct guess: qwertyr, for candidate: qwerty, given max_len: 7
# Correct guess: qwertyt, for candidate: qwerty, given max_len: 7
# Correct guess: qwerty89, for candidate: qwerty, given max_len: 8
# Correct guess: qwertyue, for candidate: qwerty, given max_len: 8
# Correct guess: qwertyu, for candidate: qwertyu, given max_len: 5
# Correct guess: qwertyu0, for candidate: qwertyu, given max_len: 8
# Correct guess: qwertyun, for candidate: qwertyu, given max_len: 8
# Correct guess: qwertyu5, for candidate: qwertyu, given max_len: 8
# Correct guess: qwertyui, for candidate: qwertyui, given max_len: 5
# Correct guess: qwertyui1, for candidate: qwertyui, given max_len: 9
# Correct guess: qwertyuii, for candidate: qwertyui, given max_len: 9
# Correct guess: qwertyui0, for candidate: qwertyui, given max_len: 9
# Correct guess: welee, for candidate: wel, given max_len: 5
# Correct guess: welca, for candidate: welc, given max_len: 5
# Correct guess: welcu, for candidate: welc, given max_len: 5
# Correct guess: welco, for candidate: welco, given max_len: 5
# Correct guess: welcoo, for candidate: welco, given max_len: 6
# Correct guess: prina, for candidate: prin, given max_len: 5
# Correct guess: prins, for candidate: prin, given max_len: 5
# Correct guess: prin9, for candidate: prin, given max_len: 5
# Correct guess: prinslo, for candidate: prin, given max_len: 7
# Correct guess: princ, for candidate: princ, given max_len: 5
# Correct guess: princs, for candidate: princ, given max_len: 6
# Correct guess: princa, for candidate: princ, given max_len: 6
# Correct guess: princ1, for candidate: princ, given max_len: 6
# Correct guess: princ2, for candidate: princ, given max_len: 6
# Correct guess: prince, for candidate: prince, given max_len: 5
# Correct guess: princem, for candidate: prince, given max_len: 7
# Correct guess: princea, for candidate: prince, given max_len: 7
# Correct guess: prince8, for candidate: prince, given max_len: 7
# Correct guess: princet, for candidate: prince, given max_len: 7
# Correct guess: princez, for candidate: prince, given max_len: 7
# Correct guess: princema, for candidate: prince, given max_len: 8
# Correct guess: princere, for candidate: prince, given max_len: 8
# Correct guess: paso1, for candidate: pas, given max_len: 5
# Correct guess: pasro, for candidate: pas, given max_len: 5
# Correct guess: pass4, for candidate: pass, given max_len: 5
# Correct guess: passt, for candidate: pass, given max_len: 5
# Correct guess: passi, for candidate: pass, given max_len: 5
# Correct guess: passwo4, for candidate: passwo, given max_len: 7
# Correct guess: passwoe, for candidate: passwo, given max_len: 7
# Correct guess: passwoi, for candidate: passwo, given max_len: 7
# Correct guess: passworr, for candidate: passwor, given max_len: 8
# Correct guess: passwor2, for candidate: passwor, given max_len: 8
# Correct guess: passworm, for candidate: passwor, given max_len: 8
# Correct guess: passwordko, for candidate: passwor, given max_len: 10
# Correct guess: shan0, for candidate: sha, given max_len: 5
# Correct guess: shaan, for candidate: sha, given max_len: 5
# Correct guess: shaye, for candidate: sha, given max_len: 5
# Correct guess: shaia, for candidate: sha, given max_len: 5
# Correct guess: shanb3, for candidate: sha, given max_len: 6
# Correct guess: shadi, for candidate: shad, given max_len: 5
# Correct guess: shads, for candidate: shad, given max_len: 5
# Correct guess: shady, for candidate: shad, given max_len: 5
# Correct guess: shada, for candidate: shad, given max_len: 5
# Correct guess: shado0, for candidate: shad, given max_len: 6
# Correct guess: shadlan, for candidate: shad, given max_len: 7
# At guess 7000 of 1000000
# Correct guess: sunee, for candidate: sun, given max_len: 5
# Correct guess: sunny, for candidate: sun, given max_len: 5
# Correct guess: sunsee, for candidate: sun, given max_len: 6
# Correct guess: sundae, for candidate: sun, given max_len: 6
# Correct guess: sunsi, for candidate: suns, given max_len: 5
# Correct guess: sunsh, for candidate: sunsh, given max_len: 5
# Correct guess: sunshn, for candidate: sunsh, given max_len: 6
# Correct guess: sunshi, for candidate: sunshi, given max_len: 5
# Correct guess: sunshim, for candidate: sunshi, given max_len: 7
# Correct guess: drage, for candidate: drag, given max_len: 5
# Correct guess: draga, for candidate: drag, given max_len: 5
# Correct guess: dragn, for candidate: drag, given max_len: 5
# Correct guess: drags8, for candidate: drag, given max_len: 6
# Correct guess: dragur, for candidate: drag, given max_len: 6
# Correct guess: 77721, for candidate: 777, given max_len: 5
# Correct guess: 77715, for candidate: 777, given max_len: 5
# Correct guess: 77740, for candidate: 777, given max_len: 5
# Correct guess: 77786, for candidate: 777, given max_len: 5
# Correct guess: 777012, for candidate: 777, given max_len: 6
# Correct guess: 777219, for candidate: 777, given max_len: 6
# Correct guess: 7777222, for candidate: 777, given max_len: 7
# Correct guess: 77779, for candidate: 7777, given max_len: 5
# Correct guess: 77776, for candidate: 7777, given max_len: 5
# Correct guess: 777791, for candidate: 7777, given max_len: 6
# Correct guess: 777766, for candidate: 7777, given max_len: 6
# Correct guess: 777770, for candidate: 7777, given max_len: 6
# Correct guess: 77777, for candidate: 77777, given max_len: 5
# Correct guess: 777779, for candidate: 77777, given max_len: 6
# Correct guess: 777773, for candidate: 77777, given max_len: 6
# Correct guess: 777777, for candidate: 77777, given max_len: 6
# Correct guess: 7777775, for candidate: 77777, given max_len: 7
# Correct guess: 7777788, for candidate: 77777, given max_len: 7
# Correct guess: ilovs, for candidate: ilov, given max_len: 5
# Correct guess: ilovi, for candidate: ilov, given max_len: 5
# Correct guess: iloveo, for candidate: ilov, given max_len: 6
# Correct guess: ilovmo, for candidate: ilov, given max_len: 6
# Correct guess: ilovew, for candidate: ilov, given max_len: 6
# Correct guess: loveu, for candidate: love, given max_len: 5
# Correct guess: lovet, for candidate: love, given max_len: 5
# Correct guess: loves, for candidate: love, given max_len: 5
# Correct guess: loven, for candidate: love, given max_len: 5
# Correct guess: lovena, for candidate: love, given max_len: 6
# Correct guess: lovee0, for candidate: love, given max_len: 6
# Correct guess: loveagn, for candidate: love, given max_len: 7
# Correct guess: love871, for candidate: love, given max_len: 7
# Correct guess: love1, for candidate: love1, given max_len: 5
# Correct guess: love17, for candidate: love1, given max_len: 6
# Correct guess: love12b, for candidate: love1, given max_len: 7
# Correct guess: 12131, for candidate: 121, given max_len: 5
# Correct guess: 12132, for candidate: 121, given max_len: 5
# Correct guess: 12160, for candidate: 121, given max_len: 5
# Correct guess: 12116, for candidate: 121, given max_len: 5
# Correct guess: 12146, for candidate: 121, given max_len: 5
# Correct guess: 121367, for candidate: 121, given max_len: 6
# Correct guess: 121257, for candidate: 121, given max_len: 6
# Correct guess: 1211627, for candidate: 121, given max_len: 7
# Correct guess: 12125, for candidate: 1212, given max_len: 5
# Correct guess: 12128, for candidate: 1212, given max_len: 5
# Correct guess: 12122, for candidate: 1212, given max_len: 5
# Correct guess: 12129, for candidate: 1212, given max_len: 5
# Correct guess: 12121, for candidate: 1212, given max_len: 5
# Correct guess: 121235, for candidate: 1212, given max_len: 6
# Correct guess: 121220, for candidate: 1212, given max_len: 6
# Correct guess: 121287, for candidate: 1212, given max_len: 6
# Correct guess: 121231, for candidate: 1212, given max_len: 6
# Correct guess: 1212439, for candidate: 1212, given max_len: 7
# Correct guess: 1212101, for candidate: 1212, given max_len: 7
# Correct guess: jorcu, for candidate: jor, given max_len: 5
# Correct guess: joris, for candidate: jor, given max_len: 5
# Correct guess: jorda, for candidate: jord, given max_len: 5
# Correct guess: jord1, for candidate: jord, given max_len: 5
# Correct guess: jorde, for candidate: jord, given max_len: 5
# Correct guess: super, for candidate: sup, given max_len: 5
# Correct guess: supal, for candidate: sup, given max_len: 5
# Correct guess: supam, for candidate: sup, given max_len: 5
# Correct guess: supea, for candidate: supe, given max_len: 5
# At guess 8000 of 1000000
# Correct guess: superi, for candidate: super, given max_len: 6
# Correct guess: super2, for candidate: super, given max_len: 6
# Correct guess: supert, for candidate: super, given max_len: 6
# Correct guess: supere, for candidate: super, given max_len: 6
# Correct guess: super21, for candidate: super, given max_len: 7
# Correct guess: superlarr, for candidate: super, given max_len: 9
# Correct guess: superm, for candidate: superm, given max_len: 5
# Correct guess: supermo, for candidate: superm, given max_len: 7
# Correct guess: superme, for candidate: superm, given max_len: 7
# Correct guess: supermot, for candidate: superm, given max_len: 8
# Correct guess: supermil, for candidate: superm, given max_len: 8
# Correct guess: asdfa, for candidate: asdf, given max_len: 5
# Correct guess: asdfn, for candidate: asdf, given max_len: 5
# Correct guess: asdfe, for candidate: asdf, given max_len: 5
# Correct guess: asdfh, for candidate: asdf, given max_len: 5
# Correct guess: asdfia, for candidate: asdf, given max_len: 6
# Correct guess: asdfg, for candidate: asdfg, given max_len: 5
# Correct guess: asdfg2, for candidate: asdfg, given max_len: 6
# Correct guess: asdfge, for candidate: asdfg, given max_len: 6
# Correct guess: asdfg09, for candidate: asdfg, given max_len: 7
# Correct guess: asdfgh, for candidate: asdfgh, given max_len: 5
# Correct guess: asdfgha, for candidate: asdfgh, given max_len: 7
# Correct guess: asdfghn, for candidate: asdfgh, given max_len: 7
# Correct guess: asdfgh7, for candidate: asdfgh, given max_len: 7
# Correct guess: asdfghj, for candidate: asdfghj, given max_len: 5
# Correct guess: asdfghj1, for candidate: asdfghj, given max_len: 8
# Correct guess: asdfghja, for candidate: asdfghj, given max_len: 8
# Correct guess: asdfghjl, for candidate: asdfghj, given max_len: 8
# Correct guess: asdfghj8, for candidate: asdfghj, given max_len: 8
# Correct guess: mushk, for candidate: mus, given max_len: 5
# Correct guess: musa1, for candidate: mus, given max_len: 5
# Correct guess: mushir, for candidate: mus, given max_len: 6
# Correct guess: musara, for candidate: mus, given max_len: 6
# Correct guess: must2, for candidate: must, given max_len: 5
# Correct guess: mustb, for candidate: must, given max_len: 5
# Correct guess: mustu, for candidate: must, given max_len: 5
# Correct guess: mustn, for candidate: must, given max_len: 5
# Correct guess: mustf, for candidate: must, given max_len: 5
# Correct guess: mustur, for candidate: must, given max_len: 6
# Correct guess: mustan, for candidate: must, given max_len: 6
# Correct guess: musta, for candidate: musta, given max_len: 5
# Correct guess: mustae, for candidate: musta, given max_len: 6
# Correct guess: bleda, for candidate: ble, given max_len: 5
# Correct guess: bles7, for candidate: bles, given max_len: 5
# Correct guess: bless, for candidate: bles, given max_len: 5
# Correct guess: blessu, for candidate: bless, given max_len: 6
# Correct guess: blessi, for candidate: bless, given max_len: 6
# Correct guess: blessa, for candidate: bless, given max_len: 6
# Correct guess: blesses, for candidate: bless, given max_len: 7
# Correct guess: blessi1, for candidate: blessi, given max_len: 7
# Correct guess: dantu, for candidate: dan, given max_len: 5
# Correct guess: danya0, for candidate: dan, given max_len: 6
# Correct guess: daniy, for candidate: dani, given max_len: 5
# Correct guess: danid, for candidate: dani, given max_len: 5
# Correct guess: danii, for candidate: dani, given max_len: 5
# Correct guess: danik, for candidate: dani, given max_len: 5
# Correct guess: dania, for candidate: dani, given max_len: 5
# Correct guess: dania2, for candidate: dani, given max_len: 6
# Correct guess: samia, for candidate: sam, given max_len: 5
# Correct guess: sam4t, for candidate: sam, given max_len: 5
# Correct guess: sama2, for candidate: sam, given max_len: 5
# Correct guess: samna, for candidate: sam, given max_len: 5
# Correct guess: sama12, for candidate: sam, given max_len: 6
# Correct guess: sammo1, for candidate: sam, given max_len: 6
# Correct guess: samu2, for candidate: samu, given max_len: 5
# Correct guess: samu1, for candidate: samu, given max_len: 5
# Correct guess: samue, for candidate: samu, given max_len: 5
# Correct guess: samula, for candidate: samu, given max_len: 6
# Correct guess: jesne, for candidate: jes, given max_len: 5
# Correct guess: jesa4, for candidate: jes, given max_len: 5
# Correct guess: jesla, for candidate: jes, given max_len: 5
# Correct guess: jessi, for candidate: jes, given max_len: 5
# Correct guess: jessa, for candidate: jess, given max_len: 5
# Correct guess: jessp, for candidate: jess, given max_len: 5
# Correct guess: jesse, for candidate: jess, given max_len: 5
# Correct guess: jessy, for candidate: jess, given max_len: 5
# Correct guess: jessl, for candidate: jess, given max_len: 5
# Correct guess: jessla, for candidate: jess, given max_len: 6
# Correct guess: jesssss, for candidate: jess, given max_len: 7
# At guess 9000 of 1000000
# Correct guess: jessia, for candidate: jessi, given max_len: 6
# Correct guess: jessiah, for candidate: jessi, given max_len: 7
# Correct guess: loonmt, for candidate: loo, given max_len: 6
# Correct guess: lookt, for candidate: look, given max_len: 5
# Correct guess: look1, for candidate: look, given max_len: 5
# Correct guess: looke, for candidate: look, given max_len: 5
# Correct guess: lookat, for candidate: look, given max_len: 6
# Correct guess: looki, for candidate: looki, given max_len: 5
# Correct guess: lookii, for candidate: looki, given max_len: 6
# Correct guess: assno, for candidate: ass, given max_len: 5
# Correct guess: assha, for candidate: ass, given max_len: 5
# Correct guess: asshe, for candidate: assh, given max_len: 5
# Correct guess: assho, for candidate: assho, given max_len: 5
# Correct guess: asshor, for candidate: assho, given max_len: 6
# Correct guess: buser, for candidate: bus, given max_len: 5
# Correct guess: busian, for candidate: bus, given max_len: 6
# Correct guess: busth, for candidate: bust, given max_len: 5
# Correct guess: bustl, for candidate: bust, given max_len: 5
# Correct guess: busta, for candidate: bust, given max_len: 5
# Correct guess: bust1, for candidate: bust, given max_len: 5
# Correct guess: bustr, for candidate: bust, given max_len: 5
# Correct guess: bustha, for candidate: bust, given max_len: 6
# Correct guess: hunie, for candidate: hun, given max_len: 5
# Correct guess: hunna, for candidate: hun, given max_len: 5
# Correct guess: hunyb2, for candidate: hun, given max_len: 6
# Correct guess: huntr, for candidate: hunt, given max_len: 5
# Correct guess: hunte, for candidate: hunt, given max_len: 5
# Correct guess: hunt1, for candidate: hunt, given max_len: 5
# Correct guess: hunth, for candidate: hunt, given max_len: 5
# Correct guess: hunt30, for candidate: hunt, given max_len: 6
# Correct guess: float5, for candidate: flo, given max_len: 6
# Correct guess: flowr, for candidate: flow, given max_len: 5
# Correct guess: flowa, for candidate: flow, given max_len: 5
# Correct guess: flowi, for candidate: flow, given max_len: 5
# Correct guess: flown, for candidate: flow, given max_len: 5
# Correct guess: lovym, for candidate: lov, given max_len: 5
# Correct guess: lovees, for candidate: lov, given max_len: 6
# Correct guess: love2, for candidate: love, given max_len: 5
# Correct guess: lovebr, for candidate: love, given max_len: 6
# Correct guess: loveat, for candidate: love, given max_len: 6
# Correct guess: loveji, for candidate: love, given max_len: 6
# Correct guess: loveno, for candidate: love, given max_len: 6
# Correct guess: lovey, for candidate: lovey, given max_len: 5
# Correct guess: lovey2, for candidate: lovey, given max_len: 6
# Correct guess: loveyy, for candidate: lovey, given max_len: 6
# Correct guess: loveyi, for candidate: lovey, given max_len: 6
# Correct guess: lovey0, for candidate: lovey, given max_len: 6
# Correct guess: loveyal, for candidate: lovey, given max_len: 7
# Correct guess: loveyhu, for candidate: lovey, given max_len: 7
# Correct guess: asdan, for candidate: asd, given max_len: 5
# Correct guess: asdr2, for candidate: asd, given max_len: 5
# Correct guess: asdf2, for candidate: asdf, given max_len: 5
# Correct guess: asdfm, for candidate: asdf, given max_len: 5
# Correct guess: asdfs, for candidate: asdf, given max_len: 5
# Correct guess: asdfo, for candidate: asdf, given max_len: 5
# Correct guess: kilma, for candidate: kil, given max_len: 5
# Correct guess: kille, for candidate: kil, given max_len: 5
# Correct guess: kilai, for candidate: kil, given max_len: 5
# Correct guess: killb, for candidate: kill, given max_len: 5
# Correct guess: kills, for candidate: kill, given max_len: 5
# Correct guess: killn, for candidate: kill, given max_len: 5
# Correct guess: kill9, for candidate: kill, given max_len: 5
# Correct guess: kill0, for candidate: kill, given max_len: 5
# At guess 10000 of 1000000
# Correct guess: arsin, for candidate: ars, given max_len: 5
# Correct guess: arse5, for candidate: arse, given max_len: 5
# Correct guess: arsen, for candidate: arsen, given max_len: 5
# Correct guess: arsena, for candidate: arsen, given max_len: 6
# Correct guess: arsenl, for candidate: arsen, given max_len: 6
# Correct guess: arsen3, for candidate: arsen, given max_len: 6
# Correct guess: arseni, for candidate: arsen, given max_len: 6
# Correct guess: 55550, for candidate: 555, given max_len: 5
# ...
# Correct guess: roben, for candidate: robe, given max_len: 5
# Correct guess: robeer, for candidate: robe, given max_len: 6
# Correct guess: goore, for candidate: goo, given max_len: 5
# Correct guess: goo2i, for candidate: goo, given max_len: 5
# Correct guess: goody, for candidate: good, given max_len: 5
# Correct guess: goodn, for candidate: good, given max_len: 5
# Correct guess: goodu, for candidate: good, given max_len: 5
# Correct guess: goodr, for candidate: good, given max_len: 5
# Correct guess: goode, for candidate: good, given max_len: 5
# Correct guess: goodea, for candidate: good, given max_len: 6
# Correct guess: goodl, for candidate: goodl, given max_len: 5
# Correct guess: goodle, for candidate: goodl, given max_len: 6
# Correct guess: goodleo, for candidate: goodl, given max_len: 7
# Correct guess: goodlu, for candidate: goodlu, given max_len: 5
# Correct guess: ricia, for candidate: ric, given max_len: 5
# Correct guess: ricle, for candidate: ric, given max_len: 5
# Correct guess: richh, for candidate: rich, given max_len: 5
# Correct guess: rich0, for candidate: rich, given max_len: 5
# Correct guess: richm, for candidate: rich, given max_len: 5
# Correct guess: richa, for candidate: rich, given max_len: 5
# Correct guess: rich2, for candidate: rich, given max_len: 5
# Correct guess: richar, for candidate: richa, given max_len: 6
# Correct guess: richan, for candidate: richa, given max_len: 6
# At guess 14000 of 1000000
# Correct guess: big1m, for candidate: big, given max_len: 5
# Correct guess: biger, for candidate: big, given max_len: 5
# Correct guess: bigya, for candidate: big, given max_len: 5
# Correct guess: bigbl, for candidate: bigb, given max_len: 5
# Correct guess: bigbn, for candidate: bigb, given max_len: 5
# Correct guess: bigby, for candidate: bigb, given max_len: 5
# Correct guess: bigba, for candidate: bigb, given max_len: 5
# Correct guess: bigb42, for candidate: bigb, given max_len: 6
# Correct guess: wilea, for candidate: wil, given max_len: 5
# Correct guess: willn, for candidate: will, given max_len: 5
# Correct guess: wills, for candidate: will, given max_len: 5
# Correct guess: willr, for candidate: will, given max_len: 5
# Correct guess: will0, for candidate: will, given max_len: 5
# Correct guess: will1, for candidate: will, given max_len: 5
# Correct guess: willra, for candidate: will, given max_len: 6
# Correct guess: willi, for candidate: willi, given max_len: 5
# Correct guess: willin, for candidate: willi, given max_len: 6
# Correct guess: willid, for candidate: willi, given max_len: 6
# Correct guess: willia, for candidate: willi, given max_len: 6
# Correct guess: williat, for candidate: willi, given max_len: 7
# Correct guess: willie9, for candidate: willi, given max_len: 7
# Correct guess: batea, for candidate: bat, given max_len: 5
# Correct guess: batuc, for candidate: bat, given max_len: 5
# Correct guess: batas, for candidate: bat, given max_len: 5
# Correct guess: batmn, for candidate: batm, given max_len: 5
# Correct guess: batmen, for candidate: batm, given max_len: 6
# Correct guess: batmik, for candidate: batm, given max_len: 6
# Correct guess: thosa, for candidate: tho, given max_len: 5
# Correct guess: thore0, for candidate: tho, given max_len: 6
# Correct guess: thomo, for candidate: thom, given max_len: 5
# Correct guess: thomu, for candidate: thom, given max_len: 5
# Correct guess: thom5, for candidate: thom, given max_len: 5
# Correct guess: thoms, for candidate: thom, given max_len: 5
# Correct guess: thomad, for candidate: thom, given max_len: 6
# Correct guess: thomme, for candidate: thom, given max_len: 6
# Correct guess: thom11, for candidate: thom, given max_len: 6
# Correct guess: geoke, for candidate: geo, given max_len: 5
# Correct guess: geoobi, for candidate: geo, given max_len: 6
# Correct guess: tigta, for candidate: tig, given max_len: 5
# Correct guess: tigtl, for candidate: tig, given max_len: 5
# Correct guess: tigg4, for candidate: tigg, given max_len: 5
# Correct guess: tiggo, for candidate: tigg, given max_len: 5
# Correct guess: tigg1, for candidate: tigg, given max_len: 5
# Correct guess: hamfan, for candidate: ham, given max_len: 6
# Correct guess: hamar6, for candidate: ham, given max_len: 6
# Correct guess: hamma, for candidate: hamm, given max_len: 5
# Correct guess: hammi, for candidate: hamm, given max_len: 5
# Correct guess: hammr, for candidate: hamm, given max_len: 5
# Correct guess: hamma2, for candidate: hamm, given max_len: 6
# Correct guess: wilhn, for candidate: wil, given max_len: 5
# Correct guess: wille, for candidate: will, given max_len: 5
# Correct guess: willy, for candidate: will, given max_len: 5
# Correct guess: willo, for candidate: will, given max_len: 5
# Correct guess: will9, for candidate: will, given max_len: 5
# Correct guess: willru, for candidate: will, given max_len: 6
# Correct guess: willaa, for candidate: will, given max_len: 6
# Correct guess: willis, for candidate: willi, given max_len: 6
# Correct guess: willia3, for candidate: willi, given max_len: 7
# Correct guess: williap, for candidate: willia, given max_len: 7
# Correct guess: william, for candidate: willia, given max_len: 7
# Correct guess: williar, for candidate: willia, given max_len: 7
# Correct guess: williami, for candidate: willia, given max_len: 8
# Correct guess: amala, for candidate: ama, given max_len: 5
# Correct guess: amaat, for candidate: ama, given max_len: 5
# At guess 15000 of 1000000
# Correct guess: amans, for candidate: aman, given max_len: 5
# Correct guess: amane, for candidate: aman, given max_len: 5
# Correct guess: amanl, for candidate: aman, given max_len: 5
# Correct guess: amana, for candidate: aman, given max_len: 5
# Correct guess: amano, for candidate: aman, given max_len: 5
# Correct guess: amand8, for candidate: aman, given max_len: 6
# Correct guess: amanue, for candidate: aman, given max_len: 6
# Correct guess: amanmo, for candidate: aman, given max_len: 6
# Correct guess: nicer, for candidate: nic, given max_len: 5
# Correct guess: nicne, for candidate: nic, given max_len: 5
# Correct guess: nicetr, for candidate: nic, given max_len: 6
# Correct guess: nicor, for candidate: nico, given max_len: 5
# Correct guess: nicos, for candidate: nico, given max_len: 5
# Correct guess: nicod, for candidate: nico, given max_len: 5
# Correct guess: nico1, for candidate: nico, given max_len: 5
# Correct guess: nicono, for candidate: nico, given max_len: 6
# Correct guess: olant, for candidate: ola, given max_len: 5
# Correct guess: olatot, for candidate: ola, given max_len: 6
# Correct guess: olame, for candidate: olam, given max_len: 5
# Correct guess: olama, for candidate: olam, given max_len: 5
# Correct guess: olami, for candidate: olami, given max_len: 5
# Correct guess: olamie, for candidate: olami, given max_len: 6
# Correct guess: olamin, for candidate: olami, given max_len: 6
# Correct guess: olamilo, for candidate: olami, given max_len: 7
# Correct guess: olamile, for candidate: olami, given max_len: 7
# Correct guess: jusum, for candidate: jus, given max_len: 5
# Correct guess: just5, for candidate: jus, given max_len: 5
# Correct guess: justp, for candidate: just, given max_len: 5
# Correct guess: just1, for candidate: just, given max_len: 5
# Correct guess: juste, for candidate: just, given max_len: 5
# Correct guess: justr, for candidate: just, given max_len: 5
# Correct guess: just7, for candidate: just, given max_len: 5
# Correct guess: juster, for candidate: just, given max_len: 6
# Correct guess: just21, for candidate: just, given max_len: 6
# Correct guess: josel, for candidate: jos, given max_len: 5
# Correct guess: josih1, for candidate: jos, given max_len: 6
# Correct guess: josea, for candidate: jose, given max_len: 5
# Correct guess: josei, for candidate: jose, given max_len: 5
# Correct guess: joseb, for candidate: jose, given max_len: 5
# Correct guess: jose1, for candidate: jose, given max_len: 5
# Correct guess: jose2, for candidate: jose, given max_len: 5
# Correct guess: josea8, for candidate: jose, given max_len: 6
# Correct guess: joserp, for candidate: jose, given max_len: 6
# Correct guess: matse, for candidate: mat, given max_len: 5
# Correct guess: matala, for candidate: mat, given max_len: 6
# Correct guess: matchpa, for candidate: mat, given max_len: 7
# Correct guess: mattr, for candidate: matt, given max_len: 5
# Correct guess: matti, for candidate: matt, given max_len: 5
# Correct guess: matta, for candidate: matt, given max_len: 5
# Correct guess: matt0, for candidate: matt, given max_len: 5
# Correct guess: mattu, for candidate: matt, given max_len: 5
# Correct guess: matti0, for candidate: matt, given max_len: 6
# Correct guess: matt11, for candidate: matt, given max_len: 6
# Correct guess: mattma, for candidate: matt, given max_len: 6
# Correct guess: mattjar, for candidate: matt, given max_len: 7
# Correct guess: mattins, for candidate: matt, given max_len: 7
# Correct guess: matth, for candidate: matth, given max_len: 5
# Correct guess: mattht, for candidate: matth, given max_len: 6
# Correct guess: mattho, for candidate: matth, given max_len: 6
# Correct guess: matthe, for candidate: matth, given max_len: 6
# Correct guess: hanle, for candidate: han, given max_len: 5
# Correct guess: hansm, for candidate: han, given max_len: 5
# Correct guess: hannu, for candidate: hann, given max_len: 5
# Correct guess: hanna, for candidate: hann, given max_len: 5
# Correct guess: hannt, for candidate: hann, given max_len: 5
# Correct guess: hannn, for candidate: hann, given max_len: 5
# Correct guess: brae2, for candidate: bra, given max_len: 5
# Correct guess: braet, for candidate: bra, given max_len: 5
# Correct guess: braea, for candidate: bra, given max_len: 5
# Correct guess: brass, for candidate: bra, given max_len: 5
# Correct guess: brashk, for candidate: bra, given max_len: 6
# Correct guess: brana, for candidate: bran, given max_len: 5
# Correct guess: bran2, for candidate: bran, given max_len: 5
# Correct guess: brano, for candidate: bran, given max_len: 5
# Correct guess: brann, for candidate: bran, given max_len: 5
# Correct guess: branto, for candidate: bran, given max_len: 6
# Correct guess: branlan, for candidate: bran, given max_len: 7
# Correct guess: brand, for candidate: brand, given max_len: 5
# Correct guess: brandh, for candidate: brand, given max_len: 6
# Correct guess: brands, for candidate: brand, given max_len: 6
# Correct guess: brand6, for candidate: brand, given max_len: 6
# Correct guess: brandk, for candidate: brand, given max_len: 6
# Correct guess: brando, for candidate: brand, given max_len: 6
# Correct guess: brandt6, for candidate: brand, given max_len: 7
# Correct guess: 55585, for candidate: 555, given max_len: 5
# Correct guess: 55551, for candidate: 555, given max_len: 5
# Correct guess: 55528, for candidate: 555, given max_len: 5
# Correct guess: 55522, for candidate: 555, given max_len: 5
# Correct guess: 555911, for candidate: 555, given max_len: 6
# Correct guess: 555223, for candidate: 555, given max_len: 6
# Correct guess: 555550, for candidate: 555, given max_len: 6
# Correct guess: cowad, for candidate: cow, given max_len: 5
# Correct guess: cowil, for candidate: cow, given max_len: 5
# Correct guess: cowpi, for candidate: cow, given max_len: 5
# At guess 16000 of 1000000
# Correct guess: cowbo, for candidate: cowb, given max_len: 5
# Correct guess: cowba, for candidate: cowb, given max_len: 5
# Correct guess: cowbog, for candidate: cowbo, given max_len: 6
# Correct guess: kisan, for candidate: kis, given max_len: 5
# Correct guess: kisas, for candidate: kis, given max_len: 5
# Correct guess: kisma, for candidate: kis, given max_len: 5
# Correct guess: kissr, for candidate: kiss, given max_len: 5
# Correct guess: kissd, for candidate: kiss, given max_len: 5
# Correct guess: kissh, for candidate: kiss, given max_len: 5
# Correct guess: kissa, for candidate: kiss, given max_len: 5
# Correct guess: kiss2, for candidate: kiss, given max_len: 5
# Correct guess: kissas, for candidate: kiss, given max_len: 6
# Correct guess: kissmei, for candidate: kiss, given max_len: 7
# Correct guess: miccr, for candidate: mic, given max_len: 5
# Correct guess: michn, for candidate: mich, given max_len: 5
# Correct guess: michj, for candidate: mich, given max_len: 5
# Correct guess: micht, for candidate: mich, given max_len: 5
# Correct guess: michei, for candidate: mich, given max_len: 6
# Correct guess: miche, for candidate: miche, given max_len: 5
# Correct guess: michea, for candidate: miche, given max_len: 6
# Correct guess: micher, for candidate: miche, given max_len: 6
# Correct guess: michef, for candidate: miche, given max_len: 6
# Correct guess: michett, for candidate: miche, given max_len: 7
# Correct guess: michel, for candidate: michel, given max_len: 5
# Correct guess: micheli, for candidate: michel, given max_len: 7
# Correct guess: michelo, for candidate: michel, given max_len: 7
# Correct guess: micheld, for candidate: michel, given max_len: 7
# Correct guess: michel1, for candidate: michel, given max_len: 7
# Correct guess: fish1, for candidate: fish, given max_len: 5
# Correct guess: fisho, for candidate: fish, given max_len: 5
# Correct guess: fishm, for candidate: fish, given max_len: 5
# Correct guess: fisha, for candidate: fish, given max_len: 5
# Correct guess: fish91, for candidate: fish, given max_len: 6
# Correct guess: fishi, for candidate: fishi, given max_len: 5
# Correct guess: fishin, for candidate: fishi, given max_len: 6
# Correct guess: fishin5, for candidate: fishi, given max_len: 7
# Correct guess: pepp3, for candidate: pepp, given max_len: 5
# Correct guess: peppp, for candidate: pepp, given max_len: 5
# Correct guess: pepp1, for candidate: pepp, given max_len: 5
# Correct guess: pepps1, for candidate: pepp, given max_len: 6
# Correct guess: peppyp, for candidate: pepp, given max_len: 6
# Correct guess: hocun, for candidate: hoc, given max_len: 5
# Correct guess: hocka, for candidate: hock, given max_len: 5
# Correct guess: hock1, for candidate: hock, given max_len: 5
# Correct guess: hockr, for candidate: hock, given max_len: 5
# Correct guess: hock2, for candidate: hock, given max_len: 5
# Correct guess: lovrno, for candidate: lov, given max_len: 6
# Correct guess: love9, for candidate: love, given max_len: 5
# Correct guess: love21, for candidate: love, given max_len: 6
# Correct guess: lovead, for candidate: love, given max_len: 6
# Correct guess: lovehi, for candidate: love, given max_len: 6
# Correct guess: lovely1, for candidate: love, given max_len: 7
# Correct guess: lovery, for candidate: lover, given max_len: 6
# Correct guess: loverd, for candidate: lover, given max_len: 6
# Correct guess: lover7, for candidate: lover, given max_len: 6
# Correct guess: lovern, for candidate: lover, given max_len: 6
# Correct guess: lovers7, for candidate: lover, given max_len: 7
# Correct guess: lovert1, for candidate: lover, given max_len: 7
# Correct guess: lover100, for candidate: lover, given max_len: 8
# Correct guess: loverb, for candidate: loverb, given max_len: 5
# Correct guess: loverbe, for candidate: loverb, given max_len: 7
# Correct guess: loverb0, for candidate: loverb, given max_len: 7
# Correct guess: chr0n, for candidate: chr, given max_len: 5
# Correct guess: chran, for candidate: chr, given max_len: 5
# At guess 17000 of 1000000
# Correct guess: chrit, for candidate: chri, given max_len: 5
# Correct guess: chrik, for candidate: chri, given max_len: 5
# Correct guess: chriss, for candidate: chri, given max_len: 6
# Correct guess: chris1s, for candidate: chri, given max_len: 7
# Correct guess: chan0, for candidate: cha, given max_len: 5
# Correct guess: chaon, for candidate: cha, given max_len: 5
# Correct guess: chakr, for candidate: cha, given max_len: 5
# Correct guess: charr, for candidate: char, given max_len: 5
# Correct guess: chary, for candidate: char, given max_len: 5
# Correct guess: charmn, for candidate: char, given max_len: 6
# Correct guess: charos, for candidate: char, given max_len: 6
# Correct guess: charl2, for candidate: charl, given max_len: 6
# Correct guess: charle1, for candidate: charl, given max_len: 7
# Correct guess: charli7, for candidate: charl, given max_len: 7
# Correct guess: baden, for candidate: bad, given max_len: 5
# Correct guess: badbr, for candidate: badb, given max_len: 5
# Correct guess: badbp, for candidate: badb, given max_len: 5

# %%
gru_model = torch.load('saved_gru_pwd.model')
MakePasswordGuesses(gru_model).evaluate_dataset('000webhost')
