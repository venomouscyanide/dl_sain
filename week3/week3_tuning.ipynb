# %% [markdown]
# <a href="https://colab.research.google.com/github/venomouscyanide/dl_sain/blob/master/week3/week3_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown==3.13.0
# Out:
# Collecting gdown==3.13.0
#   Downloading https://files.pythonhosted.org/packages/52/b9/d426f164f35bb50d512a77d6a7c5eb70b2bea3459dc10f73f130ba732810/gdown-3.13.0.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown==3.13.0) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown==3.13.0) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.12.0 in /usr/local/lib/python3.7/dist-packages (from gdown==3.13.0) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown==3.13.0) (3.0.12)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown==3.13.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown==3.13.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown==3.13.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown==3.13.0) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown==3.13.0) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.13.0-cp37-none-any.whl size=9046 sha256=c491804ff49821c78205fa5ec5cb544a3c6d8f6b4193864618cec7cc33032a82
#   Stored in directory: /root/.cache/pip/wheels/ba/fa/c5/12813d7496f34652c43a471e11a780e769889d06e34735c32e
# Successfully built gdown
# Installing collected packages: gdown
#   Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# Successfully installed gdown-3.13.0

# %% [markdown]
# ## All Imports

# %%
import gzip
import shutil
import copy
import random
from typing import Tuple, List, Union
import numpy as np
import struct

# third party
import gdown

# %% [markdown]
# ## Add Dataloader to get the validation/testing/training MNIST datasets

# %%
class MNISTDataLoader:
    # explanation of idx file formats: http://yann.lecun.com/exdb/mnist/
    # help wrt parsing data: https://stackoverflow.com/a/53181925

    TRAINING_DATA_URL: str = 'https://drive.google.com/uc?id=1pmI9wAdNtJkOvkJpdTqM9bmIAwPkGyMU'
    TRAINING_DATA_LABELS_URL: str = 'https://drive.google.com/uc?id=1R8BZL67U1N0GUGnf6AQIBZNVDCWO9QLS'
    TESTING_DATA_URL: str = 'https://drive.google.com/uc?id=10FdcUHw3BcQAU6keKaUwtDwJm4sC00Hu'
    TESTING_DATA_LABELS_URL: str = 'https://drive.google.com/uc?id=1GvsacEnI1eQ1vYZM-oYdERvaE2SPh0Lj'

    def load_data_wrapper(self):
        testing_data_tuple = self.load_data_as_ndarray(self.TESTING_DATA_URL, self.TESTING_DATA_LABELS_URL, False)
        training_data_tuple = self.load_data_as_ndarray(self.TRAINING_DATA_URL, self.TRAINING_DATA_LABELS_URL, True)
        return training_data_tuple, testing_data_tuple

    def load_data_wrapper_with_validation(self):
        testing_data_tuple = self.load_data_as_ndarray(self.TESTING_DATA_URL, self.TESTING_DATA_LABELS_URL, False)
        training_data_tuple = self.load_data_as_ndarray(self.TRAINING_DATA_URL, self.TRAINING_DATA_LABELS_URL, True)

        slice_threshold = len(training_data_tuple) - len(testing_data_tuple)
        training_data_tuple, validation_data_tuple = training_data_tuple[:slice_threshold], training_data_tuple[
                                                                                            slice_threshold:]
        self._convert_label_to_int(validation_data_tuple)
        return training_data_tuple, testing_data_tuple, validation_data_tuple

    def load_data_as_ndarray(self, data_file_url: str, data_labels_file_url: str, train: bool) -> List[
        Tuple[np.ndarray, Union[int, np.ndarray]]]:
        uncompressed_dataset = self._download_and_uncompressed_file(data_file_url)
        uncompressed_labels = self._download_and_uncompressed_file(data_labels_file_url)
        pixel_data = self._get_pixel_data(uncompressed_dataset)
        label_data = self._get_labels(uncompressed_labels)
        zipped_data = [
            (x.reshape(784, 1), self._one_hot_enc(y) if train else y[0]) for x, y in zip(pixel_data, label_data)
        ]
        return zipped_data

    def _one_hot_enc(self, y: np.ndarray):
        one_hot_vector = np.zeros((10, 1))
        one_hot_vector[y[0]][0] = 1
        return one_hot_vector

    def _download_and_uncompressed_file(self, url: str) -> str:
        downloaded_gzip = gdown.download(url)
        decompressed_data_file = self._write_decompressed_data(downloaded_gzip)
        return decompressed_data_file

    def _write_decompressed_data(self, downloaded_gzip: str) -> str:
        with gzip.open(downloaded_gzip, 'rb') as compressed:
            uncompressed_dataset = downloaded_gzip.replace('.gz', '')
            with open(uncompressed_dataset, 'wb') as decompressed:
                shutil.copyfileobj(compressed, decompressed)
        return uncompressed_dataset

    def _get_pixel_data(self, data_file: str) -> np.ndarray:
        with open(data_file, "rb") as dataset:
            _, num_data = struct.unpack(">II", dataset.read(8))
            num_rows, num_colums = struct.unpack(">II", dataset.read(8))
            pixel_data = np.fromfile(dataset, dtype=np.uint8) / 255
            pixel_data = pixel_data.reshape((num_data, num_rows * num_colums))
        return pixel_data

    def _get_labels(self, data_labels_file: str) -> Union[np.ndarray, int]:
        with open(data_labels_file, "rb") as labels:
            _, num_data = struct.unpack(">II", labels.read(8))
            label_data = np.fromfile(labels, dtype=np.uint8)
            label_data = label_data.reshape((num_data, -1))
        return label_data

    def _convert_label_to_int(self, validation_data_tuple: List[Tuple[np.ndarray, np.ndarray]]):
        for index, (inp, label) in enumerate(validation_data_tuple):
            validation_data_tuple[index] = (inp, label.argmax())

# %% [markdown]
# ## Add network utility functions

# %%
class NetworkUtils:
    # Replace sigmoid with relu for hidden and softmax for output layer
    @staticmethod
    def relu(z: np.ndarray) -> np.ndarray:
        return np.maximum(z, 0.0)

    @staticmethod
    def relu_prime(z: np.ndarray) -> np.ndarray:
        return (z > 0.0) * 1

    @staticmethod
    def softmax(z):
        exp_z = np.exp(z)
        return exp_z / sum(exp_z)

# %% [markdown]
# ## Init the network class
#
# Changes from week2:
# - Add dropout

# %%
class Network:
    TESTING_DATA_TYPE: str = "testing"
    TRAINING_DATA_TYPE: str = "training"

    def __init__(self, training_data: List[Tuple[np.ndarray, np.ndarray]],
                 testing_data: List[Tuple[np.ndarray, int]],
                 size: List[int], learning_rate: float, epochs: int,
                 mini_batch_size: int, lmda: int, training_accuracy_print: bool, testing_accuracy_print: bool):
        self.training_data = training_data
        self.testing_data = testing_data
        self.size = size
        self.num_layers = len(size)
        self.learning_rate = learning_rate
        self.biases = []
        self.weights = []
        self.retained_indices = {}
        self._init_weights()
        self._init_biases()
        self.epochs = epochs
        self.mini_batch_size = mini_batch_size
        self.lmda = lmda
        self.testing_accuracy_print = testing_accuracy_print
        self.training_accuracy_print = training_accuracy_print

    def _init_biases(self):
        for i in range(1, self.num_layers):
            self.biases.append(np.random.randn(self.size[i], 1))

    def _init_weights(self):
        bias_matrix_sizes = [(self.size[x + 1], self.size[x]) for x in range(self.num_layers - 1)]
        # Init weights by dividing by sqrt of each neuron's input size
        for x, y in bias_matrix_sizes:
            std_dev = 1 / np.sqrt(y)
            self.weights.append(np.random.randn(x, y) * std_dev)

    def _init_dropout_data(self):
        # Init dropout
        self.retained_indices = {}
        self._init_dropout_weights()
        self._init_dropout_biases()

    def _init_dropout_biases(self):
        # Retain biases only for the retained weights
        self.dropout_biases = copy.deepcopy(self.biases)
        for layer in range(self.num_layers - 2):
            indices_retained = self.retained_indices[layer + 1]
            self.dropout_biases[layer] = self.biases[layer][indices_retained]

    def _init_dropout_weights(self):
        # Add dropout to the weights
        self.dropout_weights = copy.deepcopy(self.weights)
        for layer in range(self.num_layers - 1):
            weight = self.dropout_weights[layer]

            input_size = np.size(weight, 1)
            indices_retained = random.sample(range(input_size), int(Hyperparameters.DROPOUT_RETAIN * input_size))
            indices_retained.sort()
            self.retained_indices[layer] = indices_retained
            self.dropout_weights[layer] = weight[:, indices_retained]

            if layer > 0:
                previous_weight = self.dropout_weights[layer - 1]
                self.dropout_weights[layer - 1] = previous_weight[indices_retained]

    def train(self):
        for epoch in range(self.epochs):
            # init dropout for each epoch
            self._init_dropout_data()
            np.random.shuffle(self.training_data)
            print(f"Start training for epoch: {epoch + 1} of {self.epochs}")

            mini_batches = self._create_mini_batches()

            for batch, mini_batch in enumerate(mini_batches, start=1):
                self._update_b_w(mini_batch)

            self._update_wt_bias()
            if self.training_accuracy_print:
                self._calc_accuracy(epoch + 1, self.training_data, self.TRAINING_DATA_TYPE)
            if self.testing_accuracy_print:
                self._calc_accuracy(epoch + 1, self.testing_data, self.TESTING_DATA_TYPE)

    def _create_mini_batches(self) -> List[List[Tuple[np.ndarray, np.ndarray]]]:
        mini_batches = [
            self.training_data[multiple:multiple + self.mini_batch_size] for multiple in
            range(0, len(self.training_data), self.mini_batch_size)
        ]
        return mini_batches

    def _update_b_w(self, mini_batch: List[Tuple[np.ndarray, np.ndarray]]):
        nabla_bias = self._get_nabla_bias_zeroes()
        nabla_wt = self._get_nabla_wt_zeroes()

        for x, y in mini_batch:
            del_bias, del_wt = self._run_back_propagation(x, y)

            nabla_bias = [curr_b + del_b for curr_b, del_b in zip(nabla_bias, del_bias)]
            nabla_wt = [curr_wt + del_w for curr_wt, del_w in zip(nabla_wt, del_wt)]

        self.dropout_biases = [
            b - ((self.learning_rate / self.mini_batch_size) * nb) for b, nb in zip(self.dropout_biases, nabla_bias)
        ]
        # Add L2 normalization
        self.dropout_weights = [
            np.dot(w, 1 - (self.learning_rate * self.lmda) / len(self.training_data)) -
            ((self.learning_rate / self.mini_batch_size) * nw) for w, nw in zip(self.dropout_weights, nabla_wt)
        ]

    def _get_nabla_bias_zeroes(self) -> List[np.ndarray]:
        return [np.zeros(np.shape(bias)) for bias in self.dropout_biases]

    def _get_nabla_wt_zeroes(self) -> List[np.ndarray]:
        return [np.zeros(np.shape(wt)) for wt in self.dropout_weights]

    def _run_back_propagation(self, x: np.ndarray, y: np.ndarray) -> Tuple[List[np.ndarray], List[np.ndarray]]:
        nabla_bias = self._get_nabla_bias_zeroes()
        nabla_wt = self._get_nabla_wt_zeroes()

        activations, z_list = self.feedforward(x[self.retained_indices[0]], self.dropout_weights, self.dropout_biases)
        # Delta for cross entropy
        error_l = self._delta_cross_entropy(activations[-1], y)

        nabla_bias[-1] = error_l
        nabla_wt[-1] = np.dot(error_l, np.transpose(activations[-2]))

        for layer in range(self.num_layers - 2, 0, -1):
            error_l = np.multiply(
                np.dot(np.transpose(self.dropout_weights[layer]), error_l), NetworkUtils.relu_prime(z_list[layer - 1])
            )

            nabla_bias[layer - 1] = error_l
            nabla_wt[layer - 1] = np.dot(error_l, activations[layer - 1].transpose())

        return nabla_bias, nabla_wt

    def _delta_cross_entropy(self, a_l: np.ndarray, y: np.ndarray) -> np.ndarray:
        return a_l - y

    def _update_wt_bias(self):
        self._update_wt()
        self._update_bias()

    def _update_wt(self):
        # Update the weights
        for layer in range(self.num_layers - 1):
            y_indices_for_wt = self.retained_indices[layer]
            if layer + 1 < self.num_layers - 1:
                x_indices_for_wt = self.retained_indices[layer + 1]

                temp = self.weights[layer].copy()[:, y_indices_for_wt]
                temp[x_indices_for_wt] = self.dropout_weights[layer]
                self.weights[layer][:, y_indices_for_wt] = temp
            else:
                self.weights[layer][:, y_indices_for_wt] = self.dropout_weights[layer]

    def _update_bias(self):
        # Update the biases
        for layer in range(self.num_layers - 2):
            x_indices_for_wt = self.retained_indices[layer + 1]
            self.biases[layer][x_indices_for_wt] = self.dropout_biases[layer]

    def _calc_accuracy(self, epoch: int, data: List[Tuple[np.ndarray, Union[np.ndarray, int]]], data_type: str):
        correct_results = 0
        total_results = len(data)
        for x, y in data:
            if data_type == self.TRAINING_DATA_TYPE:
                y = y.argmax()
            activations, _ = self.feedforward(x, self.weights, self.biases)
            logit = activations[-1]
            if logit.argmax() == y:
                correct_results += 1
        accuracy = round((correct_results / total_results) * 100, 2)
        print(
            f"Accuracy on {data_type} data for epoch {epoch}: {accuracy}"
        )

    def feedforward(self, x: np.ndarray, wt: List[np.ndarray], bias: List[np.ndarray]) -> \
            Tuple[List[np.ndarray], List[np.ndarray]]:
        a = x
        activations, z_list = list(), list()
        activations.append(x)
        self._set_relu_activations(a, z_list, activations, wt, bias)
        self._set_softmax_activation(activations[-1], z_list, activations, wt, bias)
        return activations, z_list

    def _set_relu_activations(self, a: np.ndarray, z_list: List[np.ndarray], activations: List[np.ndarray],
                              wt: List[np.ndarray], bias: List[np.ndarray]):
        for layer in range(self.num_layers - 2):
            # hidden layers(relu activation)
            z = np.dot(wt[layer], a) + bias[layer]
            z_list.append(z)
            a = NetworkUtils.relu(z)
            activations.append(a)

    def _set_softmax_activation(self, a: np.ndarray, z_list: List[np.ndarray], activations: List[np.ndarray],
                                wt: List[np.ndarray], bias: List[np.ndarray]):
        # output layer(softmax activation)
        z = np.dot(wt[-1], a) + bias[-1]
        z_list.append(z)
        a = NetworkUtils.softmax(z)
        activations.append(a)

# %% [markdown]
# ## Get datasets

# %%
training, testing, validation = MNISTDataLoader().load_data_wrapper_with_validation()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10FdcUHw3BcQAU6keKaUwtDwJm4sC00Hu
# To: /content/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 113MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GvsacEnI1eQ1vYZM-oYdERvaE2SPh0Lj
# To: /content/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.24MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1pmI9wAdNtJkOvkJpdTqM9bmIAwPkGyMU
# To: /content/train-images-idx3-ubyte.gz
# 9.91MB [00:00, 45.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1R8BZL67U1N0GUGnf6AQIBZNVDCWO9QLS
# To: /content/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 5.42MB/s]

# %% [markdown]
# ## Tune the hyperparameters

# %% [markdown]
# ### [Validation dataset] 5 eta; 3 layer; 100 mini_batch; 100% neuron retention; 25 epochs
#
# ---
#
#
# Start out trial with 3 level deep network and learning rate = 5 and by using subsets slices of the training data and validation data

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 30, 10]
    LEARNING_RATE: float = 5
    EPOCHS: int = 25
    MINI_BATCH_SIZE: int = 100
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 1000], validation[:1000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 30, 10]
#  LEARNING_RATE: 5
#  EPOCHS: 25
#  MINI_BATCH_SIZE: 100
#  LMDA: 5
#  DROPOUT_RETAIN: 1
# Start training for epoch: 1 of 25
# Accuracy on training data for epoch 1: 9.7
# Accuracy on testing data for epoch 1: 10.0
# Start training for epoch: 2 of 25
# Accuracy on training data for epoch 2: 9.7
# Accuracy on testing data for epoch 2: 10.0
# Start training for epoch: 3 of 25
# Accuracy on training data for epoch 3: 9.7
# Accuracy on testing data for epoch 3: 10.0
# Start training for epoch: 4 of 25
# Accuracy on training data for epoch 4: 11.6
# Accuracy on testing data for epoch 4: 12.2
# Start training for epoch: 5 of 25
# Accuracy on training data for epoch 5: 9.7
# Accuracy on testing data for epoch 5: 10.0
# Start training for epoch: 6 of 25
# Accuracy on training data for epoch 6: 9.7
# Accuracy on testing data for epoch 6: 10.0
# Start training for epoch: 7 of 25
# Accuracy on training data for epoch 7: 9.7
# Accuracy on testing data for epoch 7: 10.0
# Start training for epoch: 8 of 25
# Accuracy on training data for epoch 8: 9.7
# Accuracy on testing data for epoch 8: 10.0
# Start training for epoch: 9 of 25
# Accuracy on training data for epoch 9: 9.7
# Accuracy on testing data for epoch 9: 10.0
# Start training for epoch: 10 of 25
# Accuracy on training data for epoch 10: 9.7
# Accuracy on testing data for epoch 10: 10.0
# Start training for epoch: 11 of 25
# Accuracy on training data for epoch 11: 9.7
# Accuracy on testing data for epoch 11: 10.0
# Start training for epoch: 12 of 25
# Accuracy on training data for epoch 12: 9.7
# Accuracy on testing data for epoch 12: 10.0
# Start training for epoch: 13 of 25
# Accuracy on training data for epoch 13: 9.7
# Accuracy on testing data for epoch 13: 10.0
# Start training for epoch: 14 of 25
# Accuracy on training data for epoch 14: 9.7
# Accuracy on testing data for epoch 14: 10.0
# Start training for epoch: 15 of 25
# Accuracy on training data for epoch 15: 9.7
# Accuracy on testing data for epoch 15: 10.0
# Start training for epoch: 16 of 25
# Accuracy on training data for epoch 16: 9.7
# Accuracy on testing data for epoch 16: 10.0
# Start training for epoch: 17 of 25
# Accuracy on training data for epoch 17: 9.7
# Accuracy on testing data for epoch 17: 10.0
# Start training for epoch: 18 of 25
# Accuracy on training data for epoch 18: 9.7
# Accuracy on testing data for epoch 18: 10.0
# Start training for epoch: 19 of 25
# Accuracy on training data for epoch 19: 9.7
# Accuracy on testing data for epoch 19: 10.0
# Start training for epoch: 20 of 25
# Accuracy on training data for epoch 20: 9.7
# Accuracy on testing data for epoch 20: 10.0
# Start training for epoch: 21 of 25
# Accuracy on training data for epoch 21: 9.7
# Accuracy on testing data for epoch 21: 10.0
# Start training for epoch: 22 of 25
# Accuracy on training data for epoch 22: 9.7
# Accuracy on testing data for epoch 22: 10.0
# Start training for epoch: 23 of 25
# Accuracy on training data for epoch 23: 9.7
# Accuracy on testing data for epoch 23: 10.0
# Start training for epoch: 24 of 25
# Accuracy on training data for epoch 24: 9.7
# Accuracy on testing data for epoch 24: 10.0
# Start training for epoch: 25 of 25
# Accuracy on training data for epoch 25: 9.7
# Accuracy on testing data for epoch 25: 10.0

# %% [markdown]
# ### [Validation dataset] 1 eta; 3 layer; 100 mini_batch; 100% neuron retention; 10 epochs
#
# ---
#
#
# No learning occurs, try with reduced learning rate of 1

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 30, 10]
    LEARNING_RATE: float = 1
    EPOCHS: int = 10
    MINI_BATCH_SIZE: int = 100
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 1000], validation[:1000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 30, 10]
#  LEARNING_RATE: 1
#  EPOCHS: 10
#  MINI_BATCH_SIZE: 100
#  LMDA: 5
#  DROPOUT_RETAIN: 1
# Start training for epoch: 1 of 10
# Accuracy on training data for epoch 1: 32.9
# Accuracy on testing data for epoch 1: 28.9
# Start training for epoch: 2 of 10
# Accuracy on training data for epoch 2: 40.9
# Accuracy on testing data for epoch 2: 36.5
# Start training for epoch: 3 of 10
# Accuracy on training data for epoch 3: 44.9
# Accuracy on testing data for epoch 3: 37.6
# Start training for epoch: 4 of 10
# Accuracy on training data for epoch 4: 51.8
# Accuracy on testing data for epoch 4: 46.4
# Start training for epoch: 5 of 10
# Accuracy on training data for epoch 5: 62.6
# Accuracy on testing data for epoch 5: 53.2
# Start training for epoch: 6 of 10
# Accuracy on training data for epoch 6: 38.2
# Accuracy on testing data for epoch 6: 31.9
# Start training for epoch: 7 of 10
# Accuracy on training data for epoch 7: 50.2
# Accuracy on testing data for epoch 7: 43.3
# Start training for epoch: 8 of 10
# Accuracy on training data for epoch 8: 52.2
# Accuracy on testing data for epoch 8: 43.3
# Start training for epoch: 9 of 10
# Accuracy on training data for epoch 9: 38.0
# Accuracy on testing data for epoch 9: 39.2
# Start training for epoch: 10 of 10
# Accuracy on training data for epoch 10: 59.7
# Accuracy on testing data for epoch 10: 52.1

# %% [markdown]
# ### [Validation dataset] 0.1 eta; 3 layer; 100 mini_batch; 100% neuron retention; 20 epochs
#
# ---
#
#
# Better results, try lowering to 0.1

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 30, 10]
    LEARNING_RATE: float = 0.1
    EPOCHS: int = 20
    MINI_BATCH_SIZE: int = 100
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 1000], validation[:1000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 30, 10]
#  LEARNING_RATE: 0.1
#  EPOCHS: 20
#  MINI_BATCH_SIZE: 100
#  LMDA: 5
#  DROPOUT_RETAIN: 1
# Start training for epoch: 1 of 20
# Accuracy on training data for epoch 1: 48.2
# Accuracy on testing data for epoch 1: 45.1
# Start training for epoch: 2 of 20
# Accuracy on training data for epoch 2: 68.1
# Accuracy on testing data for epoch 2: 62.1
# Start training for epoch: 3 of 20
# Accuracy on training data for epoch 3: 77.5
# Accuracy on testing data for epoch 3: 68.6
# Start training for epoch: 4 of 20
# Accuracy on training data for epoch 4: 81.0
# Accuracy on testing data for epoch 4: 73.8
# Start training for epoch: 5 of 20
# Accuracy on training data for epoch 5: 83.2
# Accuracy on testing data for epoch 5: 76.7
# Start training for epoch: 6 of 20
# Accuracy on training data for epoch 6: 84.9
# Accuracy on testing data for epoch 6: 78.5
# Start training for epoch: 7 of 20
# Accuracy on training data for epoch 7: 85.8
# Accuracy on testing data for epoch 7: 80.0
# Start training for epoch: 8 of 20
# Accuracy on training data for epoch 8: 87.2
# Accuracy on testing data for epoch 8: 78.8
# Start training for epoch: 9 of 20
# Accuracy on training data for epoch 9: 88.5
# Accuracy on testing data for epoch 9: 81.0
# Start training for epoch: 10 of 20
# Accuracy on training data for epoch 10: 88.8
# Accuracy on testing data for epoch 10: 81.3
# Start training for epoch: 11 of 20
# Accuracy on training data for epoch 11: 89.5
# Accuracy on testing data for epoch 11: 81.0
# Start training for epoch: 12 of 20
# Accuracy on training data for epoch 12: 89.9
# Accuracy on testing data for epoch 12: 82.7
# Start training for epoch: 13 of 20
# Accuracy on training data for epoch 13: 90.0
# Accuracy on testing data for epoch 13: 82.5
# Start training for epoch: 14 of 20
# Accuracy on training data for epoch 14: 90.5
# Accuracy on testing data for epoch 14: 83.1
# Start training for epoch: 15 of 20
# Accuracy on training data for epoch 15: 90.3
# Accuracy on testing data for epoch 15: 84.0
# Start training for epoch: 16 of 20
# Accuracy on training data for epoch 16: 91.1
# Accuracy on testing data for epoch 16: 82.9
# Start training for epoch: 17 of 20
# Accuracy on training data for epoch 17: 91.1
# Accuracy on testing data for epoch 17: 82.7
# Start training for epoch: 18 of 20
# Accuracy on training data for epoch 18: 91.6
# Accuracy on testing data for epoch 18: 83.6
# Start training for epoch: 19 of 20
# Accuracy on training data for epoch 19: 92.5
# Accuracy on testing data for epoch 19: 83.3
# Start training for epoch: 20 of 20
# Accuracy on training data for epoch 20: 92.4
# Accuracy on testing data for epoch 20: 84.5

# %% [markdown]
# ### [Validation dataset] 0.01 eta; 3 layer(deeper hidden); 100 mini_batch; 100% neuron retention; 20 epochs
#
# ---
#
#
# Try increasing the number of neurons in the hidden layer from 30 to 100 & reducing learning rate to 0.01

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 20
    MINI_BATCH_SIZE: int = 100
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 1000], validation[:1000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 20
#  MINI_BATCH_SIZE: 100
#  LMDA: 5
#  DROPOUT_RETAIN: 1
# Start training for epoch: 1 of 20
# Accuracy on training data for epoch 1: 9.3
# Accuracy on testing data for epoch 1: 8.3
# Start training for epoch: 2 of 20
# Accuracy on training data for epoch 2: 17.6
# Accuracy on testing data for epoch 2: 13.7
# Start training for epoch: 3 of 20
# Accuracy on training data for epoch 3: 28.0
# Accuracy on testing data for epoch 3: 23.2
# Start training for epoch: 4 of 20
# Accuracy on training data for epoch 4: 39.7
# Accuracy on testing data for epoch 4: 31.2
# Start training for epoch: 5 of 20
# Accuracy on training data for epoch 5: 47.7
# Accuracy on testing data for epoch 5: 37.4
# Start training for epoch: 6 of 20
# Accuracy on training data for epoch 6: 51.2
# Accuracy on testing data for epoch 6: 41.7
# Start training for epoch: 7 of 20
# Accuracy on training data for epoch 7: 54.8
# Accuracy on testing data for epoch 7: 44.0
# Start training for epoch: 8 of 20
# Accuracy on training data for epoch 8: 57.2
# Accuracy on testing data for epoch 8: 46.8
# Start training for epoch: 9 of 20
# Accuracy on training data for epoch 9: 59.2
# Accuracy on testing data for epoch 9: 49.2
# Start training for epoch: 10 of 20
# Accuracy on training data for epoch 10: 61.3
# Accuracy on testing data for epoch 10: 51.0
# Start training for epoch: 11 of 20
# Accuracy on training data for epoch 11: 62.2
# Accuracy on testing data for epoch 11: 52.7
# Start training for epoch: 12 of 20
# Accuracy on training data for epoch 12: 62.9
# Accuracy on testing data for epoch 12: 54.0
# Start training for epoch: 13 of 20
# Accuracy on training data for epoch 13: 64.2
# Accuracy on testing data for epoch 13: 55.9
# Start training for epoch: 14 of 20
# Accuracy on training data for epoch 14: 66.3
# Accuracy on testing data for epoch 14: 58.0
# Start training for epoch: 15 of 20
# Accuracy on training data for epoch 15: 67.7
# Accuracy on testing data for epoch 15: 59.4
# Start training for epoch: 16 of 20
# Accuracy on training data for epoch 16: 69.1
# Accuracy on testing data for epoch 16: 60.9
# Start training for epoch: 17 of 20
# Accuracy on training data for epoch 17: 70.1
# Accuracy on testing data for epoch 17: 61.5
# Start training for epoch: 18 of 20
# Accuracy on training data for epoch 18: 71.5
# Accuracy on testing data for epoch 18: 62.8
# Start training for epoch: 19 of 20
# Accuracy on training data for epoch 19: 72.2
# Accuracy on testing data for epoch 19: 63.5
# Start training for epoch: 20 of 20
# Accuracy on training data for epoch 20: 73.2
# Accuracy on testing data for epoch 20: 65.1

# %% [markdown]
# ### [Validation dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 100% neuron retention; 20 epochs
#
# ---
#
#
# Slower learning observed, reducing batch size in SGD to 10
# Also make the network deeper by one more hidden layer

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 20
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 2000], validation[:2000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 20
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 1
# Start training for epoch: 1 of 20
# Accuracy on training data for epoch 1: 65.0
# Accuracy on testing data for epoch 1: 60.85
# Start training for epoch: 2 of 20
# Accuracy on training data for epoch 2: 80.7
# Accuracy on testing data for epoch 2: 77.85
# Start training for epoch: 3 of 20
# Accuracy on training data for epoch 3: 84.5
# Accuracy on testing data for epoch 3: 82.7
# Start training for epoch: 4 of 20
# Accuracy on training data for epoch 4: 87.25
# Accuracy on testing data for epoch 4: 84.4
# Start training for epoch: 5 of 20
# Accuracy on training data for epoch 5: 88.25
# Accuracy on testing data for epoch 5: 84.2
# Start training for epoch: 6 of 20
# Accuracy on training data for epoch 6: 89.5
# Accuracy on testing data for epoch 6: 85.0
# Start training for epoch: 7 of 20
# Accuracy on training data for epoch 7: 90.75
# Accuracy on testing data for epoch 7: 87.2
# Start training for epoch: 8 of 20
# Accuracy on training data for epoch 8: 91.75
# Accuracy on testing data for epoch 8: 86.85
# Start training for epoch: 9 of 20
# Accuracy on training data for epoch 9: 92.35
# Accuracy on testing data for epoch 9: 87.75
# Start training for epoch: 10 of 20
# Accuracy on training data for epoch 10: 92.6
# Accuracy on testing data for epoch 10: 87.85
# Start training for epoch: 11 of 20
# Accuracy on training data for epoch 11: 93.3
# Accuracy on testing data for epoch 11: 88.45
# Start training for epoch: 12 of 20
# Accuracy on training data for epoch 12: 93.65
# Accuracy on testing data for epoch 12: 88.35
# Start training for epoch: 13 of 20
# Accuracy on training data for epoch 13: 94.05
# Accuracy on testing data for epoch 13: 87.9
# Start training for epoch: 14 of 20
# Accuracy on training data for epoch 14: 94.45
# Accuracy on testing data for epoch 14: 89.2
# Start training for epoch: 15 of 20
# Accuracy on training data for epoch 15: 94.5
# Accuracy on testing data for epoch 15: 89.05
# Start training for epoch: 16 of 20
# Accuracy on training data for epoch 16: 94.55
# Accuracy on testing data for epoch 16: 88.7
# Start training for epoch: 17 of 20
# Accuracy on training data for epoch 17: 95.05
# Accuracy on testing data for epoch 17: 88.95
# Start training for epoch: 18 of 20
# Accuracy on training data for epoch 18: 95.7
# Accuracy on testing data for epoch 18: 89.45
# Start training for epoch: 19 of 20
# Accuracy on training data for epoch 19: 95.45
# Accuracy on testing data for epoch 19: 89.1
# Start training for epoch: 20 of 20
# Accuracy on training data for epoch 20: 95.45
# Accuracy on testing data for epoch 20: 89.2

# %% [markdown]
# ### [Validation dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 80% neuron retention; 20 epochs
#
# ---
#
#
# Better results with lower mini batch size observed, introduce dropout to retain 80% of neurons

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 20
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.80

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 2000], validation[:2000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 20
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.8
# Start training for epoch: 1 of 20
# Accuracy on training data for epoch 1: 21.0
# Accuracy on testing data for epoch 1: 19.95
# Start training for epoch: 2 of 20
# Accuracy on training data for epoch 2: 53.9
# Accuracy on testing data for epoch 2: 50.85
# Start training for epoch: 3 of 20
# Accuracy on training data for epoch 3: 53.35
# Accuracy on testing data for epoch 3: 49.6
# Start training for epoch: 4 of 20
# Accuracy on training data for epoch 4: 65.65
# Accuracy on testing data for epoch 4: 62.65
# Start training for epoch: 5 of 20
# Accuracy on training data for epoch 5: 66.6
# Accuracy on testing data for epoch 5: 62.35
# Start training for epoch: 6 of 20
# Accuracy on training data for epoch 6: 70.2
# Accuracy on testing data for epoch 6: 66.7
# Start training for epoch: 7 of 20
# Accuracy on training data for epoch 7: 77.05
# Accuracy on testing data for epoch 7: 73.5
# Start training for epoch: 8 of 20
# Accuracy on training data for epoch 8: 78.9
# Accuracy on testing data for epoch 8: 76.0
# Start training for epoch: 9 of 20
# Accuracy on training data for epoch 9: 82.95
# Accuracy on testing data for epoch 9: 80.65
# Start training for epoch: 10 of 20
# Accuracy on training data for epoch 10: 84.2
# Accuracy on testing data for epoch 10: 80.5
# Start training for epoch: 11 of 20
# Accuracy on training data for epoch 11: 81.75
# Accuracy on testing data for epoch 11: 78.2
# Start training for epoch: 12 of 20
# Accuracy on training data for epoch 12: 80.5
# Accuracy on testing data for epoch 12: 76.75
# Start training for epoch: 13 of 20
# Accuracy on training data for epoch 13: 83.45
# Accuracy on testing data for epoch 13: 81.5
# Start training for epoch: 14 of 20
# Accuracy on training data for epoch 14: 83.4
# Accuracy on testing data for epoch 14: 79.5
# Start training for epoch: 15 of 20
# Accuracy on training data for epoch 15: 85.3
# Accuracy on testing data for epoch 15: 80.7
# Start training for epoch: 16 of 20
# Accuracy on training data for epoch 16: 89.45
# Accuracy on testing data for epoch 16: 86.15
# Start training for epoch: 17 of 20
# Accuracy on training data for epoch 17: 84.9
# Accuracy on testing data for epoch 17: 81.4
# Start training for epoch: 18 of 20
# Accuracy on training data for epoch 18: 83.9
# Accuracy on testing data for epoch 18: 81.6
# Start training for epoch: 19 of 20
# Accuracy on training data for epoch 19: 88.15
# Accuracy on testing data for epoch 19: 84.0
# Start training for epoch: 20 of 20
# Accuracy on training data for epoch 20: 89.15
# Accuracy on testing data for epoch 20: 85.1

# %% [markdown]
# ### [Validation dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 70% neuron retention; 20 epochs
#
# ---
#
#
# Similar results if not worse, further reduce dropout to 70%

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 20
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.70

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 2000], validation[:2000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 20
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.7
# Start training for epoch: 1 of 20
# Accuracy on training data for epoch 1: 23.0
# Accuracy on testing data for epoch 1: 22.75
# Start training for epoch: 2 of 20
# Accuracy on training data for epoch 2: 52.55
# Accuracy on testing data for epoch 2: 49.85
# Start training for epoch: 3 of 20
# Accuracy on training data for epoch 3: 55.45
# Accuracy on testing data for epoch 3: 53.35
# Start training for epoch: 4 of 20
# Accuracy on training data for epoch 4: 63.1
# Accuracy on testing data for epoch 4: 59.75
# Start training for epoch: 5 of 20
# Accuracy on training data for epoch 5: 64.65
# Accuracy on testing data for epoch 5: 61.8
# Start training for epoch: 6 of 20
# Accuracy on training data for epoch 6: 63.9
# Accuracy on testing data for epoch 6: 62.55
# Start training for epoch: 7 of 20
# Accuracy on training data for epoch 7: 73.8
# Accuracy on testing data for epoch 7: 72.95
# Start training for epoch: 8 of 20
# Accuracy on training data for epoch 8: 78.95
# Accuracy on testing data for epoch 8: 76.8
# Start training for epoch: 9 of 20
# Accuracy on training data for epoch 9: 71.8
# Accuracy on testing data for epoch 9: 68.65
# Start training for epoch: 10 of 20
# Accuracy on training data for epoch 10: 81.2
# Accuracy on testing data for epoch 10: 79.4
# Start training for epoch: 11 of 20
# Accuracy on training data for epoch 11: 81.1
# Accuracy on testing data for epoch 11: 77.1
# Start training for epoch: 12 of 20
# Accuracy on training data for epoch 12: 82.25
# Accuracy on testing data for epoch 12: 78.75
# Start training for epoch: 13 of 20
# Accuracy on training data for epoch 13: 81.05
# Accuracy on testing data for epoch 13: 78.7
# Start training for epoch: 14 of 20
# Accuracy on training data for epoch 14: 79.15
# Accuracy on testing data for epoch 14: 76.1
# Start training for epoch: 15 of 20
# Accuracy on training data for epoch 15: 82.95
# Accuracy on testing data for epoch 15: 81.15
# Start training for epoch: 16 of 20
# Accuracy on training data for epoch 16: 79.4
# Accuracy on testing data for epoch 16: 76.8
# Start training for epoch: 17 of 20
# Accuracy on training data for epoch 17: 79.55
# Accuracy on testing data for epoch 17: 77.05
# Start training for epoch: 18 of 20
# Accuracy on training data for epoch 18: 73.75
# Accuracy on testing data for epoch 18: 72.85
# Start training for epoch: 19 of 20
# Accuracy on training data for epoch 19: 78.05
# Accuracy on testing data for epoch 19: 76.55
# Start training for epoch: 20 of 20
# Accuracy on training data for epoch 20: 88.55
# Accuracy on testing data for epoch 20: 84.85

# %% [markdown]
# ### [Validation dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 70% neuron retention; 100 epochs
#
# ---
#
#
# Try increasing epochs from 20 to 100 to see if networks keeps learning

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 100
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.70

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 2000], validation[:2000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 100
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.7
# Start training for epoch: 1 of 100
# Accuracy on training data for epoch 1: 39.85
# Accuracy on testing data for epoch 1: 36.45
# Start training for epoch: 2 of 100
# Accuracy on training data for epoch 2: 57.2
# Accuracy on testing data for epoch 2: 56.35
# Start training for epoch: 3 of 100
# Accuracy on training data for epoch 3: 40.3
# Accuracy on testing data for epoch 3: 37.75
# Start training for epoch: 4 of 100
# Accuracy on training data for epoch 4: 57.55
# Accuracy on testing data for epoch 4: 55.95
# Start training for epoch: 5 of 100
# Accuracy on training data for epoch 5: 65.85
# Accuracy on testing data for epoch 5: 62.05
# Start training for epoch: 6 of 100
# Accuracy on training data for epoch 6: 66.05
# Accuracy on testing data for epoch 6: 63.3
# Start training for epoch: 7 of 100
# Accuracy on training data for epoch 7: 72.3
# Accuracy on testing data for epoch 7: 72.1
# Start training for epoch: 8 of 100
# Accuracy on training data for epoch 8: 75.65
# Accuracy on testing data for epoch 8: 73.65
# Start training for epoch: 9 of 100
# Accuracy on training data for epoch 9: 73.35
# Accuracy on testing data for epoch 9: 71.4
# Start training for epoch: 10 of 100
# Accuracy on training data for epoch 10: 74.4
# Accuracy on testing data for epoch 10: 71.6
# Start training for epoch: 11 of 100
# Accuracy on training data for epoch 11: 64.2
# Accuracy on testing data for epoch 11: 61.4
# Start training for epoch: 12 of 100
# Accuracy on training data for epoch 12: 76.75
# Accuracy on testing data for epoch 12: 73.45
# Start training for epoch: 13 of 100
# Accuracy on training data for epoch 13: 74.25
# Accuracy on testing data for epoch 13: 71.85
# Start training for epoch: 14 of 100
# Accuracy on training data for epoch 14: 83.2
# Accuracy on testing data for epoch 14: 80.15
# Start training for epoch: 15 of 100
# Accuracy on training data for epoch 15: 78.4
# Accuracy on testing data for epoch 15: 75.55
# Start training for epoch: 16 of 100
# Accuracy on training data for epoch 16: 82.65
# Accuracy on testing data for epoch 16: 78.9
# Start training for epoch: 17 of 100
# Accuracy on training data for epoch 17: 77.85
# Accuracy on testing data for epoch 17: 74.65
# Start training for epoch: 18 of 100
# Accuracy on training data for epoch 18: 81.4
# Accuracy on testing data for epoch 18: 77.05
# Start training for epoch: 19 of 100
# Accuracy on training data for epoch 19: 75.0
# Accuracy on testing data for epoch 19: 71.75
# Start training for epoch: 20 of 100
# Accuracy on training data for epoch 20: 77.85
# Accuracy on testing data for epoch 20: 75.75
# Start training for epoch: 21 of 100
# Accuracy on training data for epoch 21: 73.75
# Accuracy on testing data for epoch 21: 70.35
# Start training for epoch: 22 of 100
# Accuracy on training data for epoch 22: 70.9
# Accuracy on testing data for epoch 22: 67.45
# Start training for epoch: 23 of 100
# Accuracy on training data for epoch 23: 79.55
# Accuracy on testing data for epoch 23: 76.75
# Start training for epoch: 24 of 100
# Accuracy on training data for epoch 24: 83.85
# Accuracy on testing data for epoch 24: 80.55
# Start training for epoch: 25 of 100
# Accuracy on training data for epoch 25: 87.3
# Accuracy on testing data for epoch 25: 82.6
# Start training for epoch: 26 of 100
# Accuracy on training data for epoch 26: 81.55
# Accuracy on testing data for epoch 26: 78.75
# Start training for epoch: 27 of 100
# Accuracy on training data for epoch 27: 78.1
# Accuracy on testing data for epoch 27: 73.25
# Start training for epoch: 28 of 100
# Accuracy on training data for epoch 28: 70.15
# Accuracy on testing data for epoch 28: 66.7
# Start training for epoch: 29 of 100
# Accuracy on training data for epoch 29: 64.8
# Accuracy on testing data for epoch 29: 63.25
# Start training for epoch: 30 of 100
# Accuracy on training data for epoch 30: 73.5
# Accuracy on testing data for epoch 30: 69.35
# Start training for epoch: 31 of 100
# Accuracy on training data for epoch 31: 85.0
# Accuracy on testing data for epoch 31: 80.05
# Start training for epoch: 32 of 100
# Accuracy on training data for epoch 32: 84.05
# Accuracy on testing data for epoch 32: 78.15
# Start training for epoch: 33 of 100
# Accuracy on training data for epoch 33: 81.15
# Accuracy on testing data for epoch 33: 76.8
# Start training for epoch: 34 of 100
# Accuracy on training data for epoch 34: 81.5
# Accuracy on testing data for epoch 34: 77.15
# Start training for epoch: 35 of 100
# Accuracy on training data for epoch 35: 79.25
# Accuracy on testing data for epoch 35: 74.3
# Start training for epoch: 36 of 100
# Accuracy on training data for epoch 36: 77.0
# Accuracy on testing data for epoch 36: 73.95
# Start training for epoch: 37 of 100
# Accuracy on training data for epoch 37: 73.3
# Accuracy on testing data for epoch 37: 69.3
# Start training for epoch: 38 of 100
# Accuracy on training data for epoch 38: 83.95
# Accuracy on testing data for epoch 38: 79.0
# Start training for epoch: 39 of 100
# Accuracy on training data for epoch 39: 87.75
# Accuracy on testing data for epoch 39: 81.6
# Start training for epoch: 40 of 100
# Accuracy on training data for epoch 40: 81.4
# Accuracy on testing data for epoch 40: 75.3
# Start training for epoch: 41 of 100
# Accuracy on training data for epoch 41: 87.95
# Accuracy on testing data for epoch 41: 81.55
# Start training for epoch: 42 of 100
# Accuracy on training data for epoch 42: 90.3
# Accuracy on testing data for epoch 42: 83.75
# Start training for epoch: 43 of 100
# Accuracy on training data for epoch 43: 91.25
# Accuracy on testing data for epoch 43: 86.8
# Start training for epoch: 44 of 100
# Accuracy on training data for epoch 44: 87.2
# Accuracy on testing data for epoch 44: 81.55
# Start training for epoch: 45 of 100
# Accuracy on training data for epoch 45: 89.95
# Accuracy on testing data for epoch 45: 85.35
# Start training for epoch: 46 of 100
# Accuracy on training data for epoch 46: 89.4
# Accuracy on testing data for epoch 46: 83.85
# Start training for epoch: 47 of 100
# Accuracy on training data for epoch 47: 87.7
# Accuracy on testing data for epoch 47: 82.85
# Start training for epoch: 48 of 100
# Accuracy on training data for epoch 48: 88.65
# Accuracy on testing data for epoch 48: 84.8
# Start training for epoch: 49 of 100
# Accuracy on training data for epoch 49: 89.3
# Accuracy on testing data for epoch 49: 83.3
# Start training for epoch: 50 of 100
# Accuracy on training data for epoch 50: 88.55
# Accuracy on testing data for epoch 50: 82.5
# Start training for epoch: 51 of 100
# Accuracy on training data for epoch 51: 86.35
# Accuracy on testing data for epoch 51: 80.65
# Start training for epoch: 52 of 100
# Accuracy on training data for epoch 52: 82.7
# Accuracy on testing data for epoch 52: 77.0
# Start training for epoch: 53 of 100
# Accuracy on training data for epoch 53: 82.1
# Accuracy on testing data for epoch 53: 76.1
# Start training for epoch: 54 of 100
# Accuracy on training data for epoch 54: 84.8
# Accuracy on testing data for epoch 54: 78.55
# Start training for epoch: 55 of 100
# Accuracy on training data for epoch 55: 89.25
# Accuracy on testing data for epoch 55: 82.7
# Start training for epoch: 56 of 100
# Accuracy on training data for epoch 56: 91.75
# Accuracy on testing data for epoch 56: 86.4
# Start training for epoch: 57 of 100
# Accuracy on training data for epoch 57: 91.4
# Accuracy on testing data for epoch 57: 86.95
# Start training for epoch: 58 of 100
# Accuracy on training data for epoch 58: 88.85
# Accuracy on testing data for epoch 58: 83.1
# Start training for epoch: 59 of 100
# Accuracy on training data for epoch 59: 87.15
# Accuracy on testing data for epoch 59: 81.2
# Start training for epoch: 60 of 100
# Accuracy on training data for epoch 60: 89.25
# Accuracy on testing data for epoch 60: 84.05
# Start training for epoch: 61 of 100
# Accuracy on training data for epoch 61: 89.7
# Accuracy on testing data for epoch 61: 82.45
# Start training for epoch: 62 of 100
# Accuracy on training data for epoch 62: 85.7
# Accuracy on testing data for epoch 62: 79.35
# Start training for epoch: 63 of 100
# Accuracy on training data for epoch 63: 88.75
# Accuracy on testing data for epoch 63: 84.0
# Start training for epoch: 64 of 100
# Accuracy on training data for epoch 64: 88.8
# Accuracy on testing data for epoch 64: 82.95
# Start training for epoch: 65 of 100
# Accuracy on training data for epoch 65: 93.55
# Accuracy on testing data for epoch 65: 87.75
# Start training for epoch: 66 of 100
# Accuracy on training data for epoch 66: 92.65
# Accuracy on testing data for epoch 66: 85.95
# Start training for epoch: 67 of 100
# Accuracy on training data for epoch 67: 90.75
# Accuracy on testing data for epoch 67: 84.0
# Start training for epoch: 68 of 100
# Accuracy on training data for epoch 68: 86.7
# Accuracy on testing data for epoch 68: 81.85
# Start training for epoch: 69 of 100
# Accuracy on training data for epoch 69: 89.9
# Accuracy on testing data for epoch 69: 83.85
# Start training for epoch: 70 of 100
# Accuracy on training data for epoch 70: 89.8
# Accuracy on testing data for epoch 70: 84.15
# Start training for epoch: 71 of 100
# Accuracy on training data for epoch 71: 87.45
# Accuracy on testing data for epoch 71: 81.05
# Start training for epoch: 72 of 100
# Accuracy on training data for epoch 72: 90.9
# Accuracy on testing data for epoch 72: 84.85
# Start training for epoch: 73 of 100
# Accuracy on training data for epoch 73: 88.45
# Accuracy on testing data for epoch 73: 82.7
# Start training for epoch: 74 of 100
# Accuracy on training data for epoch 74: 93.6
# Accuracy on testing data for epoch 74: 88.3
# Start training for epoch: 75 of 100
# Accuracy on training data for epoch 75: 93.3
# Accuracy on testing data for epoch 75: 87.6
# Start training for epoch: 76 of 100
# Accuracy on training data for epoch 76: 93.7
# Accuracy on testing data for epoch 76: 86.85
# Start training for epoch: 77 of 100
# Accuracy on training data for epoch 77: 85.2
# Accuracy on testing data for epoch 77: 78.35
# Start training for epoch: 78 of 100
# Accuracy on training data for epoch 78: 87.45
# Accuracy on testing data for epoch 78: 80.7
# Start training for epoch: 79 of 100
# Accuracy on training data for epoch 79: 94.25
# Accuracy on testing data for epoch 79: 87.4
# Start training for epoch: 80 of 100
# Accuracy on training data for epoch 80: 93.2
# Accuracy on testing data for epoch 80: 86.25
# Start training for epoch: 81 of 100
# Accuracy on training data for epoch 81: 89.15
# Accuracy on testing data for epoch 81: 83.2
# Start training for epoch: 82 of 100
# Accuracy on training data for epoch 82: 93.6
# Accuracy on testing data for epoch 82: 87.85
# Start training for epoch: 83 of 100
# Accuracy on training data for epoch 83: 93.5
# Accuracy on testing data for epoch 83: 86.55
# Start training for epoch: 84 of 100
# Accuracy on training data for epoch 84: 93.1
# Accuracy on testing data for epoch 84: 85.15
# Start training for epoch: 85 of 100
# Accuracy on training data for epoch 85: 89.3
# Accuracy on testing data for epoch 85: 81.95
# Start training for epoch: 86 of 100
# Accuracy on training data for epoch 86: 88.15
# Accuracy on testing data for epoch 86: 79.2
# Start training for epoch: 87 of 100
# Accuracy on training data for epoch 87: 93.15
# Accuracy on testing data for epoch 87: 85.8
# Start training for epoch: 88 of 100
# Accuracy on training data for epoch 88: 88.8
# Accuracy on testing data for epoch 88: 82.25
# Start training for epoch: 89 of 100
# Accuracy on training data for epoch 89: 90.3
# Accuracy on testing data for epoch 89: 83.25
# Start training for epoch: 90 of 100
# Accuracy on training data for epoch 90: 90.65
# Accuracy on testing data for epoch 90: 84.25
# Start training for epoch: 91 of 100
# Accuracy on training data for epoch 91: 90.95
# Accuracy on testing data for epoch 91: 83.75
# Start training for epoch: 92 of 100
# Accuracy on training data for epoch 92: 89.35
# Accuracy on testing data for epoch 92: 80.65
# Start training for epoch: 93 of 100
# Accuracy on training data for epoch 93: 88.7
# Accuracy on testing data for epoch 93: 80.25
# Start training for epoch: 94 of 100
# Accuracy on training data for epoch 94: 90.75
# Accuracy on testing data for epoch 94: 82.45
# Start training for epoch: 95 of 100
# Accuracy on training data for epoch 95: 95.9
# Accuracy on testing data for epoch 95: 88.95
# Start training for epoch: 96 of 100
# Accuracy on training data for epoch 96: 94.55
# Accuracy on testing data for epoch 96: 87.4
# Start training for epoch: 97 of 100
# Accuracy on training data for epoch 97: 94.0
# Accuracy on testing data for epoch 97: 87.25
# Start training for epoch: 98 of 100
# Accuracy on training data for epoch 98: 94.2
# Accuracy on testing data for epoch 98: 86.85
# Start training for epoch: 99 of 100
# Accuracy on training data for epoch 99: 94.35
# Accuracy on testing data for epoch 99: 87.1
# Start training for epoch: 100 of 100
# Accuracy on training data for epoch 100: 93.35
# Accuracy on testing data for epoch 100: 88.35

# %% [markdown]
# ### [Testing dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 70% neuron retention; 100 epochs
#
#
# ---
#
#
# Promising results, maybe with higher epochs will go higher. Verify data with testing data

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 100
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.70

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training[: 2000], testing[:2000], params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 100
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.7
# Start training for epoch: 1 of 100
# Accuracy on training data for epoch 1: 24.45
# Accuracy on testing data for epoch 1: 21.6
# Start training for epoch: 2 of 100
# Accuracy on training data for epoch 2: 44.3
# Accuracy on testing data for epoch 2: 41.35
# Start training for epoch: 3 of 100
# Accuracy on training data for epoch 3: 42.35
# Accuracy on testing data for epoch 3: 38.3
# Start training for epoch: 4 of 100
# Accuracy on training data for epoch 4: 51.55
# Accuracy on testing data for epoch 4: 46.7
# Start training for epoch: 5 of 100
# Accuracy on training data for epoch 5: 63.05
# Accuracy on testing data for epoch 5: 57.75
# Start training for epoch: 6 of 100
# Accuracy on training data for epoch 6: 65.6
# Accuracy on testing data for epoch 6: 63.55
# Start training for epoch: 7 of 100
# Accuracy on training data for epoch 7: 60.15
# Accuracy on testing data for epoch 7: 56.15
# Start training for epoch: 8 of 100
# Accuracy on training data for epoch 8: 50.75
# Accuracy on testing data for epoch 8: 48.3
# Start training for epoch: 9 of 100
# Accuracy on training data for epoch 9: 74.25
# Accuracy on testing data for epoch 9: 65.95
# Start training for epoch: 10 of 100
# Accuracy on training data for epoch 10: 75.15
# Accuracy on testing data for epoch 10: 66.3
# Start training for epoch: 11 of 100
# Accuracy on training data for epoch 11: 73.35
# Accuracy on testing data for epoch 11: 65.35
# Start training for epoch: 12 of 100
# Accuracy on training data for epoch 12: 79.65
# Accuracy on testing data for epoch 12: 71.75
# Start training for epoch: 13 of 100
# Accuracy on training data for epoch 13: 77.2
# Accuracy on testing data for epoch 13: 69.5
# Start training for epoch: 14 of 100
# Accuracy on training data for epoch 14: 78.75
# Accuracy on testing data for epoch 14: 70.7
# Start training for epoch: 15 of 100
# Accuracy on training data for epoch 15: 78.55
# Accuracy on testing data for epoch 15: 69.3
# Start training for epoch: 16 of 100
# Accuracy on training data for epoch 16: 81.85
# Accuracy on testing data for epoch 16: 73.1
# Start training for epoch: 17 of 100
# Accuracy on training data for epoch 17: 82.4
# Accuracy on testing data for epoch 17: 70.75
# Start training for epoch: 18 of 100
# Accuracy on training data for epoch 18: 84.45
# Accuracy on testing data for epoch 18: 74.75
# Start training for epoch: 19 of 100
# Accuracy on training data for epoch 19: 83.65
# Accuracy on testing data for epoch 19: 75.75
# Start training for epoch: 20 of 100
# Accuracy on training data for epoch 20: 78.85
# Accuracy on testing data for epoch 20: 68.05
# Start training for epoch: 21 of 100
# Accuracy on training data for epoch 21: 83.1
# Accuracy on testing data for epoch 21: 73.7
# Start training for epoch: 22 of 100
# Accuracy on training data for epoch 22: 86.1
# Accuracy on testing data for epoch 22: 79.0
# Start training for epoch: 23 of 100
# Accuracy on training data for epoch 23: 85.0
# Accuracy on testing data for epoch 23: 75.15
# Start training for epoch: 24 of 100
# Accuracy on training data for epoch 24: 87.7
# Accuracy on testing data for epoch 24: 79.65
# Start training for epoch: 25 of 100
# Accuracy on training data for epoch 25: 87.2
# Accuracy on testing data for epoch 25: 79.15
# Start training for epoch: 26 of 100
# Accuracy on training data for epoch 26: 74.45
# Accuracy on testing data for epoch 26: 68.1
# Start training for epoch: 27 of 100
# Accuracy on training data for epoch 27: 81.4
# Accuracy on testing data for epoch 27: 73.35
# Start training for epoch: 28 of 100
# Accuracy on training data for epoch 28: 85.8
# Accuracy on testing data for epoch 28: 78.05
# Start training for epoch: 29 of 100
# Accuracy on training data for epoch 29: 83.95
# Accuracy on testing data for epoch 29: 73.55
# Start training for epoch: 30 of 100
# Accuracy on training data for epoch 30: 89.9
# Accuracy on testing data for epoch 30: 81.7
# Start training for epoch: 31 of 100
# Accuracy on training data for epoch 31: 88.9
# Accuracy on testing data for epoch 31: 80.75
# Start training for epoch: 32 of 100
# Accuracy on training data for epoch 32: 88.75
# Accuracy on testing data for epoch 32: 80.5
# Start training for epoch: 33 of 100
# Accuracy on training data for epoch 33: 86.65
# Accuracy on testing data for epoch 33: 78.2
# Start training for epoch: 34 of 100
# Accuracy on training data for epoch 34: 87.75
# Accuracy on testing data for epoch 34: 79.95
# Start training for epoch: 35 of 100
# Accuracy on training data for epoch 35: 86.2
# Accuracy on testing data for epoch 35: 77.85
# Start training for epoch: 36 of 100
# Accuracy on training data for epoch 36: 88.3
# Accuracy on testing data for epoch 36: 78.5
# Start training for epoch: 37 of 100
# Accuracy on training data for epoch 37: 89.5
# Accuracy on testing data for epoch 37: 82.0
# Start training for epoch: 38 of 100
# Accuracy on training data for epoch 38: 89.45
# Accuracy on testing data for epoch 38: 80.25
# Start training for epoch: 39 of 100
# Accuracy on training data for epoch 39: 90.25
# Accuracy on testing data for epoch 39: 81.9
# Start training for epoch: 40 of 100
# Accuracy on training data for epoch 40: 89.25
# Accuracy on testing data for epoch 40: 80.0
# Start training for epoch: 41 of 100
# Accuracy on training data for epoch 41: 86.9
# Accuracy on testing data for epoch 41: 76.55
# Start training for epoch: 42 of 100
# Accuracy on training data for epoch 42: 88.0
# Accuracy on testing data for epoch 42: 78.4
# Start training for epoch: 43 of 100
# Accuracy on training data for epoch 43: 88.0
# Accuracy on testing data for epoch 43: 78.3
# Start training for epoch: 44 of 100
# Accuracy on training data for epoch 44: 90.05
# Accuracy on testing data for epoch 44: 80.95
# Start training for epoch: 45 of 100
# Accuracy on training data for epoch 45: 85.75
# Accuracy on testing data for epoch 45: 76.15
# Start training for epoch: 46 of 100
# Accuracy on training data for epoch 46: 89.35
# Accuracy on testing data for epoch 46: 79.5
# Start training for epoch: 47 of 100
# Accuracy on training data for epoch 47: 87.05
# Accuracy on testing data for epoch 47: 76.65
# Start training for epoch: 48 of 100
# Accuracy on training data for epoch 48: 84.3
# Accuracy on testing data for epoch 48: 72.25
# Start training for epoch: 49 of 100
# Accuracy on training data for epoch 49: 89.5
# Accuracy on testing data for epoch 49: 77.55
# Start training for epoch: 50 of 100
# Accuracy on training data for epoch 50: 93.1
# Accuracy on testing data for epoch 50: 82.9
# Start training for epoch: 51 of 100
# Accuracy on training data for epoch 51: 91.55
# Accuracy on testing data for epoch 51: 82.3
# Start training for epoch: 52 of 100
# Accuracy on training data for epoch 52: 90.2
# Accuracy on testing data for epoch 52: 81.5
# Start training for epoch: 53 of 100
# Accuracy on training data for epoch 53: 92.25
# Accuracy on testing data for epoch 53: 83.05
# Start training for epoch: 54 of 100
# Accuracy on training data for epoch 54: 87.9
# Accuracy on testing data for epoch 54: 78.65
# Start training for epoch: 55 of 100
# Accuracy on training data for epoch 55: 87.7
# Accuracy on testing data for epoch 55: 77.25
# Start training for epoch: 56 of 100
# Accuracy on training data for epoch 56: 87.6
# Accuracy on testing data for epoch 56: 78.55
# Start training for epoch: 57 of 100
# Accuracy on training data for epoch 57: 91.1
# Accuracy on testing data for epoch 57: 82.5
# Start training for epoch: 58 of 100
# Accuracy on training data for epoch 58: 90.4
# Accuracy on testing data for epoch 58: 81.15
# Start training for epoch: 59 of 100
# Accuracy on training data for epoch 59: 89.3
# Accuracy on testing data for epoch 59: 80.15
# Start training for epoch: 60 of 100
# Accuracy on training data for epoch 60: 91.25
# Accuracy on testing data for epoch 60: 80.65
# Start training for epoch: 61 of 100
# Accuracy on training data for epoch 61: 89.4
# Accuracy on testing data for epoch 61: 78.45
# Start training for epoch: 62 of 100
# Accuracy on training data for epoch 62: 91.1
# Accuracy on testing data for epoch 62: 80.05
# Start training for epoch: 63 of 100
# Accuracy on training data for epoch 63: 90.2
# Accuracy on testing data for epoch 63: 79.45
# Start training for epoch: 64 of 100
# Accuracy on training data for epoch 64: 91.5
# Accuracy on testing data for epoch 64: 80.65
# Start training for epoch: 65 of 100
# Accuracy on training data for epoch 65: 93.35
# Accuracy on testing data for epoch 65: 82.0
# Start training for epoch: 66 of 100
# Accuracy on training data for epoch 66: 91.7
# Accuracy on testing data for epoch 66: 80.35
# Start training for epoch: 67 of 100
# Accuracy on training data for epoch 67: 90.4
# Accuracy on testing data for epoch 67: 79.5
# Start training for epoch: 68 of 100
# Accuracy on training data for epoch 68: 88.15
# Accuracy on testing data for epoch 68: 78.4
# Start training for epoch: 69 of 100
# Accuracy on training data for epoch 69: 92.95
# Accuracy on testing data for epoch 69: 82.8
# Start training for epoch: 70 of 100
# Accuracy on training data for epoch 70: 92.55
# Accuracy on testing data for epoch 70: 81.85
# Start training for epoch: 71 of 100
# Accuracy on training data for epoch 71: 90.75
# Accuracy on testing data for epoch 71: 80.45
# Start training for epoch: 72 of 100
# Accuracy on training data for epoch 72: 90.2
# Accuracy on testing data for epoch 72: 80.75
# Start training for epoch: 73 of 100
# Accuracy on training data for epoch 73: 85.45
# Accuracy on testing data for epoch 73: 75.55
# Start training for epoch: 74 of 100
# Accuracy on training data for epoch 74: 93.4
# Accuracy on testing data for epoch 74: 83.9
# Start training for epoch: 75 of 100
# Accuracy on training data for epoch 75: 91.15
# Accuracy on testing data for epoch 75: 79.45
# Start training for epoch: 76 of 100
# Accuracy on training data for epoch 76: 81.0
# Accuracy on testing data for epoch 76: 69.6
# Start training for epoch: 77 of 100
# Accuracy on training data for epoch 77: 84.75
# Accuracy on testing data for epoch 77: 74.05
# Start training for epoch: 78 of 100
# Accuracy on training data for epoch 78: 93.75
# Accuracy on testing data for epoch 78: 83.3
# Start training for epoch: 79 of 100
# Accuracy on training data for epoch 79: 92.2
# Accuracy on testing data for epoch 79: 82.8
# Start training for epoch: 80 of 100
# Accuracy on training data for epoch 80: 91.8
# Accuracy on testing data for epoch 80: 80.95
# Start training for epoch: 81 of 100
# Accuracy on training data for epoch 81: 92.9
# Accuracy on testing data for epoch 81: 81.25
# Start training for epoch: 82 of 100
# Accuracy on training data for epoch 82: 92.2
# Accuracy on testing data for epoch 82: 82.3
# Start training for epoch: 83 of 100
# Accuracy on training data for epoch 83: 92.5
# Accuracy on testing data for epoch 83: 81.5
# Start training for epoch: 84 of 100
# Accuracy on training data for epoch 84: 91.2
# Accuracy on testing data for epoch 84: 81.4
# Start training for epoch: 85 of 100
# Accuracy on training data for epoch 85: 86.9
# Accuracy on testing data for epoch 85: 78.05
# Start training for epoch: 86 of 100
# Accuracy on training data for epoch 86: 93.15
# Accuracy on testing data for epoch 86: 83.15
# Start training for epoch: 87 of 100
# Accuracy on training data for epoch 87: 94.2
# Accuracy on testing data for epoch 87: 82.6
# Start training for epoch: 88 of 100
# Accuracy on training data for epoch 88: 93.6
# Accuracy on testing data for epoch 88: 83.4
# Start training for epoch: 89 of 100
# Accuracy on training data for epoch 89: 92.95
# Accuracy on testing data for epoch 89: 81.1
# Start training for epoch: 90 of 100
# Accuracy on training data for epoch 90: 94.95
# Accuracy on testing data for epoch 90: 82.75
# Start training for epoch: 91 of 100
# Accuracy on training data for epoch 91: 92.7
# Accuracy on testing data for epoch 91: 81.1
# Start training for epoch: 92 of 100
# Accuracy on training data for epoch 92: 91.0
# Accuracy on testing data for epoch 92: 79.85
# Start training for epoch: 93 of 100
# Accuracy on training data for epoch 93: 94.15
# Accuracy on testing data for epoch 93: 83.4
# Start training for epoch: 94 of 100
# Accuracy on training data for epoch 94: 93.2
# Accuracy on testing data for epoch 94: 81.15
# Start training for epoch: 95 of 100
# Accuracy on training data for epoch 95: 91.0
# Accuracy on testing data for epoch 95: 79.9
# Start training for epoch: 96 of 100
# Accuracy on training data for epoch 96: 90.45
# Accuracy on testing data for epoch 96: 79.95
# Start training for epoch: 97 of 100
# Accuracy on training data for epoch 97: 93.4
# Accuracy on testing data for epoch 97: 83.05
# Start training for epoch: 98 of 100
# Accuracy on training data for epoch 98: 86.9
# Accuracy on testing data for epoch 98: 78.7
# Start training for epoch: 99 of 100
# Accuracy on training data for epoch 99: 92.65
# Accuracy on testing data for epoch 99: 83.25
# Start training for epoch: 100 of 100
# Accuracy on training data for epoch 100: 93.2
# Accuracy on testing data for epoch 100: 81.85

# %% [markdown]
# ### [Testing dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 70% neuron retention; 200 epochs
#
# ---
#
#
# Results hold on testing data subset as well, run with current setting on whole training and testing datasets with epochs=200

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 200
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.70

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training, testing, params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 200
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.7
# Start training for epoch: 1 of 200
# Accuracy on training data for epoch 1: 87.38
# Accuracy on testing data for epoch 1: 88.19
# Start training for epoch: 2 of 200
# Accuracy on training data for epoch 2: 88.86
# Accuracy on testing data for epoch 2: 88.87
# Start training for epoch: 3 of 200
# Accuracy on training data for epoch 3: 88.39
# Accuracy on testing data for epoch 3: 88.71
# Start training for epoch: 4 of 200
# Accuracy on training data for epoch 4: 85.23
# Accuracy on testing data for epoch 4: 85.8
# Start training for epoch: 5 of 200
# Accuracy on training data for epoch 5: 90.48
# Accuracy on testing data for epoch 5: 90.37
# Start training for epoch: 6 of 200
# Accuracy on training data for epoch 6: 91.53
# Accuracy on testing data for epoch 6: 91.55
# Start training for epoch: 7 of 200
# Accuracy on training data for epoch 7: 88.77
# Accuracy on testing data for epoch 7: 88.71
# Start training for epoch: 8 of 200
# Accuracy on training data for epoch 8: 93.53
# Accuracy on testing data for epoch 8: 93.24
# Start training for epoch: 9 of 200
# Accuracy on training data for epoch 9: 89.37
# Accuracy on testing data for epoch 9: 89.09
# Start training for epoch: 10 of 200
# Accuracy on training data for epoch 10: 86.77
# Accuracy on testing data for epoch 10: 86.38
# Start training for epoch: 11 of 200
# Accuracy on training data for epoch 11: 87.0
# Accuracy on testing data for epoch 11: 86.18
# Start training for epoch: 12 of 200
# Accuracy on training data for epoch 12: 90.61
# Accuracy on testing data for epoch 12: 90.19
# Start training for epoch: 13 of 200
# Accuracy on training data for epoch 13: 89.71
# Accuracy on testing data for epoch 13: 88.82
# Start training for epoch: 14 of 200
# Accuracy on training data for epoch 14: 92.38
# Accuracy on testing data for epoch 14: 92.18
# Start training for epoch: 15 of 200
# Accuracy on training data for epoch 15: 94.72
# Accuracy on testing data for epoch 15: 94.35
# Start training for epoch: 16 of 200
# Accuracy on training data for epoch 16: 94.92
# Accuracy on testing data for epoch 16: 94.42
# Start training for epoch: 17 of 200
# Accuracy on training data for epoch 17: 94.8
# Accuracy on testing data for epoch 17: 94.56
# Start training for epoch: 18 of 200
# Accuracy on training data for epoch 18: 92.41
# Accuracy on testing data for epoch 18: 92.13
# Start training for epoch: 19 of 200
# Accuracy on training data for epoch 19: 93.47
# Accuracy on testing data for epoch 19: 92.95
# Start training for epoch: 20 of 200
# Accuracy on training data for epoch 20: 95.13
# Accuracy on testing data for epoch 20: 95.03
# Start training for epoch: 21 of 200
# Accuracy on training data for epoch 21: 94.61
# Accuracy on testing data for epoch 21: 94.6
# Start training for epoch: 22 of 200
# Accuracy on training data for epoch 22: 94.07
# Accuracy on testing data for epoch 22: 93.88
# Start training for epoch: 23 of 200
# Accuracy on training data for epoch 23: 92.59
# Accuracy on testing data for epoch 23: 92.56
# Start training for epoch: 24 of 200
# Accuracy on training data for epoch 24: 93.91
# Accuracy on testing data for epoch 24: 93.69
# Start training for epoch: 25 of 200
# Accuracy on training data for epoch 25: 95.6
# Accuracy on testing data for epoch 25: 95.1
# Start training for epoch: 26 of 200
# Accuracy on training data for epoch 26: 95.16
# Accuracy on testing data for epoch 26: 94.71
# Start training for epoch: 27 of 200
# Accuracy on training data for epoch 27: 93.92
# Accuracy on testing data for epoch 27: 93.79
# Start training for epoch: 28 of 200
# Accuracy on training data for epoch 28: 91.99
# Accuracy on testing data for epoch 28: 92.31
# Start training for epoch: 29 of 200
# Accuracy on training data for epoch 29: 94.82
# Accuracy on testing data for epoch 29: 94.23
# Start training for epoch: 30 of 200
# Accuracy on training data for epoch 30: 92.22
# Accuracy on testing data for epoch 30: 91.95
# Start training for epoch: 31 of 200
# Accuracy on training data for epoch 31: 91.37
# Accuracy on testing data for epoch 31: 90.83
# Start training for epoch: 32 of 200
# Accuracy on training data for epoch 32: 96.37
# Accuracy on testing data for epoch 32: 95.94
# Start training for epoch: 33 of 200
# Accuracy on training data for epoch 33: 96.09
# Accuracy on testing data for epoch 33: 95.5
# Start training for epoch: 34 of 200
# Accuracy on training data for epoch 34: 95.63
# Accuracy on testing data for epoch 34: 95.17
# Start training for epoch: 35 of 200
# Accuracy on training data for epoch 35: 94.68
# Accuracy on testing data for epoch 35: 94.5
# Start training for epoch: 36 of 200
# Accuracy on training data for epoch 36: 96.08
# Accuracy on testing data for epoch 36: 95.16
# Start training for epoch: 37 of 200
# Accuracy on training data for epoch 37: 93.06
# Accuracy on testing data for epoch 37: 92.44
# Start training for epoch: 38 of 200
# Accuracy on training data for epoch 38: 93.82
# Accuracy on testing data for epoch 38: 93.55
# Start training for epoch: 39 of 200
# Accuracy on training data for epoch 39: 96.69
# Accuracy on testing data for epoch 39: 95.98
# Start training for epoch: 40 of 200
# Accuracy on training data for epoch 40: 95.13
# Accuracy on testing data for epoch 40: 94.07
# Start training for epoch: 41 of 200
# Accuracy on training data for epoch 41: 96.27
# Accuracy on testing data for epoch 41: 95.67
# Start training for epoch: 42 of 200
# Accuracy on training data for epoch 42: 94.46
# Accuracy on testing data for epoch 42: 93.72
# Start training for epoch: 43 of 200
# Accuracy on training data for epoch 43: 95.51
# Accuracy on testing data for epoch 43: 95.23
# Start training for epoch: 44 of 200
# Accuracy on training data for epoch 44: 96.75
# Accuracy on testing data for epoch 44: 96.2
# Start training for epoch: 45 of 200
# Accuracy on training data for epoch 45: 94.62
# Accuracy on testing data for epoch 45: 93.79
# Start training for epoch: 46 of 200
# Accuracy on training data for epoch 46: 94.68
# Accuracy on testing data for epoch 46: 94.27
# Start training for epoch: 47 of 200
# Accuracy on training data for epoch 47: 95.05
# Accuracy on testing data for epoch 47: 94.31
# Start training for epoch: 48 of 200
# Accuracy on training data for epoch 48: 97.1
# Accuracy on testing data for epoch 48: 96.44
# Start training for epoch: 49 of 200
# Accuracy on training data for epoch 49: 96.62
# Accuracy on testing data for epoch 49: 95.99
# Start training for epoch: 50 of 200
# Accuracy on training data for epoch 50: 97.24
# Accuracy on testing data for epoch 50: 96.32
# Start training for epoch: 51 of 200
# Accuracy on training data for epoch 51: 96.65
# Accuracy on testing data for epoch 51: 95.68
# Start training for epoch: 52 of 200
# Accuracy on training data for epoch 52: 95.3
# Accuracy on testing data for epoch 52: 94.97
# Start training for epoch: 53 of 200
# Accuracy on training data for epoch 53: 96.03
# Accuracy on testing data for epoch 53: 95.49
# Start training for epoch: 54 of 200
# Accuracy on training data for epoch 54: 96.0
# Accuracy on testing data for epoch 54: 95.69
# Start training for epoch: 55 of 200
# Accuracy on training data for epoch 55: 96.37
# Accuracy on testing data for epoch 55: 95.71
# Start training for epoch: 56 of 200
# Accuracy on training data for epoch 56: 96.92
# Accuracy on testing data for epoch 56: 96.25
# Start training for epoch: 57 of 200
# Accuracy on training data for epoch 57: 95.37
# Accuracy on testing data for epoch 57: 94.71
# Start training for epoch: 58 of 200
# Accuracy on training data for epoch 58: 94.93
# Accuracy on testing data for epoch 58: 94.82
# Start training for epoch: 59 of 200
# Accuracy on training data for epoch 59: 96.51
# Accuracy on testing data for epoch 59: 96.01
# Start training for epoch: 60 of 200
# Accuracy on training data for epoch 60: 97.05
# Accuracy on testing data for epoch 60: 96.28
# Start training for epoch: 61 of 200
# Accuracy on training data for epoch 61: 96.37
# Accuracy on testing data for epoch 61: 95.91
# Start training for epoch: 62 of 200
# Accuracy on training data for epoch 62: 97.75
# Accuracy on testing data for epoch 62: 97.01
# Start training for epoch: 63 of 200
# Accuracy on training data for epoch 63: 97.89
# Accuracy on testing data for epoch 63: 96.97
# Start training for epoch: 64 of 200
# Accuracy on training data for epoch 64: 96.91
# Accuracy on testing data for epoch 64: 96.12
# Start training for epoch: 65 of 200
# Accuracy on training data for epoch 65: 96.46
# Accuracy on testing data for epoch 65: 95.52
# Start training for epoch: 66 of 200
# Accuracy on training data for epoch 66: 97.6
# Accuracy on testing data for epoch 66: 96.8
# Start training for epoch: 67 of 200
# Accuracy on training data for epoch 67: 96.15
# Accuracy on testing data for epoch 67: 95.47
# Start training for epoch: 68 of 200
# Accuracy on training data for epoch 68: 96.18
# Accuracy on testing data for epoch 68: 95.32
# Start training for epoch: 69 of 200
# Accuracy on training data for epoch 69: 95.66
# Accuracy on testing data for epoch 69: 94.82
# Start training for epoch: 70 of 200
# Accuracy on training data for epoch 70: 95.97
# Accuracy on testing data for epoch 70: 94.9
# Start training for epoch: 71 of 200
# Accuracy on training data for epoch 71: 97.12
# Accuracy on testing data for epoch 71: 96.12
# Start training for epoch: 72 of 200
# Accuracy on training data for epoch 72: 97.05
# Accuracy on testing data for epoch 72: 96.01
# Start training for epoch: 73 of 200
# Accuracy on training data for epoch 73: 95.95
# Accuracy on testing data for epoch 73: 95.11
# Start training for epoch: 74 of 200
# Accuracy on training data for epoch 74: 96.48
# Accuracy on testing data for epoch 74: 95.47
# Start training for epoch: 75 of 200
# Accuracy on training data for epoch 75: 96.14
# Accuracy on testing data for epoch 75: 94.69
# Start training for epoch: 76 of 200
# Accuracy on training data for epoch 76: 97.37
# Accuracy on testing data for epoch 76: 96.4
# Start training for epoch: 77 of 200
# Accuracy on training data for epoch 77: 98.0
# Accuracy on testing data for epoch 77: 97.02
# Start training for epoch: 78 of 200
# Accuracy on training data for epoch 78: 96.86
# Accuracy on testing data for epoch 78: 95.98
# Start training for epoch: 79 of 200
# Accuracy on training data for epoch 79: 97.4
# Accuracy on testing data for epoch 79: 96.3
# Start training for epoch: 80 of 200
# Accuracy on training data for epoch 80: 96.91
# Accuracy on testing data for epoch 80: 95.9
# Start training for epoch: 81 of 200
# Accuracy on training data for epoch 81: 96.89
# Accuracy on testing data for epoch 81: 95.8
# Start training for epoch: 82 of 200
# Accuracy on training data for epoch 82: 95.49
# Accuracy on testing data for epoch 82: 94.66
# Start training for epoch: 83 of 200
# Accuracy on training data for epoch 83: 97.26
# Accuracy on testing data for epoch 83: 96.11
# Start training for epoch: 84 of 200
# Accuracy on training data for epoch 84: 96.59
# Accuracy on testing data for epoch 84: 95.35
# Start training for epoch: 85 of 200
# Accuracy on training data for epoch 85: 96.49
# Accuracy on testing data for epoch 85: 95.61
# Start training for epoch: 86 of 200
# Accuracy on training data for epoch 86: 96.6
# Accuracy on testing data for epoch 86: 95.68
# Start training for epoch: 87 of 200
# Accuracy on training data for epoch 87: 97.43
# Accuracy on testing data for epoch 87: 96.48
# Start training for epoch: 88 of 200
# Accuracy on training data for epoch 88: 96.36
# Accuracy on testing data for epoch 88: 95.69
# Start training for epoch: 89 of 200
# Accuracy on training data for epoch 89: 96.85
# Accuracy on testing data for epoch 89: 96.0
# Start training for epoch: 90 of 200
# Accuracy on training data for epoch 90: 96.78
# Accuracy on testing data for epoch 90: 95.72
# Start training for epoch: 91 of 200
# Accuracy on training data for epoch 91: 97.23
# Accuracy on testing data for epoch 91: 96.17
# Start training for epoch: 92 of 200
# Accuracy on training data for epoch 92: 97.17
# Accuracy on testing data for epoch 92: 96.3
# Start training for epoch: 93 of 200
# Accuracy on training data for epoch 93: 96.6
# Accuracy on testing data for epoch 93: 95.92
# Start training for epoch: 94 of 200
# Accuracy on training data for epoch 94: 96.15
# Accuracy on testing data for epoch 94: 95.37
# Start training for epoch: 95 of 200
# Accuracy on training data for epoch 95: 95.06
# Accuracy on testing data for epoch 95: 94.64
# Start training for epoch: 96 of 200
# Accuracy on training data for epoch 96: 94.54
# Accuracy on testing data for epoch 96: 93.65
# Start training for epoch: 97 of 200
# Accuracy on training data for epoch 97: 96.4
# Accuracy on testing data for epoch 97: 95.66
# Start training for epoch: 98 of 200
# Accuracy on training data for epoch 98: 97.29
# Accuracy on testing data for epoch 98: 96.21
# Start training for epoch: 99 of 200
# Accuracy on training data for epoch 99: 97.23
# Accuracy on testing data for epoch 99: 95.86
# Start training for epoch: 100 of 200
# Accuracy on training data for epoch 100: 96.52
# Accuracy on testing data for epoch 100: 95.28
# Start training for epoch: 101 of 200
# Accuracy on training data for epoch 101: 93.66
# Accuracy on testing data for epoch 101: 92.6
# Start training for epoch: 102 of 200
# Accuracy on training data for epoch 102: 95.73
# Accuracy on testing data for epoch 102: 94.85
# Start training for epoch: 103 of 200
# Accuracy on training data for epoch 103: 96.28
# Accuracy on testing data for epoch 103: 95.75
# Start training for epoch: 104 of 200
# Accuracy on training data for epoch 104: 96.56
# Accuracy on testing data for epoch 104: 95.61
# Start training for epoch: 105 of 200
# Accuracy on training data for epoch 105: 96.99
# Accuracy on testing data for epoch 105: 96.08
# Start training for epoch: 106 of 200
# Accuracy on training data for epoch 106: 94.45
# Accuracy on testing data for epoch 106: 93.24
# Start training for epoch: 107 of 200
# Accuracy on training data for epoch 107: 96.35
# Accuracy on testing data for epoch 107: 94.99
# Start training for epoch: 108 of 200
# Accuracy on training data for epoch 108: 94.26
# Accuracy on testing data for epoch 108: 92.92
# Start training for epoch: 109 of 200
# Accuracy on training data for epoch 109: 97.26
# Accuracy on testing data for epoch 109: 96.08
# Start training for epoch: 110 of 200
# Accuracy on training data for epoch 110: 96.97
# Accuracy on testing data for epoch 110: 96.12
# Start training for epoch: 111 of 200
# Accuracy on training data for epoch 111: 98.06
# Accuracy on testing data for epoch 111: 96.92
# Start training for epoch: 112 of 200
# Accuracy on training data for epoch 112: 97.71
# Accuracy on testing data for epoch 112: 96.55
# Start training for epoch: 113 of 200
# Accuracy on training data for epoch 113: 97.85
# Accuracy on testing data for epoch 113: 96.74
# Start training for epoch: 114 of 200
# Accuracy on training data for epoch 114: 98.04
# Accuracy on testing data for epoch 114: 96.74
# Start training for epoch: 115 of 200
# Accuracy on training data for epoch 115: 98.27
# Accuracy on testing data for epoch 115: 97.39
# Start training for epoch: 116 of 200
# Accuracy on training data for epoch 116: 97.27
# Accuracy on testing data for epoch 116: 96.56
# Start training for epoch: 117 of 200
# Accuracy on training data for epoch 117: 97.46
# Accuracy on testing data for epoch 117: 96.28
# Start training for epoch: 118 of 200
# Accuracy on training data for epoch 118: 96.36
# Accuracy on testing data for epoch 118: 95.35
# Start training for epoch: 119 of 200
# Accuracy on training data for epoch 119: 97.0
# Accuracy on testing data for epoch 119: 95.67
# Start training for epoch: 120 of 200
# Accuracy on training data for epoch 120: 95.17
# Accuracy on testing data for epoch 120: 93.58
# Start training for epoch: 121 of 200
# Accuracy on training data for epoch 121: 95.59
# Accuracy on testing data for epoch 121: 94.33
# Start training for epoch: 122 of 200
# Accuracy on training data for epoch 122: 93.56
# Accuracy on testing data for epoch 122: 92.53
# Start training for epoch: 123 of 200
# Accuracy on training data for epoch 123: 95.52
# Accuracy on testing data for epoch 123: 94.02
# Start training for epoch: 124 of 200
# Accuracy on training data for epoch 124: 96.31
# Accuracy on testing data for epoch 124: 95.04
# Start training for epoch: 125 of 200
# Accuracy on training data for epoch 125: 97.82
# Accuracy on testing data for epoch 125: 96.78
# Start training for epoch: 126 of 200
# Accuracy on training data for epoch 126: 97.43
# Accuracy on testing data for epoch 126: 96.48
# Start training for epoch: 127 of 200
# Accuracy on training data for epoch 127: 97.63
# Accuracy on testing data for epoch 127: 96.72
# Start training for epoch: 128 of 200
# Accuracy on training data for epoch 128: 97.26
# Accuracy on testing data for epoch 128: 96.16
# Start training for epoch: 129 of 200
# Accuracy on training data for epoch 129: 95.5
# Accuracy on testing data for epoch 129: 94.27
# Start training for epoch: 130 of 200
# Accuracy on training data for epoch 130: 96.12
# Accuracy on testing data for epoch 130: 94.95
# Start training for epoch: 131 of 200
# Accuracy on training data for epoch 131: 96.42
# Accuracy on testing data for epoch 131: 95.14
# Start training for epoch: 132 of 200
# Accuracy on training data for epoch 132: 96.06
# Accuracy on testing data for epoch 132: 95.22
# Start training for epoch: 133 of 200
# Accuracy on training data for epoch 133: 95.53
# Accuracy on testing data for epoch 133: 94.43
# Start training for epoch: 134 of 200
# Accuracy on training data for epoch 134: 97.53
# Accuracy on testing data for epoch 134: 96.2
# Start training for epoch: 135 of 200
# Accuracy on training data for epoch 135: 97.23
# Accuracy on testing data for epoch 135: 95.93
# Start training for epoch: 136 of 200
# Accuracy on training data for epoch 136: 97.44
# Accuracy on testing data for epoch 136: 96.12
# Start training for epoch: 137 of 200
# Accuracy on training data for epoch 137: 97.0
# Accuracy on testing data for epoch 137: 95.75
# Start training for epoch: 138 of 200
# Accuracy on training data for epoch 138: 96.33
# Accuracy on testing data for epoch 138: 95.07
# Start training for epoch: 139 of 200
# Accuracy on training data for epoch 139: 96.81
# Accuracy on testing data for epoch 139: 95.62
# Start training for epoch: 140 of 200
# Accuracy on training data for epoch 140: 97.0
# Accuracy on testing data for epoch 140: 96.21
# Start training for epoch: 141 of 200
# Accuracy on training data for epoch 141: 98.4
# Accuracy on testing data for epoch 141: 97.5
# Start training for epoch: 142 of 200
# Accuracy on training data for epoch 142: 95.79
# Accuracy on testing data for epoch 142: 94.38
# Start training for epoch: 143 of 200
# Accuracy on training data for epoch 143: 96.92
# Accuracy on testing data for epoch 143: 95.75
# Start training for epoch: 144 of 200
# Accuracy on training data for epoch 144: 97.34
# Accuracy on testing data for epoch 144: 96.42
# Start training for epoch: 145 of 200
# Accuracy on training data for epoch 145: 96.4
# Accuracy on testing data for epoch 145: 95.39
# Start training for epoch: 146 of 200
# Accuracy on training data for epoch 146: 97.96
# Accuracy on testing data for epoch 146: 96.63
# Start training for epoch: 147 of 200
# Accuracy on training data for epoch 147: 97.8
# Accuracy on testing data for epoch 147: 96.91
# Start training for epoch: 148 of 200
# Accuracy on training data for epoch 148: 98.12
# Accuracy on testing data for epoch 148: 97.0
# Start training for epoch: 149 of 200
# Accuracy on training data for epoch 149: 97.95
# Accuracy on testing data for epoch 149: 97.04
# Start training for epoch: 150 of 200
# Accuracy on training data for epoch 150: 97.79
# Accuracy on testing data for epoch 150: 96.74
# Start training for epoch: 151 of 200
# Accuracy on training data for epoch 151: 97.49
# Accuracy on testing data for epoch 151: 96.69
# Start training for epoch: 152 of 200
# Accuracy on training data for epoch 152: 96.17
# Accuracy on testing data for epoch 152: 95.34
# Start training for epoch: 153 of 200
# Accuracy on training data for epoch 153: 96.2
# Accuracy on testing data for epoch 153: 95.22
# Start training for epoch: 154 of 200
# Accuracy on training data for epoch 154: 97.21
# Accuracy on testing data for epoch 154: 96.24
# Start training for epoch: 155 of 200
# Accuracy on training data for epoch 155: 97.2
# Accuracy on testing data for epoch 155: 96.16
# Start training for epoch: 156 of 200
# Accuracy on training data for epoch 156: 97.05
# Accuracy on testing data for epoch 156: 96.14
# Start training for epoch: 157 of 200
# Accuracy on training data for epoch 157: 97.7
# Accuracy on testing data for epoch 157: 96.68
# Start training for epoch: 158 of 200
# Accuracy on training data for epoch 158: 98.45
# Accuracy on testing data for epoch 158: 97.42
# Start training for epoch: 159 of 200
# Accuracy on training data for epoch 159: 97.59
# Accuracy on testing data for epoch 159: 96.17
# Start training for epoch: 160 of 200
# Accuracy on training data for epoch 160: 98.51
# Accuracy on testing data for epoch 160: 97.38
# Start training for epoch: 161 of 200
# Accuracy on training data for epoch 161: 98.14
# Accuracy on testing data for epoch 161: 97.14
# Start training for epoch: 162 of 200
# Accuracy on training data for epoch 162: 94.9
# Accuracy on testing data for epoch 162: 93.58
# Start training for epoch: 163 of 200
# Accuracy on training data for epoch 163: 94.33
# Accuracy on testing data for epoch 163: 93.38
# Start training for epoch: 164 of 200
# Accuracy on training data for epoch 164: 97.29
# Accuracy on testing data for epoch 164: 95.98
# Start training for epoch: 165 of 200
# Accuracy on training data for epoch 165: 98.04
# Accuracy on testing data for epoch 165: 96.87
# Start training for epoch: 166 of 200
# Accuracy on training data for epoch 166: 98.23
# Accuracy on testing data for epoch 166: 96.86
# Start training for epoch: 167 of 200
# Accuracy on training data for epoch 167: 97.34
# Accuracy on testing data for epoch 167: 96.16
# Start training for epoch: 168 of 200
# Accuracy on training data for epoch 168: 97.76
# Accuracy on testing data for epoch 168: 96.65
# Start training for epoch: 169 of 200
# Accuracy on training data for epoch 169: 96.06
# Accuracy on testing data for epoch 169: 94.68
# Start training for epoch: 170 of 200
# Accuracy on training data for epoch 170: 96.33
# Accuracy on testing data for epoch 170: 95.13
# Start training for epoch: 171 of 200
# Accuracy on training data for epoch 171: 93.84
# Accuracy on testing data for epoch 171: 92.68
# Start training for epoch: 172 of 200
# Accuracy on training data for epoch 172: 97.36
# Accuracy on testing data for epoch 172: 96.01
# Start training for epoch: 173 of 200
# Accuracy on training data for epoch 173: 97.9
# Accuracy on testing data for epoch 173: 96.7
# Start training for epoch: 174 of 200
# Accuracy on training data for epoch 174: 97.65
# Accuracy on testing data for epoch 174: 96.5
# Start training for epoch: 175 of 200
# Accuracy on training data for epoch 175: 97.83
# Accuracy on testing data for epoch 175: 96.79
# Start training for epoch: 176 of 200
# Accuracy on training data for epoch 176: 98.33
# Accuracy on testing data for epoch 176: 97.36
# Start training for epoch: 177 of 200
# Accuracy on training data for epoch 177: 97.61
# Accuracy on testing data for epoch 177: 96.59
# Start training for epoch: 178 of 200
# Accuracy on training data for epoch 178: 97.63
# Accuracy on testing data for epoch 178: 96.85
# Start training for epoch: 179 of 200
# Accuracy on training data for epoch 179: 97.45
# Accuracy on testing data for epoch 179: 96.45
# Start training for epoch: 180 of 200
# Accuracy on training data for epoch 180: 97.74
# Accuracy on testing data for epoch 180: 96.68
# Start training for epoch: 181 of 200
# Accuracy on training data for epoch 181: 97.97
# Accuracy on testing data for epoch 181: 96.97
# Start training for epoch: 182 of 200
# Accuracy on training data for epoch 182: 97.97
# Accuracy on testing data for epoch 182: 96.73
# Start training for epoch: 183 of 200
# Accuracy on training data for epoch 183: 96.73
# Accuracy on testing data for epoch 183: 95.52
# Start training for epoch: 184 of 200
# Accuracy on training data for epoch 184: 98.24
# Accuracy on testing data for epoch 184: 96.9
# Start training for epoch: 185 of 200
# Accuracy on training data for epoch 185: 97.33
# Accuracy on testing data for epoch 185: 96.25
# Start training for epoch: 186 of 200
# Accuracy on training data for epoch 186: 97.86
# Accuracy on testing data for epoch 186: 96.68
# Start training for epoch: 187 of 200
# Accuracy on training data for epoch 187: 97.82
# Accuracy on testing data for epoch 187: 96.45
# Start training for epoch: 188 of 200
# Accuracy on training data for epoch 188: 97.15
# Accuracy on testing data for epoch 188: 95.81
# Start training for epoch: 189 of 200
# Accuracy on training data for epoch 189: 98.57
# Accuracy on testing data for epoch 189: 97.32
# Start training for epoch: 190 of 200
# Accuracy on training data for epoch 190: 96.76
# Accuracy on testing data for epoch 190: 95.14
# Start training for epoch: 191 of 200
# Accuracy on training data for epoch 191: 97.28
# Accuracy on testing data for epoch 191: 95.89
# Start training for epoch: 192 of 200
# Accuracy on training data for epoch 192: 97.68
# Accuracy on testing data for epoch 192: 96.37
# Start training for epoch: 193 of 200
# Accuracy on training data for epoch 193: 98.53
# Accuracy on testing data for epoch 193: 97.32
# Start training for epoch: 194 of 200
# Accuracy on training data for epoch 194: 97.7
# Accuracy on testing data for epoch 194: 96.55
# Start training for epoch: 195 of 200
# Accuracy on training data for epoch 195: 97.26
# Accuracy on testing data for epoch 195: 96.18
# Start training for epoch: 196 of 200
# Accuracy on training data for epoch 196: 97.37
# Accuracy on testing data for epoch 196: 96.03
# Start training for epoch: 197 of 200
# Accuracy on training data for epoch 197: 97.05
# Accuracy on testing data for epoch 197: 95.82
# Start training for epoch: 198 of 200
# Accuracy on training data for epoch 198: 95.83
# Accuracy on testing data for epoch 198: 95.01
# Start training for epoch: 199 of 200
# Accuracy on training data for epoch 199: 97.32
# Accuracy on testing data for epoch 199: 96.36
# Start training for epoch: 200 of 200
# Accuracy on training data for epoch 200: 96.98
# Accuracy on testing data for epoch 200: 95.79

# %% [markdown]
# ### [Testing dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 80% neuron retention; 100 epochs
# Previous setting shows a peak accuray of around ~97% on testing data. Try decreasing dropout

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 100
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.85

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training, testing, params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 100
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.85
# Start training for epoch: 1 of 100
# Accuracy on training data for epoch 1: 90.88
# Accuracy on testing data for epoch 1: 91.36
# Start training for epoch: 2 of 100
# Accuracy on training data for epoch 2: 91.12
# Accuracy on testing data for epoch 2: 91.18
# Start training for epoch: 3 of 100
# Accuracy on training data for epoch 3: 90.21
# Accuracy on testing data for epoch 3: 90.38
# Start training for epoch: 4 of 100
# Accuracy on training data for epoch 4: 90.82
# Accuracy on testing data for epoch 4: 90.94
# Start training for epoch: 5 of 100
# Accuracy on training data for epoch 5: 89.5
# Accuracy on testing data for epoch 5: 89.26
# Start training for epoch: 6 of 100
# Accuracy on training data for epoch 6: 91.81
# Accuracy on testing data for epoch 6: 91.19
# Start training for epoch: 7 of 100
# Accuracy on training data for epoch 7: 93.31
# Accuracy on testing data for epoch 7: 92.78
# Start training for epoch: 8 of 100
# Accuracy on training data for epoch 8: 90.62
# Accuracy on testing data for epoch 8: 90.36
# Start training for epoch: 9 of 100
# Accuracy on training data for epoch 9: 93.36
# Accuracy on testing data for epoch 9: 92.51
# Start training for epoch: 10 of 100
# Accuracy on training data for epoch 10: 94.67
# Accuracy on testing data for epoch 10: 93.94
# Start training for epoch: 11 of 100
# Accuracy on training data for epoch 11: 92.75
# Accuracy on testing data for epoch 11: 92.23
# Start training for epoch: 12 of 100
# Accuracy on training data for epoch 12: 94.99
# Accuracy on testing data for epoch 12: 94.65
# Start training for epoch: 13 of 100
# Accuracy on training data for epoch 13: 95.88
# Accuracy on testing data for epoch 13: 95.36
# Start training for epoch: 14 of 100
# Accuracy on training data for epoch 14: 95.31
# Accuracy on testing data for epoch 14: 94.46
# Start training for epoch: 15 of 100
# Accuracy on training data for epoch 15: 95.41
# Accuracy on testing data for epoch 15: 94.47
# Start training for epoch: 16 of 100
# Accuracy on training data for epoch 16: 94.84
# Accuracy on testing data for epoch 16: 94.2
# Start training for epoch: 17 of 100
# Accuracy on training data for epoch 17: 96.16
# Accuracy on testing data for epoch 17: 95.35
# Start training for epoch: 18 of 100
# Accuracy on training data for epoch 18: 96.34
# Accuracy on testing data for epoch 18: 95.65
# Start training for epoch: 19 of 100
# Accuracy on training data for epoch 19: 93.21
# Accuracy on testing data for epoch 19: 92.23
# Start training for epoch: 20 of 100
# Accuracy on training data for epoch 20: 94.84
# Accuracy on testing data for epoch 20: 93.99
# Start training for epoch: 21 of 100
# Accuracy on training data for epoch 21: 96.4
# Accuracy on testing data for epoch 21: 95.79
# Start training for epoch: 22 of 100
# Accuracy on training data for epoch 22: 95.97
# Accuracy on testing data for epoch 22: 95.37
# Start training for epoch: 23 of 100
# Accuracy on training data for epoch 23: 94.03
# Accuracy on testing data for epoch 23: 92.32
# Start training for epoch: 24 of 100
# Accuracy on training data for epoch 24: 92.9
# Accuracy on testing data for epoch 24: 91.72
# Start training for epoch: 25 of 100
# Accuracy on training data for epoch 25: 96.94
# Accuracy on testing data for epoch 25: 95.6
# Start training for epoch: 26 of 100
# Accuracy on training data for epoch 26: 94.15
# Accuracy on testing data for epoch 26: 93.37
# Start training for epoch: 27 of 100
# Accuracy on training data for epoch 27: 94.35
# Accuracy on testing data for epoch 27: 93.17
# Start training for epoch: 28 of 100
# Accuracy on training data for epoch 28: 96.02
# Accuracy on testing data for epoch 28: 94.82
# Start training for epoch: 29 of 100
# Accuracy on training data for epoch 29: 96.13
# Accuracy on testing data for epoch 29: 95.13
# Start training for epoch: 30 of 100
# Accuracy on training data for epoch 30: 97.54
# Accuracy on testing data for epoch 30: 96.51
# Start training for epoch: 31 of 100
# Accuracy on training data for epoch 31: 95.87
# Accuracy on testing data for epoch 31: 94.37
# Start training for epoch: 32 of 100
# Accuracy on training data for epoch 32: 97.79
# Accuracy on testing data for epoch 32: 96.37
# Start training for epoch: 33 of 100
# Accuracy on training data for epoch 33: 95.17
# Accuracy on testing data for epoch 33: 94.04
# Start training for epoch: 34 of 100
# Accuracy on training data for epoch 34: 97.77
# Accuracy on testing data for epoch 34: 96.66
# Start training for epoch: 35 of 100
# Accuracy on training data for epoch 35: 98.41
# Accuracy on testing data for epoch 35: 97.02
# Start training for epoch: 36 of 100
# Accuracy on training data for epoch 36: 97.99
# Accuracy on testing data for epoch 36: 97.05
# Start training for epoch: 37 of 100
# Accuracy on training data for epoch 37: 97.33
# Accuracy on testing data for epoch 37: 96.01
# Start training for epoch: 38 of 100
# Accuracy on training data for epoch 38: 95.93
# Accuracy on testing data for epoch 38: 94.83
# Start training for epoch: 39 of 100
# Accuracy on training data for epoch 39: 94.12
# Accuracy on testing data for epoch 39: 93.28
# Start training for epoch: 40 of 100
# Accuracy on training data for epoch 40: 97.84
# Accuracy on testing data for epoch 40: 96.3
# Start training for epoch: 41 of 100
# Accuracy on training data for epoch 41: 96.38
# Accuracy on testing data for epoch 41: 95.0
# Start training for epoch: 42 of 100
# Accuracy on training data for epoch 42: 98.02
# Accuracy on testing data for epoch 42: 96.4
# Start training for epoch: 43 of 100
# Accuracy on training data for epoch 43: 96.2
# Accuracy on testing data for epoch 43: 95.05
# Start training for epoch: 44 of 100
# Accuracy on training data for epoch 44: 98.15
# Accuracy on testing data for epoch 44: 96.65
# Start training for epoch: 45 of 100
# Accuracy on training data for epoch 45: 97.3
# Accuracy on testing data for epoch 45: 95.79
# Start training for epoch: 46 of 100
# Accuracy on training data for epoch 46: 98.19
# Accuracy on testing data for epoch 46: 96.86
# Start training for epoch: 47 of 100
# Accuracy on training data for epoch 47: 97.98
# Accuracy on testing data for epoch 47: 96.86
# Start training for epoch: 48 of 100
# Accuracy on training data for epoch 48: 96.21
# Accuracy on testing data for epoch 48: 95.2
# Start training for epoch: 49 of 100
# Accuracy on training data for epoch 49: 96.6
# Accuracy on testing data for epoch 49: 95.41
# Start training for epoch: 50 of 100
# Accuracy on training data for epoch 50: 97.97
# Accuracy on testing data for epoch 50: 96.52
# Start training for epoch: 51 of 100
# Accuracy on training data for epoch 51: 98.11
# Accuracy on testing data for epoch 51: 96.54
# Start training for epoch: 52 of 100
# Accuracy on training data for epoch 52: 98.46
# Accuracy on testing data for epoch 52: 96.94
# Start training for epoch: 53 of 100
# Accuracy on training data for epoch 53: 98.39
# Accuracy on testing data for epoch 53: 96.53
# Start training for epoch: 54 of 100
# Accuracy on training data for epoch 54: 98.13
# Accuracy on testing data for epoch 54: 96.52
# Start training for epoch: 55 of 100
# Accuracy on training data for epoch 55: 95.59
# Accuracy on testing data for epoch 55: 94.03
# Start training for epoch: 56 of 100
# Accuracy on training data for epoch 56: 98.39
# Accuracy on testing data for epoch 56: 96.86
# Start training for epoch: 57 of 100
# Accuracy on training data for epoch 57: 97.86
# Accuracy on testing data for epoch 57: 96.49
# Start training for epoch: 58 of 100
# Accuracy on training data for epoch 58: 98.48
# Accuracy on testing data for epoch 58: 96.95
# Start training for epoch: 59 of 100
# Accuracy on training data for epoch 59: 97.16
# Accuracy on testing data for epoch 59: 95.9
# Start training for epoch: 60 of 100
# Accuracy on training data for epoch 60: 97.66
# Accuracy on testing data for epoch 60: 96.2
# Start training for epoch: 61 of 100
# Accuracy on training data for epoch 61: 97.05
# Accuracy on testing data for epoch 61: 96.22
# Start training for epoch: 62 of 100
# Accuracy on training data for epoch 62: 98.72
# Accuracy on testing data for epoch 62: 97.19
# Start training for epoch: 63 of 100
# Accuracy on training data for epoch 63: 96.76
# Accuracy on testing data for epoch 63: 95.0
# Start training for epoch: 64 of 100
# Accuracy on training data for epoch 64: 97.94
# Accuracy on testing data for epoch 64: 96.48
# Start training for epoch: 65 of 100
# Accuracy on training data for epoch 65: 98.98
# Accuracy on testing data for epoch 65: 97.49
# Start training for epoch: 66 of 100
# Accuracy on training data for epoch 66: 98.27
# Accuracy on testing data for epoch 66: 96.61
# Start training for epoch: 67 of 100
# Accuracy on training data for epoch 67: 98.73
# Accuracy on testing data for epoch 67: 97.01
# Start training for epoch: 68 of 100
# Accuracy on training data for epoch 68: 99.03
# Accuracy on testing data for epoch 68: 97.69
# Start training for epoch: 69 of 100
# Accuracy on training data for epoch 69: 98.71
# Accuracy on testing data for epoch 69: 97.26
# Start training for epoch: 70 of 100
# Accuracy on training data for epoch 70: 98.1
# Accuracy on testing data for epoch 70: 96.24
# Start training for epoch: 71 of 100
# Accuracy on training data for epoch 71: 97.45
# Accuracy on testing data for epoch 71: 95.77
# Start training for epoch: 72 of 100
# Accuracy on training data for epoch 72: 96.63
# Accuracy on testing data for epoch 72: 94.74
# Start training for epoch: 73 of 100
# Accuracy on training data for epoch 73: 95.93
# Accuracy on testing data for epoch 73: 94.32
# Start training for epoch: 74 of 100
# Accuracy on training data for epoch 74: 98.29
# Accuracy on testing data for epoch 74: 96.64
# Start training for epoch: 75 of 100
# Accuracy on training data for epoch 75: 97.81
# Accuracy on testing data for epoch 75: 96.32
# Start training for epoch: 76 of 100
# Accuracy on training data for epoch 76: 98.28
# Accuracy on testing data for epoch 76: 96.32
# Start training for epoch: 77 of 100
# Accuracy on training data for epoch 77: 96.9
# Accuracy on testing data for epoch 77: 95.26
# Start training for epoch: 78 of 100
# Accuracy on training data for epoch 78: 99.16
# Accuracy on testing data for epoch 78: 97.57
# Start training for epoch: 79 of 100
# Accuracy on training data for epoch 79: 99.15
# Accuracy on testing data for epoch 79: 97.44
# Start training for epoch: 80 of 100
# Accuracy on training data for epoch 80: 98.9
# Accuracy on testing data for epoch 80: 97.15
# Start training for epoch: 81 of 100
# Accuracy on training data for epoch 81: 98.6
# Accuracy on testing data for epoch 81: 96.66
# Start training for epoch: 82 of 100
# Accuracy on training data for epoch 82: 97.66
# Accuracy on testing data for epoch 82: 95.47
# Start training for epoch: 83 of 100
# Accuracy on training data for epoch 83: 98.53
# Accuracy on testing data for epoch 83: 96.84
# Start training for epoch: 84 of 100
# Accuracy on training data for epoch 84: 97.88
# Accuracy on testing data for epoch 84: 96.41
# Start training for epoch: 85 of 100
# Accuracy on training data for epoch 85: 98.43
# Accuracy on testing data for epoch 85: 96.92
# Start training for epoch: 86 of 100
# Accuracy on training data for epoch 86: 97.62
# Accuracy on testing data for epoch 86: 96.29
# Start training for epoch: 87 of 100
# Accuracy on training data for epoch 87: 98.86
# Accuracy on testing data for epoch 87: 97.01
# Start training for epoch: 88 of 100
# Accuracy on training data for epoch 88: 98.0
# Accuracy on testing data for epoch 88: 96.26
# Start training for epoch: 89 of 100
# Accuracy on training data for epoch 89: 97.45
# Accuracy on testing data for epoch 89: 96.0
# Start training for epoch: 90 of 100
# Accuracy on training data for epoch 90: 97.36
# Accuracy on testing data for epoch 90: 95.7
# Start training for epoch: 91 of 100
# Accuracy on training data for epoch 91: 98.83
# Accuracy on testing data for epoch 91: 97.2
# Start training for epoch: 92 of 100
# Accuracy on training data for epoch 92: 98.65
# Accuracy on testing data for epoch 92: 97.27
# Start training for epoch: 93 of 100
# Accuracy on training data for epoch 93: 97.27
# Accuracy on testing data for epoch 93: 96.14
# Start training for epoch: 94 of 100
# Accuracy on training data for epoch 94: 96.78
# Accuracy on testing data for epoch 94: 95.52
# Start training for epoch: 95 of 100
# Accuracy on training data for epoch 95: 97.83
# Accuracy on testing data for epoch 95: 96.39
# Start training for epoch: 96 of 100
# Accuracy on training data for epoch 96: 96.86
# Accuracy on testing data for epoch 96: 95.13
# Start training for epoch: 97 of 100
# Accuracy on training data for epoch 97: 98.1
# Accuracy on testing data for epoch 97: 96.35
# Start training for epoch: 98 of 100
# Accuracy on training data for epoch 98: 98.65
# Accuracy on testing data for epoch 98: 96.85
# Start training for epoch: 99 of 100
# Accuracy on training data for epoch 99: 98.53
# Accuracy on testing data for epoch 99: 96.77
# Start training for epoch: 100 of 100
# Accuracy on training data for epoch 100: 99.44
# Accuracy on testing data for epoch 100: 97.61

# %% [markdown]
# ### [Testing dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 90% neuron retention; 100 epochs
# More consistent results observed, use lesser dropout

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 100
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 0.9

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training, testing, params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 100
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 0.9
# Start training for epoch: 1 of 100
# Accuracy on training data for epoch 1: 89.75
# Accuracy on testing data for epoch 1: 90.32
# Start training for epoch: 2 of 100
# Accuracy on training data for epoch 2: 91.83
# Accuracy on testing data for epoch 2: 92.39
# Start training for epoch: 3 of 100
# Accuracy on training data for epoch 3: 90.61
# Accuracy on testing data for epoch 3: 90.91
# Start training for epoch: 4 of 100
# Accuracy on training data for epoch 4: 93.14
# Accuracy on testing data for epoch 4: 93.02
# Start training for epoch: 5 of 100
# Accuracy on training data for epoch 5: 93.74
# Accuracy on testing data for epoch 5: 93.54
# Start training for epoch: 6 of 100
# Accuracy on training data for epoch 6: 93.34
# Accuracy on testing data for epoch 6: 92.82
# Start training for epoch: 7 of 100
# Accuracy on training data for epoch 7: 93.21
# Accuracy on testing data for epoch 7: 92.75
# Start training for epoch: 8 of 100
# Accuracy on training data for epoch 8: 95.9
# Accuracy on testing data for epoch 8: 95.35
# Start training for epoch: 9 of 100
# Accuracy on training data for epoch 9: 94.65
# Accuracy on testing data for epoch 9: 93.97
# Start training for epoch: 10 of 100
# Accuracy on training data for epoch 10: 95.79
# Accuracy on testing data for epoch 10: 95.39
# Start training for epoch: 11 of 100
# Accuracy on training data for epoch 11: 95.54
# Accuracy on testing data for epoch 11: 94.63
# Start training for epoch: 12 of 100
# Accuracy on training data for epoch 12: 96.49
# Accuracy on testing data for epoch 12: 95.89
# Start training for epoch: 13 of 100
# Accuracy on training data for epoch 13: 96.33
# Accuracy on testing data for epoch 13: 95.47
# Start training for epoch: 14 of 100
# Accuracy on training data for epoch 14: 95.65
# Accuracy on testing data for epoch 14: 95.02
# Start training for epoch: 15 of 100
# Accuracy on training data for epoch 15: 96.73
# Accuracy on testing data for epoch 15: 95.62
# Start training for epoch: 16 of 100
# Accuracy on training data for epoch 16: 96.1
# Accuracy on testing data for epoch 16: 94.93
# Start training for epoch: 17 of 100
# Accuracy on training data for epoch 17: 96.14
# Accuracy on testing data for epoch 17: 94.9
# Start training for epoch: 18 of 100
# Accuracy on training data for epoch 18: 94.33
# Accuracy on testing data for epoch 18: 93.56
# Start training for epoch: 19 of 100
# Accuracy on training data for epoch 19: 95.45
# Accuracy on testing data for epoch 19: 94.94
# Start training for epoch: 20 of 100
# Accuracy on training data for epoch 20: 96.58
# Accuracy on testing data for epoch 20: 95.56
# Start training for epoch: 21 of 100
# Accuracy on training data for epoch 21: 97.35
# Accuracy on testing data for epoch 21: 95.83
# Start training for epoch: 22 of 100
# Accuracy on training data for epoch 22: 97.44
# Accuracy on testing data for epoch 22: 96.18
# Start training for epoch: 23 of 100
# Accuracy on training data for epoch 23: 94.04
# Accuracy on testing data for epoch 23: 93.05
# Start training for epoch: 24 of 100
# Accuracy on training data for epoch 24: 95.07
# Accuracy on testing data for epoch 24: 93.92
# Start training for epoch: 25 of 100
# Accuracy on training data for epoch 25: 95.27
# Accuracy on testing data for epoch 25: 93.96
# Start training for epoch: 26 of 100
# Accuracy on training data for epoch 26: 97.59
# Accuracy on testing data for epoch 26: 96.31
# Start training for epoch: 27 of 100
# Accuracy on training data for epoch 27: 97.82
# Accuracy on testing data for epoch 27: 96.22
# Start training for epoch: 28 of 100
# Accuracy on training data for epoch 28: 96.83
# Accuracy on testing data for epoch 28: 95.53
# Start training for epoch: 29 of 100
# Accuracy on training data for epoch 29: 97.97
# Accuracy on testing data for epoch 29: 96.47
# Start training for epoch: 30 of 100
# Accuracy on training data for epoch 30: 96.85
# Accuracy on testing data for epoch 30: 95.6
# Start training for epoch: 31 of 100
# Accuracy on training data for epoch 31: 97.08
# Accuracy on testing data for epoch 31: 95.57
# Start training for epoch: 32 of 100
# Accuracy on training data for epoch 32: 98.26
# Accuracy on testing data for epoch 32: 96.59
# Start training for epoch: 33 of 100
# Accuracy on training data for epoch 33: 97.06
# Accuracy on testing data for epoch 33: 95.87
# Start training for epoch: 34 of 100
# Accuracy on training data for epoch 34: 96.93
# Accuracy on testing data for epoch 34: 95.44
# Start training for epoch: 35 of 100
# Accuracy on training data for epoch 35: 97.91
# Accuracy on testing data for epoch 35: 96.3
# Start training for epoch: 36 of 100
# Accuracy on training data for epoch 36: 97.63
# Accuracy on testing data for epoch 36: 96.1
# Start training for epoch: 37 of 100
# Accuracy on training data for epoch 37: 97.34
# Accuracy on testing data for epoch 37: 95.66
# Start training for epoch: 38 of 100
# Accuracy on training data for epoch 38: 98.16
# Accuracy on testing data for epoch 38: 96.98
# Start training for epoch: 39 of 100
# Accuracy on training data for epoch 39: 98.1
# Accuracy on testing data for epoch 39: 96.55
# Start training for epoch: 40 of 100
# Accuracy on training data for epoch 40: 97.44
# Accuracy on testing data for epoch 40: 96.2
# Start training for epoch: 41 of 100
# Accuracy on training data for epoch 41: 97.74
# Accuracy on testing data for epoch 41: 96.12
# Start training for epoch: 42 of 100
# Accuracy on training data for epoch 42: 97.84
# Accuracy on testing data for epoch 42: 96.29
# Start training for epoch: 43 of 100
# Accuracy on training data for epoch 43: 96.73
# Accuracy on testing data for epoch 43: 95.25
# Start training for epoch: 44 of 100
# Accuracy on training data for epoch 44: 98.3
# Accuracy on testing data for epoch 44: 96.75
# Start training for epoch: 45 of 100
# Accuracy on training data for epoch 45: 95.04
# Accuracy on testing data for epoch 45: 93.8
# Start training for epoch: 46 of 100
# Accuracy on training data for epoch 46: 98.48
# Accuracy on testing data for epoch 46: 96.71
# Start training for epoch: 47 of 100
# Accuracy on training data for epoch 47: 97.8
# Accuracy on testing data for epoch 47: 96.04
# Start training for epoch: 48 of 100
# Accuracy on training data for epoch 48: 98.75
# Accuracy on testing data for epoch 48: 96.94
# Start training for epoch: 49 of 100
# Accuracy on training data for epoch 49: 98.53
# Accuracy on testing data for epoch 49: 96.96
# Start training for epoch: 50 of 100
# Accuracy on training data for epoch 50: 95.56
# Accuracy on testing data for epoch 50: 94.42
# Start training for epoch: 51 of 100
# Accuracy on training data for epoch 51: 96.63
# Accuracy on testing data for epoch 51: 95.08
# Start training for epoch: 52 of 100
# Accuracy on training data for epoch 52: 98.07
# Accuracy on testing data for epoch 52: 96.42
# Start training for epoch: 53 of 100
# Accuracy on training data for epoch 53: 97.95
# Accuracy on testing data for epoch 53: 96.19
# Start training for epoch: 54 of 100
# Accuracy on training data for epoch 54: 99.02
# Accuracy on testing data for epoch 54: 97.27
# Start training for epoch: 55 of 100
# Accuracy on training data for epoch 55: 98.37
# Accuracy on testing data for epoch 55: 96.39
# Start training for epoch: 56 of 100
# Accuracy on training data for epoch 56: 98.38
# Accuracy on testing data for epoch 56: 96.83
# Start training for epoch: 57 of 100
# Accuracy on training data for epoch 57: 98.66
# Accuracy on testing data for epoch 57: 96.71
# Start training for epoch: 58 of 100
# Accuracy on training data for epoch 58: 97.91
# Accuracy on testing data for epoch 58: 96.27
# Start training for epoch: 59 of 100
# Accuracy on training data for epoch 59: 98.03
# Accuracy on testing data for epoch 59: 95.99
# Start training for epoch: 60 of 100
# Accuracy on training data for epoch 60: 96.49
# Accuracy on testing data for epoch 60: 94.91
# Start training for epoch: 61 of 100
# Accuracy on training data for epoch 61: 96.86
# Accuracy on testing data for epoch 61: 94.87
# Start training for epoch: 62 of 100
# Accuracy on training data for epoch 62: 97.56
# Accuracy on testing data for epoch 62: 95.97
# Start training for epoch: 63 of 100
# Accuracy on training data for epoch 63: 97.16
# Accuracy on testing data for epoch 63: 95.64
# Start training for epoch: 64 of 100
# Accuracy on training data for epoch 64: 97.5
# Accuracy on testing data for epoch 64: 95.83
# Start training for epoch: 65 of 100
# Accuracy on training data for epoch 65: 98.73
# Accuracy on testing data for epoch 65: 96.9
# Start training for epoch: 66 of 100
# Accuracy on training data for epoch 66: 98.46
# Accuracy on testing data for epoch 66: 96.51
# Start training for epoch: 67 of 100
# Accuracy on training data for epoch 67: 98.38
# Accuracy on testing data for epoch 67: 96.53
# Start training for epoch: 68 of 100
# Accuracy on training data for epoch 68: 98.28
# Accuracy on testing data for epoch 68: 96.64
# Start training for epoch: 69 of 100
# Accuracy on training data for epoch 69: 97.17
# Accuracy on testing data for epoch 69: 95.75
# Start training for epoch: 70 of 100
# Accuracy on training data for epoch 70: 97.76
# Accuracy on testing data for epoch 70: 96.12
# Start training for epoch: 71 of 100
# Accuracy on training data for epoch 71: 98.44
# Accuracy on testing data for epoch 71: 96.61
# Start training for epoch: 72 of 100
# Accuracy on training data for epoch 72: 97.31
# Accuracy on testing data for epoch 72: 95.38
# Start training for epoch: 73 of 100
# Accuracy on training data for epoch 73: 98.17
# Accuracy on testing data for epoch 73: 96.44
# Start training for epoch: 74 of 100
# Accuracy on training data for epoch 74: 97.78
# Accuracy on testing data for epoch 74: 96.5
# Start training for epoch: 75 of 100
# Accuracy on training data for epoch 75: 98.71
# Accuracy on testing data for epoch 75: 96.91
# Start training for epoch: 76 of 100
# Accuracy on training data for epoch 76: 98.01
# Accuracy on testing data for epoch 76: 95.92
# Start training for epoch: 77 of 100
# Accuracy on training data for epoch 77: 98.77
# Accuracy on testing data for epoch 77: 96.58
# Start training for epoch: 78 of 100
# Accuracy on training data for epoch 78: 99.03
# Accuracy on testing data for epoch 78: 97.0
# Start training for epoch: 79 of 100
# Accuracy on training data for epoch 79: 99.15
# Accuracy on testing data for epoch 79: 97.29
# Start training for epoch: 80 of 100
# Accuracy on training data for epoch 80: 96.43
# Accuracy on testing data for epoch 80: 95.22
# Start training for epoch: 81 of 100
# Accuracy on training data for epoch 81: 98.52
# Accuracy on testing data for epoch 81: 96.73
# Start training for epoch: 82 of 100
# Accuracy on training data for epoch 82: 98.43
# Accuracy on testing data for epoch 82: 96.58
# Start training for epoch: 83 of 100
# Accuracy on training data for epoch 83: 98.2
# Accuracy on testing data for epoch 83: 96.21
# Start training for epoch: 84 of 100
# Accuracy on training data for epoch 84: 98.02
# Accuracy on testing data for epoch 84: 95.98
# Start training for epoch: 85 of 100
# Accuracy on training data for epoch 85: 98.42
# Accuracy on testing data for epoch 85: 96.36
# Start training for epoch: 86 of 100
# Accuracy on training data for epoch 86: 99.01
# Accuracy on testing data for epoch 86: 96.76
# Start training for epoch: 87 of 100
# Accuracy on training data for epoch 87: 98.06
# Accuracy on testing data for epoch 87: 95.86
# Start training for epoch: 88 of 100
# Accuracy on training data for epoch 88: 98.22
# Accuracy on testing data for epoch 88: 96.26
# Start training for epoch: 89 of 100
# Accuracy on training data for epoch 89: 98.44
# Accuracy on testing data for epoch 89: 96.98
# Start training for epoch: 90 of 100
# Accuracy on training data for epoch 90: 99.23
# Accuracy on testing data for epoch 90: 97.39
# Start training for epoch: 91 of 100
# Accuracy on training data for epoch 91: 98.53
# Accuracy on testing data for epoch 91: 96.73
# Start training for epoch: 92 of 100
# Accuracy on training data for epoch 92: 97.68
# Accuracy on testing data for epoch 92: 95.82
# Start training for epoch: 93 of 100
# Accuracy on training data for epoch 93: 98.38
# Accuracy on testing data for epoch 93: 96.65
# Start training for epoch: 94 of 100
# Accuracy on training data for epoch 94: 98.83
# Accuracy on testing data for epoch 94: 96.87
# Start training for epoch: 95 of 100
# Accuracy on training data for epoch 95: 99.16
# Accuracy on testing data for epoch 95: 97.11
# Start training for epoch: 96 of 100
# Accuracy on training data for epoch 96: 98.61
# Accuracy on testing data for epoch 96: 96.91
# Start training for epoch: 97 of 100
# Accuracy on training data for epoch 97: 97.95
# Accuracy on testing data for epoch 97: 96.09
# Start training for epoch: 98 of 100
# Accuracy on training data for epoch 98: 98.96
# Accuracy on testing data for epoch 98: 97.02
# Start training for epoch: 99 of 100
# Accuracy on training data for epoch 99: 99.33
# Accuracy on testing data for epoch 99: 97.15
# Start training for epoch: 100 of 100
# Accuracy on training data for epoch 100: 99.22
# Accuracy on testing data for epoch 100: 97.12

# %% [markdown]
# ### [Testing dataset] 0.01 eta; 4 layer(deeper hidden); 10 mini_batch; 100% neuron retention; 100 epochs
#
# ---
#
# Accuracy with dropout setting seems to not be that consistent. Remove dropout and try

# %%
class Hyperparameters:
    SIZE: List[int] = [784, 100, 100, 10]
    LEARNING_RATE: float = 0.01
    EPOCHS: int = 100
    MINI_BATCH_SIZE: int = 10
    # Add lambda hyperparameter
    LMDA: int = 5
    # Add dropout to the weights. Specify the % of neurons to retain
    DROPOUT_RETAIN: float = 1.0

    def __str__(self) -> str:
        str_rep = ""
        str_rep += "Hyperparameters set are as follows"
        for hyper_param in self.__annotations__:
            str_rep += f' \n {hyper_param}: {getattr(self, hyper_param)}'
        return str_rep

params = Hyperparameters()
print(params)
mlp = Network(training, testing, params.SIZE, params.LEARNING_RATE, params.EPOCHS,
              params.MINI_BATCH_SIZE,
              params.LMDA, training_accuracy_print=True, testing_accuracy_print=True)
mlp.train()
# Out:
# Hyperparameters set are as follows
#  SIZE: [784, 100, 100, 10]
#  LEARNING_RATE: 0.01
#  EPOCHS: 100
#  MINI_BATCH_SIZE: 10
#  LMDA: 5
#  DROPOUT_RETAIN: 1.0
# Start training for epoch: 1 of 100
# Accuracy on training data for epoch 1: 91.49
# Accuracy on testing data for epoch 1: 91.32
# Start training for epoch: 2 of 100
# Accuracy on training data for epoch 2: 94.01
# Accuracy on testing data for epoch 2: 94.01
# Start training for epoch: 3 of 100
# Accuracy on training data for epoch 3: 95.35
# Accuracy on testing data for epoch 3: 94.98
# Start training for epoch: 4 of 100
# Accuracy on training data for epoch 4: 96.01
# Accuracy on testing data for epoch 4: 95.59
# Start training for epoch: 5 of 100
# Accuracy on training data for epoch 5: 96.64
# Accuracy on testing data for epoch 5: 95.99
# Start training for epoch: 6 of 100
# Accuracy on training data for epoch 6: 97.05
# Accuracy on testing data for epoch 6: 96.25
# Start training for epoch: 7 of 100
# Accuracy on training data for epoch 7: 97.48
# Accuracy on testing data for epoch 7: 96.53
# Start training for epoch: 8 of 100
# Accuracy on training data for epoch 8: 97.94
# Accuracy on testing data for epoch 8: 96.9
# Start training for epoch: 9 of 100
# Accuracy on training data for epoch 9: 97.58
# Accuracy on testing data for epoch 9: 96.44
# Start training for epoch: 10 of 100
# Accuracy on training data for epoch 10: 98.17
# Accuracy on testing data for epoch 10: 96.74
# Start training for epoch: 11 of 100
# Accuracy on training data for epoch 11: 98.56
# Accuracy on testing data for epoch 11: 97.25
# Start training for epoch: 12 of 100
# Accuracy on training data for epoch 12: 98.67
# Accuracy on testing data for epoch 12: 97.21
# Start training for epoch: 13 of 100
# Accuracy on training data for epoch 13: 98.83
# Accuracy on testing data for epoch 13: 97.26
# Start training for epoch: 14 of 100
# Accuracy on training data for epoch 14: 98.96
# Accuracy on testing data for epoch 14: 97.35
# Start training for epoch: 15 of 100
# Accuracy on training data for epoch 15: 98.98
# Accuracy on testing data for epoch 15: 97.26
# Start training for epoch: 16 of 100
# Accuracy on training data for epoch 16: 99.21
# Accuracy on testing data for epoch 16: 97.42
# Start training for epoch: 17 of 100
# Accuracy on training data for epoch 17: 99.14
# Accuracy on testing data for epoch 17: 97.24
# Start training for epoch: 18 of 100
# Accuracy on training data for epoch 18: 99.34
# Accuracy on testing data for epoch 18: 97.45
# Start training for epoch: 19 of 100
# Accuracy on training data for epoch 19: 99.44
# Accuracy on testing data for epoch 19: 97.45
# Start training for epoch: 20 of 100
# Accuracy on training data for epoch 20: 99.43
# Accuracy on testing data for epoch 20: 97.57
# Start training for epoch: 21 of 100
# Accuracy on training data for epoch 21: 99.56
# Accuracy on testing data for epoch 21: 97.46
# Start training for epoch: 22 of 100
# Accuracy on training data for epoch 22: 99.57
# Accuracy on testing data for epoch 22: 97.41
# Start training for epoch: 23 of 100
# Accuracy on training data for epoch 23: 99.7
# Accuracy on testing data for epoch 23: 97.47
# Start training for epoch: 24 of 100
# Accuracy on training data for epoch 24: 99.71
# Accuracy on testing data for epoch 24: 97.54
# Start training for epoch: 25 of 100
# Accuracy on training data for epoch 25: 99.6
# Accuracy on testing data for epoch 25: 97.29
# Start training for epoch: 26 of 100
# Accuracy on training data for epoch 26: 99.75
# Accuracy on testing data for epoch 26: 97.55
# Start training for epoch: 27 of 100
# Accuracy on training data for epoch 27: 99.84
# Accuracy on testing data for epoch 27: 97.6
# Start training for epoch: 28 of 100
# Accuracy on training data for epoch 28: 99.83
# Accuracy on testing data for epoch 28: 97.57
# Start training for epoch: 29 of 100
# Accuracy on training data for epoch 29: 99.81
# Accuracy on testing data for epoch 29: 97.46
# Start training for epoch: 30 of 100
# Accuracy on training data for epoch 30: 99.82
# Accuracy on testing data for epoch 30: 97.53
# Start training for epoch: 31 of 100
# Accuracy on training data for epoch 31: 99.91
# Accuracy on testing data for epoch 31: 97.48
# Start training for epoch: 32 of 100
# Accuracy on training data for epoch 32: 99.9
# Accuracy on testing data for epoch 32: 97.47
# Start training for epoch: 33 of 100
# Accuracy on training data for epoch 33: 99.93
# Accuracy on testing data for epoch 33: 97.53
# Start training for epoch: 34 of 100
# Accuracy on training data for epoch 34: 99.94
# Accuracy on testing data for epoch 34: 97.66
# Start training for epoch: 35 of 100
# Accuracy on training data for epoch 35: 99.9
# Accuracy on testing data for epoch 35: 97.54
# Start training for epoch: 36 of 100
# Accuracy on training data for epoch 36: 99.94
# Accuracy on testing data for epoch 36: 97.51
# Start training for epoch: 37 of 100
# Accuracy on training data for epoch 37: 99.97
# Accuracy on testing data for epoch 37: 97.58
# Start training for epoch: 38 of 100
# Accuracy on training data for epoch 38: 99.97
# Accuracy on testing data for epoch 38: 97.55
# Start training for epoch: 39 of 100
# Accuracy on training data for epoch 39: 99.96
# Accuracy on testing data for epoch 39: 97.55
# Start training for epoch: 40 of 100
# Accuracy on training data for epoch 40: 99.97
# Accuracy on testing data for epoch 40: 97.57
# Start training for epoch: 41 of 100
# Accuracy on training data for epoch 41: 99.97
# Accuracy on testing data for epoch 41: 97.45
# Start training for epoch: 42 of 100
# Accuracy on training data for epoch 42: 99.99
# Accuracy on testing data for epoch 42: 97.51
# Start training for epoch: 43 of 100
# Accuracy on training data for epoch 43: 99.99
# Accuracy on testing data for epoch 43: 97.58
# Start training for epoch: 44 of 100
# Accuracy on training data for epoch 44: 99.99
# Accuracy on testing data for epoch 44: 97.59
# Start training for epoch: 45 of 100
# Accuracy on training data for epoch 45: 99.99
# Accuracy on testing data for epoch 45: 97.52
# Start training for epoch: 46 of 100
# Accuracy on training data for epoch 46: 100.0
# Accuracy on testing data for epoch 46: 97.53
# Start training for epoch: 47 of 100
# Accuracy on training data for epoch 47: 100.0
# Accuracy on testing data for epoch 47: 97.5
# Start training for epoch: 48 of 100
# Accuracy on training data for epoch 48: 100.0
# Accuracy on testing data for epoch 48: 97.62
# Start training for epoch: 49 of 100
# Accuracy on training data for epoch 49: 100.0
# Accuracy on testing data for epoch 49: 97.64
# Start training for epoch: 50 of 100
# Accuracy on training data for epoch 50: 99.99
# Accuracy on testing data for epoch 50: 97.51
# Start training for epoch: 51 of 100
# Accuracy on training data for epoch 51: 100.0
# Accuracy on testing data for epoch 51: 97.51
# Start training for epoch: 52 of 100
# Accuracy on training data for epoch 52: 100.0
# Accuracy on testing data for epoch 52: 97.55
# Start training for epoch: 53 of 100
# Accuracy on training data for epoch 53: 100.0
# Accuracy on testing data for epoch 53: 97.59
# Start training for epoch: 54 of 100
# Accuracy on training data for epoch 54: 100.0
# Accuracy on testing data for epoch 54: 97.5
# Start training for epoch: 55 of 100
# Accuracy on training data for epoch 55: 100.0
# Accuracy on testing data for epoch 55: 97.61
# Start training for epoch: 56 of 100
# Accuracy on training data for epoch 56: 100.0
# Accuracy on testing data for epoch 56: 97.54
# Start training for epoch: 57 of 100
# Accuracy on training data for epoch 57: 100.0
# Accuracy on testing data for epoch 57: 97.58
# Start training for epoch: 58 of 100
# Accuracy on training data for epoch 58: 100.0
# Accuracy on testing data for epoch 58: 97.59
# Start training for epoch: 59 of 100
# Accuracy on training data for epoch 59: 100.0
# Accuracy on testing data for epoch 59: 97.51
# Start training for epoch: 60 of 100
# Accuracy on training data for epoch 60: 100.0
# Accuracy on testing data for epoch 60: 97.56
# Start training for epoch: 61 of 100
# Accuracy on training data for epoch 61: 100.0
# Accuracy on testing data for epoch 61: 97.5
# Start training for epoch: 62 of 100
# Accuracy on training data for epoch 62: 100.0
# Accuracy on testing data for epoch 62: 97.61
# Start training for epoch: 63 of 100
# Accuracy on training data for epoch 63: 100.0
# Accuracy on testing data for epoch 63: 97.54
# Start training for epoch: 64 of 100
# Accuracy on training data for epoch 64: 100.0
# Accuracy on testing data for epoch 64: 97.55
# Start training for epoch: 65 of 100
# Accuracy on training data for epoch 65: 100.0
# Accuracy on testing data for epoch 65: 97.54
# Start training for epoch: 66 of 100
# Accuracy on training data for epoch 66: 100.0
# Accuracy on testing data for epoch 66: 97.57
# Start training for epoch: 67 of 100
# Accuracy on training data for epoch 67: 100.0
# Accuracy on testing data for epoch 67: 97.56
# Start training for epoch: 68 of 100
# Accuracy on training data for epoch 68: 100.0
# Accuracy on testing data for epoch 68: 97.5
# Start training for epoch: 69 of 100
# Accuracy on training data for epoch 69: 100.0
# Accuracy on testing data for epoch 69: 97.61
# Start training for epoch: 70 of 100
# Accuracy on training data for epoch 70: 100.0
# Accuracy on testing data for epoch 70: 97.59
# Start training for epoch: 71 of 100
# Accuracy on training data for epoch 71: 100.0
# Accuracy on testing data for epoch 71: 97.59
# Start training for epoch: 72 of 100
# Accuracy on training data for epoch 72: 100.0
# Accuracy on testing data for epoch 72: 97.62
# Start training for epoch: 73 of 100
# Accuracy on training data for epoch 73: 100.0
# Accuracy on testing data for epoch 73: 97.62
# Start training for epoch: 74 of 100
# Accuracy on training data for epoch 74: 100.0
# Accuracy on testing data for epoch 74: 97.66
# Start training for epoch: 75 of 100
# Accuracy on training data for epoch 75: 100.0
# Accuracy on testing data for epoch 75: 97.65
# Start training for epoch: 76 of 100
# Accuracy on training data for epoch 76: 100.0
# Accuracy on testing data for epoch 76: 97.62
# Start training for epoch: 77 of 100
# Accuracy on training data for epoch 77: 100.0
# Accuracy on testing data for epoch 77: 97.49
# Start training for epoch: 78 of 100
# Accuracy on training data for epoch 78: 100.0
# Accuracy on testing data for epoch 78: 97.51
# Start training for epoch: 79 of 100
# Accuracy on training data for epoch 79: 100.0
# Accuracy on testing data for epoch 79: 97.57
# Start training for epoch: 80 of 100
# Accuracy on training data for epoch 80: 100.0
# Accuracy on testing data for epoch 80: 97.56
# Start training for epoch: 81 of 100
# Accuracy on training data for epoch 81: 100.0
# Accuracy on testing data for epoch 81: 97.6
# Start training for epoch: 82 of 100
# Accuracy on training data for epoch 82: 100.0
# Accuracy on testing data for epoch 82: 97.63
# Start training for epoch: 83 of 100
# Accuracy on training data for epoch 83: 100.0
# Accuracy on testing data for epoch 83: 97.57
# Start training for epoch: 84 of 100
# Accuracy on training data for epoch 84: 100.0
# Accuracy on testing data for epoch 84: 97.62
# Start training for epoch: 85 of 100
# Accuracy on training data for epoch 85: 100.0
# Accuracy on testing data for epoch 85: 97.54
# Start training for epoch: 86 of 100
# Accuracy on training data for epoch 86: 100.0
# Accuracy on testing data for epoch 86: 97.67
# Start training for epoch: 87 of 100
# Accuracy on training data for epoch 87: 100.0
# Accuracy on testing data for epoch 87: 97.61
# Start training for epoch: 88 of 100
# Accuracy on training data for epoch 88: 100.0
# Accuracy on testing data for epoch 88: 97.61
# Start training for epoch: 89 of 100
# Accuracy on training data for epoch 89: 100.0
# Accuracy on testing data for epoch 89: 97.56
# Start training for epoch: 90 of 100
# Accuracy on training data for epoch 90: 100.0
# Accuracy on testing data for epoch 90: 97.6
# Start training for epoch: 91 of 100
# Accuracy on training data for epoch 91: 100.0
# Accuracy on testing data for epoch 91: 97.64
# Start training for epoch: 92 of 100
# Accuracy on training data for epoch 92: 100.0
# Accuracy on testing data for epoch 92: 97.62
# Start training for epoch: 93 of 100
# Accuracy on training data for epoch 93: 100.0
# Accuracy on testing data for epoch 93: 97.58
# Start training for epoch: 94 of 100
# Accuracy on training data for epoch 94: 100.0
# Accuracy on testing data for epoch 94: 97.58
# Start training for epoch: 95 of 100
# Accuracy on training data for epoch 95: 100.0
# Accuracy on testing data for epoch 95: 97.69
# Start training for epoch: 96 of 100
# Accuracy on training data for epoch 96: 100.0
# Accuracy on testing data for epoch 96: 97.64
# Start training for epoch: 97 of 100
# Accuracy on training data for epoch 97: 100.0
# Accuracy on testing data for epoch 97: 97.71
# Start training for epoch: 98 of 100
# Accuracy on training data for epoch 98: 100.0
# Accuracy on testing data for epoch 98: 97.61
# Start training for epoch: 99 of 100
# Accuracy on training data for epoch 99: 100.0
# Accuracy on testing data for epoch 99: 97.58
# Start training for epoch: 100 of 100
# Accuracy on training data for epoch 100: 100.0
# Accuracy on testing data for epoch 100: 97.63

# %% [markdown]
# ### Key Takeaways
# - Peak accuracy of **~97.7%** seen on testing data(using the last hyperparameter setting).
# - Results were more consistent without dropout(this could also be the result of a flawed implementation of dropout?).
# - Beyond a certain epoch(46th in the last setting's output), training data accuracy is at 100% and testing data accuracy does not improve much.
# - Maybe for better tuning, an average of *N* iterations per setting with a fixed set of *N* random seeds is a better approach
